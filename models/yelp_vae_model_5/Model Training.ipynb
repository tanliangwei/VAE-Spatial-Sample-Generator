# %% [markdown]
# # Model Training
# In this notebook, we will train our VAE model. This involves:
#
# 1. Encoder
# 2. Decoder
# 3. Full Model

# %% [markdown]
# ## Importing Packages
# We will be using Keras to build and train our VAE

# %%
from __future__ import absolute_import, division, print_function, unicode_literals
# %matplotlib notebook
import tensorflow as tf

import os
import time
import numpy as np
import glob
import matplotlib.pyplot as plt
import PIL
import imageio
import h5py

import keras
from keras import backend as K
from keras.layers import Input, Dense, Lambda, Layer, Add, Multiply, Concatenate
from keras.models import Model, Sequential
from keras.utils import to_categorical
from keras.models import model_from_json

from IPython import display
import numpy as np
import pandas as pd
from sklearn import preprocessing

from matplotlib.ticker import FormatStrFormatter
from keras.utils.vis_utils import model_to_dot, plot_model
from IPython.display import SVG
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ## Definition of Constants
# Hyper parameters and constants will all be located here for ease of adjustments

# %%
categorical_dim = 11
categorical_map = {0:0, 0.5:1, 1: 2, 1.5:3, 2:4, 2.5:5, 3:6, 3.5:7, 4:8, 4.5:9, 5:10}
reverse_categorical_map = {0:0, 1:0.5, 2:1, 3:1.5, 4:2, 5:2.5, 6:3, 7:3.5, 8:4, 9:4.5, 10:5}
continuous_dim = 3
binary_dim = 1
original_dim = binary_dim + continuous_dim + categorical_dim
intermediate_dim_1 = 50
intermediate_dim_2 = 50
latent_dim = 4
batch_size = 100
epochs = 50
epsilon_std = 1.0

# %% [markdown]
# ## Building the Model
# We have to write our own custom layer and custom loss function as these are not supported on Keras natively. There are a few things to be done:
#
# 1. Custom KLDivergence Layer
# 2. Custom Loss Functions
# 3. Building the Model

# %% [markdown]
# ### KL Divergence Layer
# To ensure modularity, we decided to create a separate layer for KL Divergence. This layer will account for the loss required.

# %%
class KLDivergenceLayer(Layer):

    """ Identity transform layer that adds KL divergence
    to the final model loss.
    """

    def __init__(self, *args, **kwargs):
        self.is_placeholder = True
        super(KLDivergenceLayer, self).__init__(*args, **kwargs)

    def call(self, inputs):

        mu, log_var = inputs

        kl_batch = - .5 * K.sum(1 + log_var -
                                K.square(mu) -
                                K.exp(log_var), axis=-1)

        self.add_loss(K.mean(kl_batch), inputs=inputs)

        return inputs

# %% [markdown]
# ### Custom Loss Functions
# As the yelp dataset contains binary, categorical as well as continuous data, we will build 3 custom loss functions.
#
# #### Binary Loss Function

# %%
def binary_loss(y_true, y_pred):
	# input dimension is (batchsize, 1)
    return K.binary_crossentropy(y_true, y_pred) # the dimension of return value is (batchsize , 1)

# %% [markdown]
# #### Categorical Loss Function

# %%
def categorical_loss(y_true, y_pred):
	# input dimension is (batchsize, number of categories)
  return K.categorical_crossentropy(y_true, y_pred) # the dimension of return value is (batchsize , 1)

# %% [markdown]
# #### Continuous Loss Function

# %%
def log_normal_pdf(sample, mean, logvar, raxis=1):
  log2pi = tf.math.log(2. * np.pi)
  return tf.reduce_sum(
      -.5 * ((sample - mean) ** 2. * tf.exp(-logvar) + logvar + log2pi),
      axis=raxis) # return a tensor of shape (batch_size, 1)

# Added a postfix because now we also have poisson as a distribution
def continuous_loss_gaussian(y_true, y_pred):
	# need to return log probability for continuous gaussian loss.
	# will get a (batchsize, 6 continuous variable input) where 3 of the 6 represents mu and the others logvar
	# y_true will be (batchsize, 3)
  mu, logvar = tf.split(y_pred, num_or_size_splits = 2, axis = 1)
  return -1 * log_normal_pdf(y_true, mu, logvar) 

def continuous_loss_poisson(y_true, y_pred):
	# need to return log probability for continuous poisson loss.
	# will get a (batchsize, 6 continuous variable input) where 3 of the 6 represents mu and the others logvar
	# y_true will be (batchsize, 3)
  return tf.nn.log_poisson_loss(y_true, y_pred)

# %% [markdown]
# ### Model Architecture
# - tanh/sigmoid is used because Relu resulted in loss going to infinity
# - going to delete review_log_var and review_mu since we are trying out the Poission distribution which only takes 1 parameter.

# %%
x = Input(shape=(original_dim,), name='input_x')
h = Dense(intermediate_dim_1, activation='tanh', name='hidden_enc_1')(x)
h = Dense(intermediate_dim_2, activation='tanh', name='hidden_enc_2')(h)

z_mu = Dense(latent_dim, name='z_mu')(h)
z_log_var = Dense(latent_dim, name='z_log_var')(h)

z_mu, z_log_var = KLDivergenceLayer(name='KL_Divergence')([z_mu, z_log_var])
z_sigma = Lambda(lambda t: K.exp(.5*t))(z_log_var)

eps = Input(name='input_eps',tensor=K.random_normal(stddev=epsilon_std,
                                   shape=(K.shape(x)[0], latent_dim)))
z_eps = Multiply()([z_sigma, eps])
z = Add()([z_mu, z_eps])

decode_1 = Dense(intermediate_dim_2, activation='tanh', name='hidden_dec_2')
h_dec = decode_1(z)

decode_2 = Dense(intermediate_dim_1, activation='tanh', name='hidden_dec_1')
h_dec = decode_2(h_dec)

x_pred_coordinates_mu_layer = Dense(2, activation='sigmoid',name='x_pred_coordinates_mu')
x_pred_coordinates_mu = x_pred_coordinates_mu_layer(h_dec)

x_pred_coordinates_log_var_layer = Dense(2, name='x_pred_coordinates_log_var')
x_pred_coordinates_log_var = x_pred_coordinates_log_var_layer(h_dec)

x_pred_coordinates_layer = Concatenate(axis=-1, name = 'x_pred_coordinates')
x_pred_coordinates = x_pred_coordinates_layer([x_pred_coordinates_mu, x_pred_coordinates_log_var])

## This outputs the lambda require for poisson distribution and thats all that we need
x_pred_review_log_lambda_layer = Dense(1,name = 'x_pred_review_log_lambda_layer')
x_pred_review = x_pred_review_log_lambda_layer(h_dec)


# x_pred_review_mu_layer = Dense(1, activation='relu', name='x_pred_review_mu')
# x_pred_review_mu = x_pred_review_mu_layer(h_dec)

# x_pred_review_log_var_layer = Dense(1, name='x_pred_review_log_var')
# x_pred_review_log_var = x_pred_review_log_var_layer(h_dec)

# x_pred_review_layer = Concatenate(axis=-1, name = 'x_pred_review')
# x_pred_review = x_pred_review_layer([x_pred_review_mu, x_pred_review_log_var])

x_pred_binary_layer = Dense(binary_dim, activation='sigmoid', name='x_pred_binary')
x_pred_binary = x_pred_binary_layer(h_dec) # binary cross entropy

x_pred_categorical_layer = Dense(categorical_dim, activation='softmax', name='x_pred_categorical')
x_pred_categorical = x_pred_categorical_layer(h_dec) # categorical cross entropy

vae = Model(inputs=[x,eps], outputs=[x_pred_binary, x_pred_categorical, x_pred_review, x_pred_coordinates])

# %%
SVG(model_to_dot(vae, show_shapes=True)
    .create(prog='dot', format='svg'))

# %%
plot_model(
    model=vae, show_shapes=True,
    to_file='./description/vae_full_model.png'
)

# %% [markdown]
# ### Compiling Model and Setting Parameters

# %%
optimizer = keras.optimizers.Adam(lr=0.0001,clipvalue=1)
vae.compile(optimizer=optimizer, loss=[binary_loss, categorical_loss, continuous_loss_poisson, continuous_loss_gaussian], loss_weights=[1, 1, 1, 1])

# %%
vae.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_x (InputLayer)            (None, 15)           0
# __________________________________________________________________________________________________
# hidden_enc_1 (Dense)            (None, 50)           800         input_x[0][0]
# __________________________________________________________________________________________________
# hidden_enc_2 (Dense)            (None, 50)           2550        hidden_enc_1[0][0]
# __________________________________________________________________________________________________
# z_mu (Dense)                    (None, 4)            204         hidden_enc_2[0][0]
# __________________________________________________________________________________________________
# z_log_var (Dense)               (None, 4)            204         hidden_enc_2[0][0]
# __________________________________________________________________________________________________
# KL_Divergence (KLDivergenceLaye [(None, 4), (None, 4 0           z_mu[0][0]
#                                                                  z_log_var[0][0]
# __________________________________________________________________________________________________
# lambda_1 (Lambda)               (None, 4)            0           KL_Divergence[0][1]
# __________________________________________________________________________________________________
# input_eps (InputLayer)          (None, 4)            0
# __________________________________________________________________________________________________
# multiply_1 (Multiply)           (None, 4)            0           lambda_1[0][0]
#                                                                  input_eps[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 4)            0           KL_Divergence[0][0]
#                                                                  multiply_1[0][0]
# __________________________________________________________________________________________________
# hidden_dec_2 (Dense)            (None, 50)           250         add_1[0][0]
# __________________________________________________________________________________________________
# hidden_dec_1 (Dense)            (None, 50)           2550        hidden_dec_2[0][0]
# __________________________________________________________________________________________________
# x_pred_coordinates_mu (Dense)   (None, 2)            102         hidden_dec_1[0][0]
# __________________________________________________________________________________________________
# x_pred_coordinates_log_var (Den (None, 2)            102         hidden_dec_1[0][0]
# __________________________________________________________________________________________________
# x_pred_binary (Dense)           (None, 1)            51          hidden_dec_1[0][0]
# __________________________________________________________________________________________________
# x_pred_categorical (Dense)      (None, 11)           561         hidden_dec_1[0][0]
# __________________________________________________________________________________________________
# x_pred_review_log_lambda_layer  (None, 1)            51          hidden_dec_1[0][0]
# __________________________________________________________________________________________________
# x_pred_coordinates (Concatenate (None, 4)            0           x_pred_coordinates_mu[0][0]
#                                                                  x_pred_coordinates_log_var[0][0]
# ==================================================================================================
# Total params: 7,425
# Trainable params: 7,425
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# ## Data Loading and Preprocessing

# %%
dataset = np.genfromtxt('../../datasets/yelp_business.csv',delimiter=',',skip_header=1)
dataset = dataset[~np.isnan(dataset).any(axis=1)]
test_set, train_set = np.split(dataset,[1], axis = 0)

def format_data(dataset):
  # handling the categorical variables
  coordinates, ratings, reviews, is_opens = np.split(dataset, [2, 3, 4], axis = 1)
  one_hot_array = np.zeros((ratings.shape[0], categorical_dim))

  for i, r in enumerate(ratings):
    one_hot_array[i][categorical_map[r[0]]] = 1
  
  for i, c in enumerate(coordinates):
    coordinates[i][0] = (c[0]+180)/360
    coordinates[i][1] = (c[1]+180)/360

  dataset = np.concatenate((coordinates, reviews, is_opens, one_hot_array), axis = 1)

  # creating the labels
  coordinates_labels = coordinates
  review_labels = reviews
  categorical_labels = one_hot_array
  binary_labels = is_opens
  return dataset, coordinates_labels, review_labels, categorical_labels, binary_labels

train_dataset, train_coordinates_labels, train_review_labels, train_categorical_labels, train_binary_labels = format_data(train_set)
test_dataset, test_coordinates_labels, test_review_labels, test_categorical_labels, test_binary_labels = format_data(test_set)

# %% [markdown]
# ### Distribution of Review_Count

# %%
# import matplotlib.pyplot as plt
# plt.hist(train_review_labels, 1000)
# plt.show()

# %% [markdown]
# ## Training the Model

# %%
vae.fit(train_dataset , [train_binary_labels, train_categorical_labels, train_review_labels, train_coordinates_labels], shuffle = True, epochs = epochs, batch_size = batch_size, validation_data=(test_dataset , [test_binary_labels, test_categorical_labels, test_review_labels, test_coordinates_labels]))
# Out:
# Train on 174565 samples, validate on 1 samples
# Epoch 1/50
# 174565/174565 [==============================] - 15s 88us/step - loss: -94.7156 - x_pred_binary_loss: 0.5293 - x_pred_categorical_loss: 2.1124 - x_pred_review_log_lambda_layer_loss: -99.8756 - x_pred_coordinates_loss: 0.1301 - val_loss: -44.9978 - val_x_pred_binary_loss: 0.1444 - val_x_pred_categorical_loss: 1.4928 - val_x_pred_review_log_lambda_layer_loss: -45.9308 - val_x_pred_coordinates_loss: -3.1448
# Epoch 2/50
# 174565/174565 [==============================] - 12s 72us/step - loss: -106.8045 - x_pred_binary_loss: 0.4411 - x_pred_categorical_loss: 1.9919 - x_pred_review_log_lambda_layer_loss: -108.2528 - x_pred_coordinates_loss: -3.2146 - val_loss: -45.8449 - val_x_pred_binary_loss: 0.1804 - val_x_pred_categorical_loss: 1.3665 - val_x_pred_review_log_lambda_layer_loss: -45.7813 - val_x_pred_coordinates_loss: -3.8785rical_loss: 1.9939 - x_pred_review_log_lambda_layer_loss: -108.2347 - x_pred_coor
# Epoch 3/50
# 174565/174565 [==============================] - 9s 49us/step - loss: -107.8984 - x_pred_binary_loss: 0.4374 - x_pred_categorical_loss: 1.9720 - x_pred_review_log_lambda_layer_loss: -108.4411 - x_pred_coordinates_loss: -3.8653 - val_loss: -47.0900 - val_x_pred_binary_loss: 0.1360 - val_x_pred_categorical_loss: 1.5887 - val_x_pred_review_log_lambda_layer_loss: -45.8340 - val_x_pred_coordinates_loss: -4.9802
# Epoch 4/50
# 174565/174565 [==============================] - 7s 40us/step - loss: -108.4169 - x_pred_binary_loss: 0.4379 - x_pred_categorical_loss: 1.9664 - x_pred_review_log_lambda_layer_loss: -108.5365 - x_pred_coordinates_loss: -4.0454 - val_loss: -47.0580 - val_x_pred_binary_loss: 0.1503 - val_x_pred_categorical_loss: 1.4488 - val_x_pred_review_log_lambda_layer_loss: -45.9595 - val_x_pred_coordinates_loss: -4.4526
# Epoch 5/50
# 174565/174565 [==============================] - 12s 67us/step - loss: -108.5390 - x_pred_binary_loss: 0.4380 - x_pred_categorical_loss: 1.9644 - x_pred_review_log_lambda_layer_loss: -108.5721 - x_pred_coordinates_loss: -4.0574 - val_loss: -46.6719 - val_x_pred_binary_loss: 0.1825 - val_x_pred_categorical_loss: 1.3173 - val_x_pred_review_log_lambda_layer_loss: -45.5956 - val_x_pred_coordinates_loss: -4.1691
# Epoch 6/50
# 174565/174565 [==============================] - 16s 93us/step - loss: -108.5971 - x_pred_binary_loss: 0.4383 - x_pred_categorical_loss: 1.9630 - x_pred_review_log_lambda_layer_loss: -108.5427 - x_pred_coordinates_loss: -4.0646 - val_loss: -45.4065 - val_x_pred_binary_loss: 0.1424 - val_x_pred_categorical_loss: 1.5235 - val_x_pred_review_log_lambda_layer_loss: -43.6967 - val_x_pred_coordinates_loss: -4.9068
# Epoch 7/50
# 174565/174565 [==============================] - 13s 76us/step - loss: -108.6998 - x_pred_binary_loss: 0.4382 - x_pred_categorical_loss: 1.9615 - x_pred_review_log_lambda_layer_loss: -108.6174 - x_pred_coordinates_loss: -4.0748 - val_loss: -47.0645 - val_x_pred_binary_loss: 0.1827 - val_x_pred_categorical_loss: 1.3336 - val_x_pred_review_log_lambda_layer_loss: -45.7508 - val_x_pred_coordinates_loss: -4.3387
# Epoch 8/50
# 174565/174565 [==============================] - 13s 76us/step - loss: -108.8125 - x_pred_binary_loss: 0.4381 - x_pred_categorical_loss: 1.9587 - x_pred_review_log_lambda_layer_loss: -108.6774 - x_pred_coordinates_loss: -4.0874 - val_loss: -42.7662 - val_x_pred_binary_loss: 0.1261 - val_x_pred_categorical_loss: 1.4982 - val_x_pred_review_log_lambda_layer_loss: -40.9614 - val_x_pred_coordinates_loss: -4.8994
# Epoch 9/50
# 174565/174565 [==============================] - 15s 85us/step - loss: -108.8666 - x_pred_binary_loss: 0.4381 - x_pred_categorical_loss: 1.9533 - x_pred_review_log_lambda_layer_loss: -108.7101 - x_pred_coordinates_loss: -4.1072 - val_loss: -46.9123 - val_x_pred_binary_loss: 0.1714 - val_x_pred_categorical_loss: 1.5072 - val_x_pred_review_log_lambda_layer_loss: -45.5309 - val_x_pred_coordinates_loss: -4.5040
# Epoch 10/50
# 174565/174565 [==============================] - 17s 97us/step - loss: -108.9361 - x_pred_binary_loss: 0.4376 - x_pred_categorical_loss: 1.9428 - x_pred_review_log_lambda_layer_loss: -108.7288 - x_pred_coordinates_loss: -4.1467 - val_loss: -46.0014 - val_x_pred_binary_loss: 0.2082 - val_x_pred_categorical_loss: 1.3240 - val_x_pred_review_log_lambda_layer_loss: -45.0689 - val_x_pred_coordinates_loss: -3.9616: 0.4382 - x_pred_categorical_loss: 1.9442 - x_pred_review_
# Epoch 11/50
# 174565/174565 [==============================] - 11s 65us/step - loss: -108.9708 - x_pred_binary_loss: 0.4370 - x_pred_categorical_loss: 1.9222 - x_pred_review_log_lambda_layer_loss: -108.6926 - x_pred_coordinates_loss: -4.2459 - val_loss: -46.9706 - val_x_pred_binary_loss: 0.1707 - val_x_pred_categorical_loss: 1.4273 - val_x_pred_review_log_lambda_layer_loss: -45.6851 - val_x_pred_coordinates_loss: -4.4085
# Epoch 12/50
# 174565/174565 [==============================] - 10s 56us/step - loss: -109.1703 - x_pred_binary_loss: 0.4367 - x_pred_categorical_loss: 1.8933 - x_pred_review_log_lambda_layer_loss: -108.7586 - x_pred_coordinates_loss: -4.4518 - val_loss: -45.5028 - val_x_pred_binary_loss: 0.1628 - val_x_pred_categorical_loss: 1.5958 - val_x_pred_review_log_lambda_layer_loss: -44.0801 - val_x_pred_coordinates_loss: -4.7666
# Epoch 13/50
# 174565/174565 [==============================] - 10s 56us/step - loss: -109.3030 - x_pred_binary_loss: 0.4377 - x_pred_categorical_loss: 1.8866 - x_pred_review_log_lambda_layer_loss: -108.7565 - x_pred_coordinates_loss: -4.7343 - val_loss: -45.6054 - val_x_pred_binary_loss: 0.1830 - val_x_pred_categorical_loss: 1.1315 - val_x_pred_review_log_lambda_layer_loss: -45.8429 - val_x_pred_coordinates_loss: -2.7525
# Epoch 14/50
# 174565/174565 [==============================] - 10s 55us/step - loss: -109.3929 - x_pred_binary_loss: 0.4386 - x_pred_categorical_loss: 1.8957 - x_pred_review_log_lambda_layer_loss: -108.7344 - x_pred_coordinates_loss: -5.0760 - val_loss: -44.4285 - val_x_pred_binary_loss: 0.1817 - val_x_pred_categorical_loss: 1.2173 - val_x_pred_review_log_lambda_layer_loss: -45.7545 - val_x_pred_coordinates_loss: -1.9545
# Epoch 15/50
# 174565/174565 [==============================] - 10s 58us/step - loss: -109.5605 - x_pred_binary_loss: 0.4389 - x_pred_categorical_loss: 1.9108 - x_pred_review_log_lambda_layer_loss: -108.8013 - x_pred_coordinates_loss: -5.5578 - val_loss: -47.4611 - val_x_pred_binary_loss: 0.1663 - val_x_pred_categorical_loss: 1.6053 - val_x_pred_review_log_lambda_layer_loss: -45.9205 - val_x_pred_coordinates_loss: -5.6371
# Epoch 16/50
# 174565/174565 [==============================] - 11s 62us/step - loss: -109.6884 - x_pred_binary_loss: 0.4392 - x_pred_categorical_loss: 1.9213 - x_pred_review_log_lambda_layer_loss: -108.7764 - x_pred_coordinates_loss: -6.0642 - val_loss: -48.1702 - val_x_pred_binary_loss: 0.1577 - val_x_pred_categorical_loss: 1.8080 - val_x_pred_review_log_lambda_layer_loss: -45.3358 - val_x_pred_coordinates_loss: -7.3546
# Epoch 17/50
# 174565/174565 [==============================] - 10s 56us/step - loss: -109.8259 - x_pred_binary_loss: 0.4389 - x_pred_categorical_loss: 1.9266 - x_pred_review_log_lambda_layer_loss: -108.7811 - x_pred_coordinates_loss: -6.4353 - val_loss: -48.8911 - val_x_pred_binary_loss: 0.1597 - val_x_pred_categorical_loss: 1.6048 - val_x_pred_review_log_lambda_layer_loss: -45.6618 - val_x_pred_coordinates_loss: -7.8086
# Epoch 18/50
# 174565/174565 [==============================] - 10s 56us/step - loss: -110.0376 - x_pred_binary_loss: 0.4390 - x_pred_categorical_loss: 1.9287 - x_pred_review_log_lambda_layer_loss: -108.8130 - x_pred_coordinates_loss: -6.7961 - val_loss: -49.2719 - val_x_pred_binary_loss: 0.1607 - val_x_pred_categorical_loss: 1.6958 - val_x_pred_review_log_lambda_layer_loss: -45.6939 - val_x_pred_coordinates_loss: -8.2884
# Epoch 19/50
# 174565/174565 [==============================] - 9s 54us/step - loss: -110.2344 - x_pred_binary_loss: 0.4388 - x_pred_categorical_loss: 1.9287 - x_pred_review_log_lambda_layer_loss: -108.7561 - x_pred_coordinates_loss: -7.0638 - val_loss: -49.7036 - val_x_pred_binary_loss: 0.1667 - val_x_pred_categorical_loss: 1.5871 - val_x_pred_review_log_lambda_layer_loss: -46.0028 - val_x_pred_coordinates_loss: -8.2555
# Epoch 20/50
# 174565/174565 [==============================] - 10s 59us/step - loss: -110.3480 - x_pred_binary_loss: 0.4388 - x_pred_categorical_loss: 1.9273 - x_pred_review_log_lambda_layer_loss: -108.7886 - x_pred_coordinates_loss: -7.0748 - val_loss: -49.4113 - val_x_pred_binary_loss: 0.1639 - val_x_pred_categorical_loss: 1.6128 - val_x_pred_review_log_lambda_layer_loss: -46.0029 - val_x_pred_coordinates_loss: -8.0782
# Epoch 21/50
# 174565/174565 [==============================] - 16s 89us/step - loss: -110.4019 - x_pred_binary_loss: 0.4386 - x_pred_categorical_loss: 1.9270 - x_pred_review_log_lambda_layer_loss: -108.7745 - x_pred_coordinates_loss: -7.0874 - val_loss: -49.6037 - val_x_pred_binary_loss: 0.1701 - val_x_pred_categorical_loss: 1.6066 - val_x_pred_review_log_lambda_layer_loss: -45.9089 - val_x_pred_coordinates_loss: -8.3807
# Epoch 22/50
# 174565/174565 [==============================] - 10s 60us/step - loss: -110.3594 - x_pred_binary_loss: 0.4384 - x_pred_categorical_loss: 1.9274 - x_pred_review_log_lambda_layer_loss: -108.7082 - x_pred_coordinates_loss: -7.0805 - val_loss: -49.6750 - val_x_pred_binary_loss: 0.1593 - val_x_pred_categorical_loss: 1.5897 - val_x_pred_review_log_lambda_layer_loss: -45.7085 - val_x_pred_coordinates_loss: -8.5631
# Epoch 23/50
# 174565/174565 [==============================] - 9s 53us/step - loss: -110.4385 - x_pred_binary_loss: 0.4386 - x_pred_categorical_loss: 1.9263 - x_pred_review_log_lambda_layer_loss: -108.7598 - x_pred_coordinates_loss: -7.0968 - val_loss: -48.8167 - val_x_pred_binary_loss: 0.1662 - val_x_pred_categorical_loss: 1.6815 - val_x_pred_review_log_lambda_layer_loss: -44.9013 - val_x_pred_coordinates_loss: -8.6657
# Epoch 24/50
# 174565/174565 [==============================] - 10s 57us/step - loss: -110.4740 - x_pred_binary_loss: 0.4385 - x_pred_categorical_loss: 1.9261 - x_pred_review_log_lambda_layer_loss: -108.7804 - x_pred_coordinates_loss: -7.0801 - val_loss: -48.5142 - val_x_pred_binary_loss: 0.1813 - val_x_pred_categorical_loss: 1.7245 - val_x_pred_review_log_lambda_layer_loss: -45.6991 - val_x_pred_coordinates_loss: -7.5571
# Epoch 25/50
# 174565/174565 [==============================] - 10s 57us/step - loss: -110.4498 - x_pred_binary_loss: 0.4382 - x_pred_categorical_loss: 1.9263 - x_pred_review_log_lambda_layer_loss: -108.7774 - x_pred_coordinates_loss: -7.0590 - val_loss: -49.8985 - val_x_pred_binary_loss: 0.1483 - val_x_pred_categorical_loss: 1.5711 - val_x_pred_review_log_lambda_layer_loss: -45.9981 - val_x_pred_coordinates_loss: -8.4143
# Epoch 26/50
# 174565/174565 [==============================] - 9s 51us/step - loss: -110.0960 - x_pred_binary_loss: 0.4383 - x_pred_categorical_loss: 1.9259 - x_pred_review_log_lambda_layer_loss: -108.4139 - x_pred_coordinates_loss: -7.0582 - val_loss: -48.3779 - val_x_pred_binary_loss: 0.1638 - val_x_pred_categorical_loss: 1.4354 - val_x_pred_review_log_lambda_layer_loss: -44.5395 - val_x_pred_coordinates_loss: -8.2732
# Epoch 27/50
# 174565/174565 [==============================] - 9s 52us/step - loss: -110.3539 - x_pred_binary_loss: 0.4382 - x_pred_categorical_loss: 1.9270 - x_pred_review_log_lambda_layer_loss: -108.6915 - x_pred_coordinates_loss: -7.0612 - val_loss: -49.5505 - val_x_pred_binary_loss: 0.1597 - val_x_pred_categorical_loss: 1.6259 - val_x_pred_review_log_lambda_layer_loss: -45.8893 - val_x_pred_coordinates_loss: -8.4130
# Epoch 28/50
# 174565/174565 [==============================] - 9s 52us/step - loss: -110.3804 - x_pred_binary_loss: 0.4382 - x_pred_categorical_loss: 1.9256 - x_pred_review_log_lambda_layer_loss: -108.7104 - x_pred_coordinates_loss: -7.0731 - val_loss: -47.5907 - val_x_pred_binary_loss: 0.1550 - val_x_pred_categorical_loss: 1.4474 - val_x_pred_review_log_lambda_layer_loss: -43.7332 - val_x_pred_coordinates_loss: -8.4771
# Epoch 29/50
# 174565/174565 [==============================] - 10s 58us/step - loss: -110.4195 - x_pred_binary_loss: 0.4382 - x_pred_categorical_loss: 1.9248 - x_pred_review_log_lambda_layer_loss: -108.7369 - x_pred_coordinates_loss: -7.0759 - val_loss: -48.6045 - val_x_pred_binary_loss: 0.1699 - val_x_pred_categorical_loss: 1.6111 - val_x_pred_review_log_lambda_layer_loss: -45.4304 - val_x_pred_coordinates_loss: -7.9911
# Epoch 30/50
# 174565/174565 [==============================] - 13s 75us/step - loss: -110.3614 - x_pred_binary_loss: 0.4383 - x_pred_categorical_loss: 1.9263 - x_pred_review_log_lambda_layer_loss: -108.7117 - x_pred_coordinates_loss: -7.0657 - val_loss: -49.1732 - val_x_pred_binary_loss: 0.1719 - val_x_pred_categorical_loss: 1.6154 - val_x_pred_review_log_lambda_layer_loss: -45.5716 - val_x_pred_coordinates_loss: -8.3986
# Epoch 31/50
# 174565/174565 [==============================] - 9s 49us/step - loss: -110.3818 - x_pred_binary_loss: 0.4384 - x_pred_categorical_loss: 1.9252 - x_pred_review_log_lambda_layer_loss: -108.6863 - x_pred_coordinates_loss: -7.0793 - val_loss: -49.0274 - val_x_pred_binary_loss: 0.1693 - val_x_pred_categorical_loss: 1.5870 - val_x_pred_review_log_lambda_layer_loss: -45.7407 - val_x_pred_coordinates_loss: -7.9237
# Epoch 32/50
# 174565/174565 [==============================] - 7s 42us/step - loss: -110.3258 - x_pred_binary_loss: 0.4382 - x_pred_categorical_loss: 1.9263 - x_pred_review_log_lambda_layer_loss: -108.6686 - x_pred_coordinates_loss: -7.0925 - val_loss: -48.9191 - val_x_pred_binary_loss: 0.1584 - val_x_pred_categorical_loss: 1.6687 - val_x_pred_review_log_lambda_layer_loss: -45.7692 - val_x_pred_coordinates_loss: -7.8559
# Epoch 33/50
# 174565/174565 [==============================] - 8s 43us/step - loss: -110.3790 - x_pred_binary_loss: 0.4383 - x_pred_categorical_loss: 1.9265 - x_pred_review_log_lambda_layer_loss: -108.6953 - x_pred_coordinates_loss: -7.0752 - val_loss: -49.5240 - val_x_pred_binary_loss: 0.1593 - val_x_pred_categorical_loss: 1.5114 - val_x_pred_review_log_lambda_layer_loss: -45.5051 - val_x_pred_coordinates_loss: -8.5505
# Epoch 34/50
# 174565/174565 [==============================] - 9s 51us/step - loss: -110.3030 - x_pred_binary_loss: 0.4384 - x_pred_categorical_loss: 1.9269 - x_pred_review_log_lambda_layer_loss: -108.6211 - x_pred_coordinates_loss: -7.0869 - val_loss: -49.1813 - val_x_pred_binary_loss: 0.1574 - val_x_pred_categorical_loss: 1.4783 - val_x_pred_review_log_lambda_layer_loss: -45.5201 - val_x_pred_coordinates_loss: -8.3586
# Epoch 35/50
# 174565/174565 [==============================] - 7s 39us/step - loss: -110.3445 - x_pred_binary_loss: 0.4383 - x_pred_categorical_loss: 1.9259 - x_pred_review_log_lambda_layer_loss: -108.6677 - x_pred_coordinates_loss: -7.0723 - val_loss: -48.4936 - val_x_pred_binary_loss: 0.1659 - val_x_pred_categorical_loss: 1.5937 - val_x_pred_review_log_lambda_layer_loss: -45.1424 - val_x_pred_coordinates_loss: -8.0455
# Epoch 36/50
# 174565/174565 [==============================] - 11s 63us/step - loss: -110.3139 - x_pred_binary_loss: 0.4383 - x_pred_categorical_loss: 1.9261 - x_pred_review_log_lambda_layer_loss: -108.7185 - x_pred_coordinates_loss: -7.0641 - val_loss: -48.8147 - val_x_pred_binary_loss: 0.1656 - val_x_pred_categorical_loss: 1.6426 - val_x_pred_review_log_lambda_layer_loss: -44.9200 - val_x_pred_coordinates_loss: -8.6146
# Epoch 37/50
# 174565/174565 [==============================] - 11s 62us/step - loss: -110.3556 - x_pred_binary_loss: 0.4383 - x_pred_categorical_loss: 1.9243 - x_pred_review_log_lambda_layer_loss: -108.6881 - x_pred_coordinates_loss: -7.0525 - val_loss: -49.0141 - val_x_pred_binary_loss: 0.1748 - val_x_pred_categorical_loss: 1.6285 - val_x_pred_review_log_lambda_layer_loss: -45.9884 - val_x_pred_coordinates_loss: -7.8451
# Epoch 38/50
# 174565/174565 [==============================] - 12s 68us/step - loss: -110.3961 - x_pred_binary_loss: 0.4384 - x_pred_categorical_loss: 1.9232 - x_pred_review_log_lambda_layer_loss: -108.7162 - x_pred_coordinates_loss: -7.0572 - val_loss: -49.6655 - val_x_pred_binary_loss: 0.1706 - val_x_pred_categorical_loss: 1.5184 - val_x_pred_review_log_lambda_layer_loss: -45.9355 - val_x_pred_coordinates_loss: -8.3832
# Epoch 39/50
# 174565/174565 [==============================] - 10s 57us/step - loss: -110.3684 - x_pred_binary_loss: 0.4383 - x_pred_categorical_loss: 1.9223 - x_pred_review_log_lambda_layer_loss: -108.6806 - x_pred_coordinates_loss: -7.0644 - val_loss: -49.8758 - val_x_pred_binary_loss: 0.1711 - val_x_pred_categorical_loss: 1.5735 - val_x_pred_review_log_lambda_layer_loss: -45.9894 - val_x_pred_coordinates_loss: -8.5838
# Epoch 40/50
# 174565/174565 [==============================] - 12s 66us/step - loss: -110.4182 - x_pred_binary_loss: 0.4381 - x_pred_categorical_loss: 1.9219 - x_pred_review_log_lambda_layer_loss: -108.7398 - x_pred_coordinates_loss: -7.0726 - val_loss: -49.9170 - val_x_pred_binary_loss: 0.1686 - val_x_pred_categorical_loss: 1.5062 - val_x_pred_review_log_lambda_layer_loss: -45.9846 - val_x_pred_coordinates_loss: -8.5028
# Epoch 41/50
# 174565/174565 [==============================] - 10s 55us/step - loss: -110.2840 - x_pred_binary_loss: 0.4382 - x_pred_categorical_loss: 1.9216 - x_pred_review_log_lambda_layer_loss: -108.6040 - x_pred_coordinates_loss: -7.0648 - val_loss: -48.6572 - val_x_pred_binary_loss: 0.1584 - val_x_pred_categorical_loss: 1.5368 - val_x_pred_review_log_lambda_layer_loss: -44.8251 - val_x_pred_coordinates_loss: -8.3685
# Epoch 42/50
# 174565/174565 [==============================] - 10s 55us/step - loss: -110.3722 - x_pred_binary_loss: 0.4383 - x_pred_categorical_loss: 1.9220 - x_pred_review_log_lambda_layer_loss: -108.6934 - x_pred_coordinates_loss: -7.0673 - val_loss: -50.0397 - val_x_pred_binary_loss: 0.1714 - val_x_pred_categorical_loss: 1.5112 - val_x_pred_review_log_lambda_layer_loss: -46.0026 - val_x_pred_coordinates_loss: -8.6192
# Epoch 43/50
# 174565/174565 [==============================] - 13s 73us/step - loss: -110.4346 - x_pred_binary_loss: 0.4381 - x_pred_categorical_loss: 1.9259 - x_pred_review_log_lambda_layer_loss: -108.7549 - x_pred_coordinates_loss: -7.0820 - val_loss: -49.7394 - val_x_pred_binary_loss: 0.1673 - val_x_pred_categorical_loss: 1.5387 - val_x_pred_review_log_lambda_layer_loss: -45.6567 - val_x_pred_coordinates_loss: -8.6575
# Epoch 44/50
# 174565/174565 [==============================] - 17s 98us/step - loss: -110.3721 - x_pred_binary_loss: 0.4379 - x_pred_categorical_loss: 1.9266 - x_pred_review_log_lambda_layer_loss: -108.6791 - x_pred_coordinates_loss: -7.0790 - val_loss: -49.5812 - val_x_pred_binary_loss: 0.1708 - val_x_pred_categorical_loss: 1.5511 - val_x_pred_review_log_lambda_layer_loss: -46.0006 - val_x_pred_coordinates_loss: -8.4027
# Epoch 45/50
# 174565/174565 [==============================] - 16s 92us/step - loss: -110.3893 - x_pred_binary_loss: 0.4378 - x_pred_categorical_loss: 1.9267 - x_pred_review_log_lambda_layer_loss: -108.7246 - x_pred_coordinates_loss: -7.0589 - val_loss: -48.8921 - val_x_pred_binary_loss: 0.1701 - val_x_pred_categorical_loss: 1.5875 - val_x_pred_review_log_lambda_layer_loss: -45.8698 - val_x_pred_coordinates_loss: -7.8861
# Epoch 46/50
# 174565/174565 [==============================] - 12s 67us/step - loss: -110.4049 - x_pred_binary_loss: 0.4376 - x_pred_categorical_loss: 1.9259 - x_pred_review_log_lambda_layer_loss: -108.7461 - x_pred_coordinates_loss: -7.0475 - val_loss: -49.0617 - val_x_pred_binary_loss: 0.1795 - val_x_pred_categorical_loss: 1.6029 - val_x_pred_review_log_lambda_layer_loss: -45.7134 - val_x_pred_coordinates_loss: -8.2473
# Epoch 47/50
# 174565/174565 [==============================] - 14s 79us/step - loss: -110.3826 - x_pred_binary_loss: 0.4375 - x_pred_categorical_loss: 1.9255 - x_pred_review_log_lambda_layer_loss: -108.7545 - x_pred_coordinates_loss: -7.0427 - val_loss: -49.0088 - val_x_pred_binary_loss: 0.1713 - val_x_pred_categorical_loss: 1.6103 - val_x_pred_review_log_lambda_layer_loss: -45.5556 - val_x_pred_coordinates_loss: -8.3665
# Epoch 48/50
# 174565/174565 [==============================] - 13s 72us/step - loss: -110.4369 - x_pred_binary_loss: 0.4374 - x_pred_categorical_loss: 1.9238 - x_pred_review_log_lambda_layer_loss: -108.7949 - x_pred_coordinates_loss: -7.0396 - val_loss: -48.6953 - val_x_pred_binary_loss: 0.1716 - val_x_pred_categorical_loss: 1.4862 - val_x_pred_review_log_lambda_layer_loss: -45.2932 - val_x_pred_coordinates_loss: -8.1436
# Epoch 49/50
# 174565/174565 [==============================] - 13s 77us/step - loss: -110.4358 - x_pred_binary_loss: 0.4375 - x_pred_categorical_loss: 1.9233 - x_pred_review_log_lambda_layer_loss: -108.7288 - x_pred_coordinates_loss: -7.0616 - val_loss: -49.2174 - val_x_pred_binary_loss: 0.1750 - val_x_pred_categorical_loss: 1.5648 - val_x_pred_review_log_lambda_layer_loss: -45.9938 - val_x_pred_coordinates_loss: -7.9270
# Epoch 50/50
# 174565/174565 [==============================] - 14s 80us/step - loss: -110.4043 - x_pred_binary_loss: 0.4375 - x_pred_categorical_loss: 1.9232 - x_pred_review_log_lambda_layer_loss: -108.7032 - x_pred_coordinates_loss: -7.0426 - val_loss: -48.7700 - val_x_pred_binary_loss: 0.1975 - val_x_pred_categorical_loss: 1.6946 - val_x_pred_review_log_lambda_layer_loss: -45.2290 - val_x_pred_coordinates_loss: -8.3133

# %% [markdown]
# ## Building the Decoder

# %%
decode_input = Input(shape=(latent_dim, ), name = 'decode_input')
decode_layer_1 = decode_1(decode_input)
decode_layer_2 = decode_2(decode_layer_1)

x_pred_coordinates_mu = x_pred_coordinates_mu_layer(decode_layer_2)
x_pred_coordinates_log_var = x_pred_coordinates_log_var_layer(decode_layer_2)
decode_x_pred_coordinates = x_pred_coordinates_layer([x_pred_coordinates_mu, x_pred_coordinates_log_var])

decode_x_pred_review = x_pred_review_log_lambda_layer(decode_layer_2)

decode_x_pred_binary = x_pred_binary_layer(decode_layer_2) # binary cross entropy
decode_x_pred_categorical = x_pred_categorical_layer(decode_layer_2) # categorical cross entropy


decoder = Model(decode_input, [decode_x_pred_coordinates, decode_x_pred_review, decode_x_pred_categorical, decode_x_pred_binary])

# %%
SVG(model_to_dot(decoder, show_shapes=True)
    .create(prog='dot', format='svg'))

# %% [markdown]
# ### Saving the Models and Metadata
# #### Saving Models (Actually, only the decoder matter)

# %%
model_json = vae.to_json()
with open("./model/vae_full_model.json", "w") as json_file:
    json_file.write(model_json)
vae.save_weights("./model/vae_full_model.h5")
print("Saved model to disk")

encoder = Model(x, [z_mu, z_log_var])
model_json = encoder.to_json()
with open("./model/vae_encoder.json", "w") as json_file:
    json_file.write(model_json)
encoder.save_weights("./model/vae_encoder.h5")
print("Saved model to disk")

model_json = decoder.to_json()
with open("./model/vae_decoder.json", "w") as json_file:
    json_file.write(model_json)
decoder.save_weights("./model/vae_decoder.h5")
print("Saved model to disk")
# Out:
# Saved model to disk
# Saved model to disk
# Saved model to disk

# %% [markdown]
# #### Generating and Saving Metadata

# %%
vae_sample = train_dataset[np.random.choice(len(train_dataset), size=10000, replace=False)]
vae_sample_mu, vae_sample_log_var = encoder.predict(vae_sample, batch_size=batch_size)
np.save('./model/sample_mu.npy', vae_sample_mu)
np.save('./model/sample_log_var.npy', vae_sample_log_var)

# %% [markdown]
# ### Generating some Samples for Testing
# #### Functions for data generation

# %%
reverse_categorical_map = {0:0, 1:0.5, 2:1, 3:1.5, 4:2, 5:2.5, 6:3, 7:3.5, 8:4, 9:4.5, 10:5}
def sample(model, input_mu, input_log_var, samples_per_z=1):
    multiplied_input_mu = np.repeat(input_mu, samples_per_z, axis=0)
    multiplied_input_log_var = np.repeat(input_log_var, samples_per_z, axis=0)
    eps = np.random.normal(size=(multiplied_input_mu.shape[0], latent_dim))
    z = reparameterize(multiplied_input_mu, multiplied_input_log_var, eps)
    predictions = model.predict(z, batch_size = None, steps = 1)
    return reconstruct(predictions)
    
def reconstruct(predictions):
    coordinates, review, categorical, binary = predictions
    mu, log_var = np.split(coordinates, indices_or_sections = 2,axis = 1)
    eps = np.random.normal(size=mu.shape)
    
    ## coordinates handled here
    coordinates_data = reparameterize(mu, log_var, eps)
    print(coordinates_data)
    for i, c in enumerate(coordinates_data):
        if c[0] > 1.0:
            coordinates_data[i][0]=1.0
        if c[0] < 0.0:
            coordinates_data[i][0]=0.0
        if c[1] > 1.0:
            coordinates_data[i][1]=1.0
        if c[1] < 0.0:
            coordinates_data[i][1]=0.0
        coordinates_data[i][0] = (coordinates_data[i][0]*360)-180
        coordinates_data[i][1] = (coordinates_data[i][1]*360)-180
    
    ## review_count handled here
    exp_log_review = np.exp(review)
    review_data = np.random.poisson(lam=exp_log_review, size = review.shape)
    for i, r in enumerate(review_data):
        if r[0] < 0:
            review_data[i][0] = 0
        review_data[i][0] = float(int(review_data[i][0]))
    
    categorical = np.apply_along_axis(lambda t : np.random.multinomial(1,t), -1, categorical)
    categorical = np.apply_along_axis(lambda t : np.argmax(t), -1, categorical)
    categorical = np.expand_dims(categorical, axis = -1)
    categorical_data = np.apply_along_axis(lambda t : float(reverse_categorical_map[t[0]]), -1, categorical)
    categorical_data = np.expand_dims(categorical_data, axis = -1)
    binary_data = np.apply_along_axis(lambda t: np.random.binomial(1, t), -1, binary)
#     coordinates, reviews = np.split(continuous_data, indices_or_sections=[2], axis = 1)
    return np.concatenate([coordinates_data, categorical_data, review_data, binary_data], axis = 1)
    

def reparameterize(input_mu, input_log_var, eps):
    sigma = np.exp(0.5*input_log_var)
    return eps*sigma + input_mu

# %% [markdown]
# ### Generating Samples
# Make use of the funciton sample to generate samples with our model. U need to supply an array of mu and their respective log var in a separate array to do that.

# %%
vae_samples = sample(decoder, vae_sample_mu, vae_sample_log_var)

# Saving the samples in a separate file
file_name = './samples/vae_5_sample_' + str(len(vae_samples)) + '.csv'
np.savetxt(file_name, vae_samples, delimiter = ',', header='latitude,longitude,stars,review_count,is_open')
# Out:
# [[0.60928821 0.27897382]
#  [0.60917892 0.26443285]
#  [0.63049849 0.48850918]
#  ...
#  [0.59481374 0.18468079]
#  [0.60034293 0.28040929]
#  [0.59377668 0.18336699]]

# %%
vae_samples[1:10]
# Out:
# array([[  39.30440957,  -84.80417413,    5.        ,    4.        ,
#            0.        ],
#        [  46.97945697,   -4.13669446,    4.        ,   43.        ,
#            1.        ],
#        [  44.92644616,  -77.99076355,    2.5       ,    5.        ,
#            1.        ],
#        [  46.01079028,  -80.67963419,    2.        ,    9.        ,
#            1.        ],
#        [  40.55983196,  -81.79675486,    2.5       ,    3.        ,
#            0.        ],
#        [  53.45926494,   -4.92361477,    4.5       ,    7.        ,
#            1.        ],
#        [  33.21981003, -111.66786637,    4.        ,   36.        ,
#            1.        ],
#        [  34.02537638,  -81.42034626,    4.5       ,    5.        ,
#            1.        ],
#        [  46.64157844,  -80.3762306 ,    4.5       ,   24.        ,
#            1.        ]])
