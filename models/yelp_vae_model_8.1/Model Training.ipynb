# %% [markdown]
# # Model Training
# In this notebook, we will train our VAE model. This involves:
#
# 1. Encoder
# 2. Decoder
# 3. Full Model

# %% [markdown]
# ## Importing Packages
# We will be using Keras to build and train our VAE

# %%
from __future__ import absolute_import, division, print_function, unicode_literals
# %matplotlib notebook
import tensorflow as tf

import os
import time
import numpy as np
import glob
import matplotlib.pyplot as plt
import PIL
import imageio
import h5py

# import keras
from tensorflow.keras import backend as K
from tensorflow.keras.layers import Input, Dense, Lambda, Layer, Add, Multiply, Concatenate
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import model_from_json
import mdn

import tensorflow.compat.v2 as tf
tf.enable_v2_behavior()

import tensorflow_probability as tfp

from IPython import display
import numpy as np
import pandas as pd
from sklearn import preprocessing
from pickle import dump, load

from matplotlib.ticker import FormatStrFormatter
from IPython.display import SVG

# %% [markdown]
# ## Definition of Constants
# Hyper parameters and constants will all be located here for ease of adjustments

# %%
categorical_dim = 11
categorical_map = {0:0, 0.5:1, 1: 2, 1.5:3, 2:4, 2.5:5, 3:6, 3.5:7, 4:8, 4.5:9, 5:10}
reverse_categorical_map = {0:0, 1:0.5, 2:1, 3:1.5, 4:2, 5:2.5, 6:3, 7:3.5, 8:4, 9:4.5, 10:5}
continuous_dim = 3
binary_dim = 1
original_dim = binary_dim + continuous_dim + categorical_dim
intermediate_dim_1 = 50
intermediate_dim_2 = 50
latent_dim = 4
batch_size = 100
epochs = 50
epsilon_std = 1.0

## Constants for the Mixture layer
N_HIDDEN = 15  # number of hidden units in the Dense layer
N_MIXES = 10  # number of mixture components
OUTPUT_DIMS = 2  # number of real-values predicted by each mixture component

# Model File Paths
full_model_file = "./model/vae_full_model.json"
full_model_weights = "./model/vae_full_model.h5"
encoder_file = "./model/vae_encoder.json"
encoder_weights = "./model/vae_encoder.h5"
decoder_file = './model/vae_decoder.json'
decoder_weights = './model/vae_decoder.h5'
z_meta_file = './model/z_meta.npy'

# %% [markdown]
# ## Building the Model
# We have to write our own custom layer and custom loss function as these are not supported on Keras natively. There are a few things to be done:
#
# 1. Custom KLDivergence Layer
# 2. Custom Loss Functions
# 3. Building the Model

# %% [markdown]
# ### Custom Loss Functions
# As the yelp dataset contains binary, categorical as well as continuous data, we will build 3 custom loss functions.
#
# #### Binary Loss Function

# %%
def binary_loss(y_true, y_pred):
	# input dimension is (batchsize, 1)
    return K.binary_crossentropy(y_true, y_pred) # the dimension of return value is (batchsize , 1)

# %% [markdown]
# #### Categorical Loss Function

# %%
def categorical_loss(y_true, y_pred):
	# input dimension is (batchsize, number of categories)
  return K.categorical_crossentropy(y_true, y_pred) # the dimension of return value is (batchsize , 1)

# %% [markdown]
# #### Continuous Loss Function

# %%
def log_normal_pdf(sample, mean, logvar, raxis=1):
  log2pi = tf.math.log(2. * np.pi)
  return tf.reduce_sum(
      -.5 * ((sample - mean) ** 2. * tf.exp(-logvar) + logvar + log2pi),
      axis=raxis) # return a tensor of shape (batch_size, 1)

# Added a postfix because now we also have poisson as a distribution
def continuous_loss_gaussian(y_true, y_pred):
	# need to return log probability for continuous gaussian loss.
	# will get a (batchsize, 6 continuous variable input) where 3 of the 6 represents mu and the others logvar
	# y_true will be (batchsize, 3)
  mu, logvar = tf.split(y_pred, num_or_size_splits = 2, axis = 1)
  return -1 * log_normal_pdf(y_true, mu, logvar) 

def continuous_loss_poisson(y_true, y_pred):
	# need to return log probability for continuous poisson loss.
	# will get a (batchsize, 6 continuous variable input) where 3 of the 6 represents mu and the others logvar
	# y_true will be (batchsize, 3)
  return tf.nn.log_poisson_loss(y_true, y_pred)

# %% [markdown]
# ### Model Architecture
# - tanh/sigmoid is used because Relu resulted in loss going to infinity
# - going to delete review_log_var and review_mu since we are trying out the Poission distribution which only takes 1 parameter.

# %%
tfk = tf.keras
tfkl = tf.keras.layers
tfpl = tfp.layers
tfd = tfp.distributions


input_shape = (original_dim,)
prior = tfd.Independent(tfd.Normal(loc=tf.zeros(latent_dim), scale=1), reinterpreted_batch_ndims=1)

## Encoder
encoder = tfk.Sequential([
    tfkl.InputLayer(input_shape=input_shape, name = 'input_x'),
    tfkl.Dense(intermediate_dim_1, activation='tanh', name='hidden_enc_1'),
    tfkl.Dense(intermediate_dim_2, activation='tanh', name='hidden_enc_2'),
    tfkl.Dense(tfpl.MultivariateNormalTriL.params_size(latent_dim), activation=None, name = 'z_probability_distribution'),
])

sampler = tfk.Sequential([
    tfkl.InputLayer(input_shape=(tfpl.MultivariateNormalTriL.params_size(latent_dim), ), name = 'input_z_params'),
    tfpl.MultivariateNormalTriL( latent_dim, name = 'sample_layer'),
    tfpl.KLDivergenceAddLoss(
        tfd.MultivariateNormalDiag(loc=tf.zeros(latent_dim))),
])

decode_1 = tfkl.Dense(intermediate_dim_2, activation='tanh', name='hidden_dec_2')
h_dec = decode_1(sampler(encoder.outputs[0]))

decode_2 = tfkl.Dense(intermediate_dim_1, activation='tanh', name='hidden_dec_1')
h_dec = decode_2(h_dec)

x_pred_coordinates_mdn_layer = mdn.MDN(OUTPUT_DIMS, N_MIXES, name = 'x_pred_coordinates_mdn_layer')
x_pred_coordinates = x_pred_coordinates_mdn_layer(h_dec)


## This outputs the lambda require for poisson distribution and thats all that we need
x_pred_review_log_lambda_layer = tfkl.Dense(1,name = 'x_pred_review_log_lambda_layer')
x_pred_review = x_pred_review_log_lambda_layer(h_dec)

x_pred_binary_layer = tfkl.Dense(binary_dim, activation='sigmoid', name='x_pred_binary')
x_pred_binary = x_pred_binary_layer(h_dec) # binary cross entropy

x_pred_categorical_layer = tfkl.Dense(categorical_dim, activation='softmax', name='x_pred_categorical')
x_pred_categorical = x_pred_categorical_layer(h_dec) # categorical cross entropy

vae = tfk.Model(inputs=encoder.inputs, outputs=[x_pred_binary, x_pred_categorical, x_pred_review, x_pred_coordinates])
# Out:
# WARNING:tensorflow:From /Users/tanliangwei/Desktop/fyp_repo/tf_1/lib/python3.6/site-packages/tensorflow_core/python/ops/linalg/linear_operator_lower_triangular.py:158: calling LinearOperator.__init__ (from tensorflow.python.ops.linalg.linear_operator) with graph_parents is deprecated and will be removed in a future version.
# Instructions for updating:
# Do not pass `graph_parents`.  They will  no longer be used.

# %% [markdown]
# ### Visualizing the Model

# %%
tf.keras.utils.plot_model(
    vae, to_file='./description/vae_full_model.png', show_shapes=True, show_layer_names=True,
    rankdir='TB', expand_nested=False, dpi=96
)

# %% [markdown]
# ### Compiling Model and Setting Parameters

# %%
optimizer = tf.keras.optimizers.Adam(lr=0.0001)
vae.compile(optimizer=optimizer, loss=[binary_loss, categorical_loss, continuous_loss_poisson, mdn.get_mixture_loss_func(OUTPUT_DIMS,N_MIXES)], loss_weights=[1, 1, 1, 1])

# %% [markdown]
# ### Alternatively, you can upload the weights which was trained during the previous time

# %%
vae.load_weights(full_model_weights)

# %%
vae.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_x (InputLayer)            [(None, 15)]         0
# __________________________________________________________________________________________________
# hidden_enc_1 (Dense)            (None, 50)           800         input_x[0][0]
# __________________________________________________________________________________________________
# hidden_enc_2 (Dense)            (None, 50)           2550        hidden_enc_1[0][0]
# __________________________________________________________________________________________________
# z_probability_distribution (Den (None, 14)           714         hidden_enc_2[0][0]
# __________________________________________________________________________________________________
# sequential_1 (Sequential)       (None, 4)            0           z_probability_distribution[0][0]
# __________________________________________________________________________________________________
# hidden_dec_2 (Dense)            (None, 50)           250         sequential_1[1][0]
# __________________________________________________________________________________________________
# hidden_dec_1 (Dense)            (None, 50)           2550        hidden_dec_2[0][0]
# __________________________________________________________________________________________________
# x_pred_binary (Dense)           (None, 1)            51          hidden_dec_1[0][0]
# __________________________________________________________________________________________________
# x_pred_categorical (Dense)      (None, 11)           561         hidden_dec_1[0][0]
# __________________________________________________________________________________________________
# x_pred_review_log_lambda_layer  (None, 1)            51          hidden_dec_1[0][0]
# __________________________________________________________________________________________________
# x_pred_coordinates_mdn_layer (M (None, 50)           2550        hidden_dec_1[0][0]
# ==================================================================================================
# Total params: 10,077
# Trainable params: 10,077
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# ## Data Loading and Preprocessing

# %%
dataset = np.genfromtxt('../../datasets/yelp_business.csv',delimiter=',',skip_header=1)
dataset = dataset[~np.isnan(dataset).any(axis=1)]
test_set, train_set = np.split(dataset,[1], axis = 0)

def format_data(dataset, scaler_to_use=None ,save_scaler=True):
    # handling the categorical variables
    coordinates, ratings, reviews, is_opens = np.split(dataset, [2, 3, 4], axis = 1)
    one_hot_array = np.zeros((ratings.shape[0], categorical_dim))

    for i, r in enumerate(ratings):
        one_hot_array[i][categorical_map[r[0]]] = 1
    
    # handling coordinates
    if scaler_to_use is None:
        scaler_to_use = preprocessing.StandardScaler()
        scaler_to_use.fit(coordinates)
    
    coordinates = scaler_to_use.transform(coordinates)
    
    if save_scaler:
        dump(scaler_to_use, open('./model/standard_scaler.pkl', 'wb'))
    
    dataset = np.concatenate((coordinates, reviews, is_opens, one_hot_array), axis = 1)

    # creating the labels
    coordinates_labels = coordinates
    review_labels = reviews
    categorical_labels = one_hot_array
    binary_labels = is_opens
    return dataset, coordinates_labels, review_labels, categorical_labels, binary_labels

train_dataset, train_coordinates_labels, train_review_labels, train_categorical_labels, train_binary_labels = format_data(train_set)

## Open scaler
scaler = load(open('./model/standard_scaler.pkl', 'rb'))
test_dataset, test_coordinates_labels, test_review_labels, test_categorical_labels, test_binary_labels = format_data(test_set, scaler, False)

# %% [markdown]
# ### Distribution of Review_Count

# %%
import matplotlib.pyplot as plt
plt.hist(train_review_labels, 1000)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ## Training the Model

# %%
vae.fit(train_dataset , [train_binary_labels, train_categorical_labels, train_review_labels, train_coordinates_labels], shuffle = True, epochs = epochs, batch_size = batch_size, validation_data=(test_dataset , [test_binary_labels, test_categorical_labels, test_review_labels, test_coordinates_labels]))
# Out:
# Train on 174565 samples, validate on 1 samples
# Epoch 1/50
# 174565/174565 [==============================] - 21s 121us/sample - loss: -91.9619 - x_pred_binary_loss: 0.3109 - x_pred_categorical_loss: 1.8149 - x_pred_review_log_lambda_layer_loss: -108.7915 - x_pred_coordinates_mdn_layer_loss: -6.9418 - val_loss: -37.4613 - val_x_pred_binary_loss: 0.0521 - val_x_pred_categorical_loss: 1.6074 - val_x_pred_review_log_lambda_layer_loss: -45.8997 - val_x_pred_coordinates_mdn_layer_loss: -7.1700
# Epoch 2/50
# 174565/174565 [==============================] - 15s 84us/sample - loss: -101.6043 - x_pred_binary_loss: 0.4159 - x_pred_categorical_loss: 1.9246 - x_pred_review_log_lambda_layer_loss: -108.6990 - x_pred_coordinates_mdn_layer_loss: -5.0008 - val_loss: -40.0906 - val_x_pred_binary_loss: 0.2753 - val_x_pred_categorical_loss: 2.1524 - val_x_pred_review_log_lambda_layer_loss: -45.4422 - val_x_pred_coordinates_mdn_layer_loss: -5.8806
# Epoch 3/50
# 174565/174565 [==============================] - 15s 83us/sample - loss: -102.9125 - x_pred_binary_loss: 0.4085 - x_pred_categorical_loss: 1.9169 - x_pred_review_log_lambda_layer_loss: -108.7546 - x_pred_coordinates_mdn_layer_loss: -4.2831 - val_loss: -41.1695 - val_x_pred_binary_loss: 0.0433 - val_x_pred_categorical_loss: 1.6059 - val_x_pred_review_log_lambda_layer_loss: -45.5327 - val_x_pred_coordinates_mdn_layer_loss: -4.3892
# Epoch 4/50
# 174565/174565 [==============================] - 13s 76us/sample - loss: -103.6134 - x_pred_binary_loss: 0.3976 - x_pred_categorical_loss: 1.9030 - x_pred_review_log_lambda_layer_loss: -108.7740 - x_pred_coordinates_mdn_layer_loss: -4.2505 - val_loss: -42.0732 - val_x_pred_binary_loss: 0.1550 - val_x_pred_categorical_loss: 1.7859 - val_x_pred_review_log_lambda_layer_loss: -45.8605 - val_x_pred_coordinates_mdn_layer_loss: -5.2407
# Epoch 5/50
# 174565/174565 [==============================] - 11s 62us/sample - loss: -104.2070 - x_pred_binary_loss: 0.3921 - x_pred_categorical_loss: 1.8956 - x_pred_review_log_lambda_layer_loss: -108.8329 - x_pred_coordinates_mdn_layer_loss: -4.2672 - val_loss: -43.2266 - val_x_pred_binary_loss: 0.3582 - val_x_pred_categorical_loss: 1.9933 - val_x_pred_review_log_lambda_layer_loss: -45.9965 - val_x_pred_coordinates_mdn_layer_loss: -5.9151
# Epoch 6/50
# 174565/174565 [==============================] - 14s 82us/sample - loss: -104.6100 - x_pred_binary_loss: 0.3933 - x_pred_categorical_loss: 1.9001 - x_pred_review_log_lambda_layer_loss: -108.8228 - x_pred_coordinates_mdn_layer_loss: -4.2903 - val_loss: -42.2134 - val_x_pred_binary_loss: 0.2481 - val_x_pred_categorical_loss: 1.7711 - val_x_pred_review_log_lambda_layer_loss: -45.5385 - val_x_pred_coordinates_mdn_layer_loss: -5.7002
# Epoch 7/50
# 174565/174565 [==============================] - 17s 99us/sample - loss: -104.8796 - x_pred_binary_loss: 0.3998 - x_pred_categorical_loss: 1.9078 - x_pred_review_log_lambda_layer_loss: -108.8266 - x_pred_coordinates_mdn_layer_loss: -4.3303 - val_loss: -42.8259 - val_x_pred_binary_loss: 0.0825 - val_x_pred_categorical_loss: 1.4760 - val_x_pred_review_log_lambda_layer_loss: -45.9834 - val_x_pred_coordinates_mdn_layer_loss: -5.9954
# Epoch 8/50
# 174565/174565 [==============================] - 13s 77us/sample - loss: -105.1791 - x_pred_binary_loss: 0.4036 - x_pred_categorical_loss: 1.9139 - x_pred_review_log_lambda_layer_loss: -108.7778 - x_pred_coordinates_mdn_layer_loss: -4.3616 - val_loss: -44.6809 - val_x_pred_binary_loss: 0.0737 - val_x_pred_categorical_loss: 1.5273 - val_x_pred_review_log_lambda_layer_loss: -44.8756 - val_x_pred_coordinates_mdn_layer_loss: -7.2969
# Epoch 9/50
# 174565/174565 [==============================] - 16s 94us/sample - loss: -105.5183 - x_pred_binary_loss: 0.4095 - x_pred_categorical_loss: 1.9163 - x_pred_review_log_lambda_layer_loss: -108.8025 - x_pred_coordinates_mdn_layer_loss: -4.4697 - val_loss: -44.1515 - val_x_pred_binary_loss: 0.1049 - val_x_pred_categorical_loss: 1.4673 - val_x_pred_review_log_lambda_layer_loss: -44.6180 - val_x_pred_coordinates_mdn_layer_loss: -6.3041
# Epoch 10/50
# 174565/174565 [==============================] - 19s 107us/sample - loss: -105.7982 - x_pred_binary_loss: 0.4131 - x_pred_categorical_loss: 1.9193 - x_pred_review_log_lambda_layer_loss: -108.8075 - x_pred_coordinates_mdn_layer_loss: -4.5244 - val_loss: -43.3736 - val_x_pred_binary_loss: 0.1730 - val_x_pred_categorical_loss: 1.6640 - val_x_pred_review_log_lambda_layer_loss: -45.8684 - val_x_pred_coordinates_mdn_layer_loss: -5.2881ed_binary_loss: 0.4120 - x_pred_categorical_loss: 1.9176 - x_pred_review_log_lambda_la - ETA: 8s - los
# Epoch 11/50
# 174565/174565 [==============================] - ETA: 0s - loss: -106.0427 - x_pred_binary_loss: 0.4153 - x_pred_categorical_loss: 1.9218 - x_pred_review_log_lambda_layer_loss: -108.8494 - x_pred_coordinates_mdn_layer_loss: -4.578 - 11s 62us/sample - loss: -106.0257 - x_pred_binary_loss: 0.4152 - x_pred_categorical_loss: 1.9219 - x_pred_review_log_lambda_layer_loss: -108.8339 - x_pred_coordinates_mdn_layer_loss: -4.5791 - val_loss: -43.9117 - val_x_pred_binary_loss: 0.2365 - val_x_pred_categorical_loss: 1.8108 - val_x_pred_review_log_lambda_layer_loss: -44.9988 - val_x_pred_coordinates_mdn_layer_loss: -5.8289
# Epoch 12/50
# 174565/174565 [==============================] - 9s 54us/sample - loss: -106.2239 - x_pred_binary_loss: 0.4161 - x_pred_categorical_loss: 1.9221 - x_pred_review_log_lambda_layer_loss: -108.8484 - x_pred_coordinates_mdn_layer_loss: -4.6349 - val_loss: -43.9827 - val_x_pred_binary_loss: 0.1864 - val_x_pred_categorical_loss: 1.6170 - val_x_pred_review_log_lambda_layer_loss: -45.4489 - val_x_pred_coordinates_mdn_layer_loss: -6.4826
# Epoch 13/50
# 174565/174565 [==============================] - 9s 54us/sample - loss: -106.2851 - x_pred_binary_loss: 0.4175 - x_pred_categorical_loss: 1.9240 - x_pred_review_log_lambda_layer_loss: -108.8362 - x_pred_coordinates_mdn_layer_loss: -4.6614 - val_loss: -44.5279 - val_x_pred_binary_loss: 0.1042 - val_x_pred_categorical_loss: 1.5063 - val_x_pred_review_log_lambda_layer_loss: -45.9956 - val_x_pred_coordinates_mdn_layer_loss: -6.3782
# Epoch 14/50
# 174565/174565 [==============================] - 10s 59us/sample - loss: -106.5158 - x_pred_binary_loss: 0.4188 - x_pred_categorical_loss: 1.9241 - x_pred_review_log_lambda_layer_loss: -108.8157 - x_pred_coordinates_mdn_layer_loss: -4.7422 - val_loss: -44.4854 - val_x_pred_binary_loss: 0.2373 - val_x_pred_categorical_loss: 1.6879 - val_x_pred_review_log_lambda_layer_loss: -45.8032 - val_x_pred_coordinates_mdn_layer_loss: -7.0799
# Epoch 15/50
# 174565/174565 [==============================] - 10s 58us/sample - loss: -106.6235 - x_pred_binary_loss: 0.4200 - x_pred_categorical_loss: 1.9248 - x_pred_review_log_lambda_layer_loss: -108.8019 - x_pred_coordinates_mdn_layer_loss: -4.7628 - val_loss: -43.7680 - val_x_pred_binary_loss: 0.1645 - val_x_pred_categorical_loss: 1.6961 - val_x_pred_review_log_lambda_layer_loss: -45.0171 - val_x_pred_coordinates_mdn_layer_loss: -5.7094
# Epoch 16/50
# 174565/174565 [==============================] - 10s 55us/sample - loss: -106.8102 - x_pred_binary_loss: 0.4220 - x_pred_categorical_loss: 1.9258 - x_pred_review_log_lambda_layer_loss: -108.8580 - x_pred_coordinates_mdn_layer_loss: -4.8137 - val_loss: -44.4277 - val_x_pred_binary_loss: 0.2101 - val_x_pred_categorical_loss: 1.6754 - val_x_pred_review_log_lambda_layer_loss: -45.9835 - val_x_pred_coordinates_mdn_layer_loss: -6.1318
# Epoch 17/50
# 174565/174565 [==============================] - 10s 55us/sample - loss: -106.9255 - x_pred_binary_loss: 0.4224 - x_pred_categorical_loss: 1.9258 - x_pred_review_log_lambda_layer_loss: -108.8300 - x_pred_coordinates_mdn_layer_loss: -4.8546 - val_loss: -46.6273 - val_x_pred_binary_loss: 0.0876 - val_x_pred_categorical_loss: 1.5002 - val_x_pred_review_log_lambda_layer_loss: -45.5928 - val_x_pred_coordinates_mdn_layer_loss: -6.9948
# Epoch 18/50
# 174565/174565 [==============================] - 10s 60us/sample - loss: -107.0747 - x_pred_binary_loss: 0.4244 - x_pred_categorical_loss: 1.9266 - x_pred_review_log_lambda_layer_loss: -108.8403 - x_pred_coordinates_mdn_layer_loss: -4.8900 - val_loss: -45.7360 - val_x_pred_binary_loss: 0.2028 - val_x_pred_categorical_loss: 1.6833 - val_x_pred_review_log_lambda_layer_loss: -45.9913 - val_x_pred_coordinates_mdn_layer_loss: -6.3863
# Epoch 19/50
# 174565/174565 [==============================] - 10s 57us/sample - loss: -107.2710 - x_pred_binary_loss: 0.4257 - x_pred_categorical_loss: 1.9287 - x_pred_review_log_lambda_layer_loss: -108.8455 - x_pred_coordinates_mdn_layer_loss: -4.8764 - val_loss: -45.1494 - val_x_pred_binary_loss: 0.1815 - val_x_pred_categorical_loss: 1.6858 - val_x_pred_review_log_lambda_layer_loss: -45.9875 - val_x_pred_coordinates_mdn_layer_loss: -6.4747
# Epoch 20/50
# 174565/174565 [==============================] - 10s 57us/sample - loss: -107.5886 - x_pred_binary_loss: 0.4264 - x_pred_categorical_loss: 1.9285 - x_pred_review_log_lambda_layer_loss: -108.8534 - x_pred_coordinates_mdn_layer_loss: -4.7738 - val_loss: -45.8006 - val_x_pred_binary_loss: 0.2170 - val_x_pred_categorical_loss: 1.7463 - val_x_pred_review_log_lambda_layer_loss: -45.9203 - val_x_pred_coordinates_mdn_layer_loss: -5.9305
# Epoch 21/50
# 174565/174565 [==============================] - 11s 61us/sample - loss: -107.7386 - x_pred_binary_loss: 0.4278 - x_pred_categorical_loss: 1.9302 - x_pred_review_log_lambda_layer_loss: -108.7357 - x_pred_coordinates_mdn_layer_loss: -4.6886 - val_loss: -46.7122 - val_x_pred_binary_loss: 0.1471 - val_x_pred_categorical_loss: 1.5490 - val_x_pred_review_log_lambda_layer_loss: -46.0029 - val_x_pred_coordinates_mdn_layer_loss: -6.2575
# Epoch 22/50
# 174565/174565 [==============================] - 14s 82us/sample - loss: -107.9609 - x_pred_binary_loss: 0.4279 - x_pred_categorical_loss: 1.9301 - x_pred_review_log_lambda_layer_loss: -108.8556 - x_pred_coordinates_mdn_layer_loss: -4.7304 - val_loss: -46.0759 - val_x_pred_binary_loss: 0.2136 - val_x_pred_categorical_loss: 1.7810 - val_x_pred_review_log_lambda_layer_loss: -45.9822 - val_x_pred_coordinates_mdn_layer_loss: -3.0604
# Epoch 23/50
# 174565/174565 [==============================] - 17s 95us/sample - loss: -108.0714 - x_pred_binary_loss: 0.4298 - x_pred_categorical_loss: 1.9294 - x_pred_review_log_lambda_layer_loss: -108.8489 - x_pred_coordinates_mdn_layer_loss: -4.7500 - val_loss: -46.7849 - val_x_pred_binary_loss: 0.1438 - val_x_pred_categorical_loss: 1.5862 - val_x_pred_review_log_lambda_layer_loss: -45.8686 - val_x_pred_coordinates_mdn_layer_loss: -6.3254
# Epoch 24/50
# 174565/174565 [==============================] - 19s 110us/sample - loss: -108.1774 - x_pred_binary_loss: 0.4300 - x_pred_categorical_loss: 1.9304 - x_pred_review_log_lambda_layer_loss: -108.8559 - x_pred_coordinates_mdn_layer_loss: -4.7751 - val_loss: -47.3251 - val_x_pred_binary_loss: 0.2318 - val_x_pred_categorical_loss: 1.8269 - val_x_pred_review_log_lambda_layer_loss: -44.5958 - val_x_pred_coordinates_mdn_layer_loss: -6.1218
# Epoch 25/50
# 174565/174565 [==============================] - 16s 89us/sample - loss: -108.2654 - x_pred_binary_loss: 0.4310 - x_pred_categorical_loss: 1.9302 - x_pred_review_log_lambda_layer_loss: -108.8857 - x_pred_coordinates_mdn_layer_loss: -4.7789 - val_loss: -45.1787 - val_x_pred_binary_loss: 0.2063 - val_x_pred_categorical_loss: 1.9157 - val_x_pred_review_log_lambda_layer_loss: -45.2843 - val_x_pred_coordinates_mdn_layer_loss: -2.2826
# Epoch 26/50
# 174565/174565 [==============================] - 19s 108us/sample - loss: -108.2965 - x_pred_binary_loss: 0.4310 - x_pred_categorical_loss: 1.9307 - x_pred_review_log_lambda_layer_loss: -108.8597 - x_pred_coordinates_mdn_layer_loss: -4.7878 - val_loss: -48.0617 - val_x_pred_binary_loss: 0.1354 - val_x_pred_categorical_loss: 1.4037 - val_x_pred_review_log_lambda_layer_loss: -46.0012 - val_x_pred_coordinates_mdn_layer_loss: -5.5347
# Epoch 27/50
# 174565/174565 [==============================] - 19s 111us/sample - loss: -108.3571 - x_pred_binary_loss: 0.4316 - x_pred_categorical_loss: 1.9304 - x_pred_review_log_lambda_layer_loss: -108.8625 - x_pred_coordinates_mdn_layer_loss: -4.7790 - val_loss: -47.3607 - val_x_pred_binary_loss: 0.0845 - val_x_pred_categorical_loss: 1.4150 - val_x_pred_review_log_lambda_layer_loss: -45.7365 - val_x_pred_coordinates_mdn_layer_loss: -5.7289
# Epoch 28/50
# 174565/174565 [==============================] - 17s 96us/sample - loss: -108.3743 - x_pred_binary_loss: 0.4315 - x_pred_categorical_loss: 1.9313 - x_pred_review_log_lambda_layer_loss: -108.8256 - x_pred_coordinates_mdn_layer_loss: -4.8003 - val_loss: -46.7872 - val_x_pred_binary_loss: 0.1290 - val_x_pred_categorical_loss: 1.5984 - val_x_pred_review_log_lambda_layer_loss: -45.9105 - val_x_pred_coordinates_mdn_layer_loss: -5.6408
# Epoch 29/50
# 174565/174565 [==============================] - 10s 59us/sample - loss: -108.3993 - x_pred_binary_loss: 0.4327 - x_pred_categorical_loss: 1.9313 - x_pred_review_log_lambda_layer_loss: -108.8046 - x_pred_coordinates_mdn_layer_loss: -4.8078 - val_loss: -46.7490 - val_x_pred_binary_loss: 0.1356 - val_x_pred_categorical_loss: 1.7219 - val_x_pred_review_log_lambda_layer_loss: -45.9850 - val_x_pred_coordinates_mdn_layer_loss: -5.3740
# Epoch 30/50
# 174565/174565 [==============================] - 13s 73us/sample - loss: -108.4545 - x_pred_binary_loss: 0.4326 - x_pred_categorical_loss: 1.9318 - x_pred_review_log_lambda_layer_loss: -108.8230 - x_pred_coordinates_mdn_layer_loss: -4.8109 - val_loss: -47.4415 - val_x_pred_binary_loss: 0.1673 - val_x_pred_categorical_loss: 1.5472 - val_x_pred_review_log_lambda_layer_loss: -45.8695 - val_x_pred_coordinates_mdn_layer_loss: -4.0390
# Epoch 31/50
# 174565/174565 [==============================] - 13s 77us/sample - loss: -108.5182 - x_pred_binary_loss: 0.4332 - x_pred_categorical_loss: 1.9315 - x_pred_review_log_lambda_layer_loss: -108.8723 - x_pred_coordinates_mdn_layer_loss: -4.8148 - val_loss: -47.5292 - val_x_pred_binary_loss: 0.1819 - val_x_pred_categorical_loss: 1.6234 - val_x_pred_review_log_lambda_layer_loss: -45.5952 - val_x_pred_coordinates_mdn_layer_loss: -5.6175
# Epoch 32/50
# 174565/174565 [==============================] - 10s 58us/sample - loss: -108.4665 - x_pred_binary_loss: 0.4330 - x_pred_categorical_loss: 1.9318 - x_pred_review_log_lambda_layer_loss: -108.7779 - x_pred_coordinates_mdn_layer_loss: -4.8229 - val_loss: -46.9775 - val_x_pred_binary_loss: 0.0897 - val_x_pred_categorical_loss: 1.4596 - val_x_pred_review_log_lambda_layer_loss: -45.5134 - val_x_pred_coordinates_mdn_layer_loss: -5.6188
# Epoch 33/50
# 174565/174565 [==============================] - 10s 56us/sample - loss: -108.5639 - x_pred_binary_loss: 0.4333 - x_pred_categorical_loss: 1.9317 - x_pred_review_log_lambda_layer_loss: -108.8471 - x_pred_coordinates_mdn_layer_loss: -4.8425 - val_loss: -47.4098 - val_x_pred_binary_loss: 0.1694 - val_x_pred_categorical_loss: 1.5068 - val_x_pred_review_log_lambda_layer_loss: -45.9835 - val_x_pred_coordinates_mdn_layer_loss: -5.9992
# Epoch 34/50
# 174565/174565 [==============================] - 11s 64us/sample - loss: -108.5915 - x_pred_binary_loss: 0.4328 - x_pred_categorical_loss: 1.9309 - x_pred_review_log_lambda_layer_loss: -108.8539 - x_pred_coordinates_mdn_layer_loss: -4.8582 - val_loss: -46.9872 - val_x_pred_binary_loss: 0.1567 - val_x_pred_categorical_loss: 1.6566 - val_x_pred_review_log_lambda_layer_loss: -45.9161 - val_x_pred_coordinates_mdn_layer_loss: -5.6183
# Epoch 35/50
# 174565/174565 [==============================] - 10s 57us/sample - loss: -108.5876 - x_pred_binary_loss: 0.4337 - x_pred_categorical_loss: 1.9318 - x_pred_review_log_lambda_layer_loss: -108.8342 - x_pred_coordinates_mdn_layer_loss: -4.8637 - val_loss: -48.2933 - val_x_pred_binary_loss: 0.2228 - val_x_pred_categorical_loss: 2.0429 - val_x_pred_review_log_lambda_layer_loss: -44.6123 - val_x_pred_coordinates_mdn_layer_loss: -6.2972
# Epoch 36/50
# 174565/174565 [==============================] - 14s 80us/sample - loss: -108.6112 - x_pred_binary_loss: 0.4341 - x_pred_categorical_loss: 1.9313 - x_pred_review_log_lambda_layer_loss: -108.8423 - x_pred_coordinates_mdn_layer_loss: -4.8819 - val_loss: -46.9209 - val_x_pred_binary_loss: 0.2020 - val_x_pred_categorical_loss: 1.7432 - val_x_pred_review_log_lambda_layer_loss: -45.9794 - val_x_pred_coordinates_mdn_layer_loss: -5.8228
# Epoch 37/50
# 174565/174565 [==============================] - 16s 90us/sample - loss: -108.6410 - x_pred_binary_loss: 0.4343 - x_pred_categorical_loss: 1.9315 - x_pred_review_log_lambda_layer_loss: -108.8519 - x_pred_coordinates_mdn_layer_loss: -4.9058 - val_loss: -46.6651 - val_x_pred_binary_loss: 0.1955 - val_x_pred_categorical_loss: 1.6051 - val_x_pred_review_log_lambda_layer_loss: -45.3895 - val_x_pred_coordinates_mdn_layer_loss: -5.9030 -109.6088 - x_pred_binary_loss: 0.4337 - x_pred_categorical_loss: 1.9316 - x_pred_review_log_lambda_layer_loss
# Epoch 38/50
# 174565/174565 [==============================] - 11s 62us/sample - loss: -108.6799 - x_pred_binary_loss: 0.4341 - x_pred_categorical_loss: 1.9314 - x_pred_review_log_lambda_layer_loss: -108.8717 - x_pred_coordinates_mdn_layer_loss: -4.9122 - val_loss: -47.1205 - val_x_pred_binary_loss: 0.1699 - val_x_pred_categorical_loss: 1.7195 - val_x_pred_review_log_lambda_layer_loss: -45.9204 - val_x_pred_coordinates_mdn_layer_loss: -5.9661
# Epoch 39/50
# 174565/174565 [==============================] - 13s 75us/sample - loss: -108.6611 - x_pred_binary_loss: 0.4342 - x_pred_categorical_loss: 1.9323 - x_pred_review_log_lambda_layer_loss: -108.8447 - x_pred_coordinates_mdn_layer_loss: -4.9196 - val_loss: -46.9741 - val_x_pred_binary_loss: 0.1755 - val_x_pred_categorical_loss: 1.6923 - val_x_pred_review_log_lambda_layer_loss: -45.7607 - val_x_pred_coordinates_mdn_layer_loss: -5.8616
# Epoch 40/50
# 174565/174565 [==============================] - 12s 68us/sample - loss: -108.6704 - x_pred_binary_loss: 0.4346 - x_pred_categorical_loss: 1.9321 - x_pred_review_log_lambda_layer_loss: -108.8410 - x_pred_coordinates_mdn_layer_loss: -4.9349 - val_loss: -47.0191 - val_x_pred_binary_loss: 0.1681 - val_x_pred_categorical_loss: 1.7904 - val_x_pred_review_log_lambda_layer_loss: -44.4350 - val_x_pred_coordinates_mdn_layer_loss: -6.0766
# Epoch 41/50
# 174565/174565 [==============================] - 15s 86us/sample - loss: -108.6093 - x_pred_binary_loss: 0.4344 - x_pred_categorical_loss: 1.9318 - x_pred_review_log_lambda_layer_loss: -108.7710 - x_pred_coordinates_mdn_layer_loss: -4.9501 - val_loss: -47.2747 - val_x_pred_binary_loss: 0.2494 - val_x_pred_categorical_loss: 1.7944 - val_x_pred_review_log_lambda_layer_loss: -45.9477 - val_x_pred_coordinates_mdn_layer_loss: -6.1888
# Epoch 42/50
# 174565/174565 [==============================] - 16s 89us/sample - loss: -108.6959 - x_pred_binary_loss: 0.4350 - x_pred_categorical_loss: 1.9323 - x_pred_review_log_lambda_layer_loss: -108.8488 - x_pred_coordinates_mdn_layer_loss: -4.9631 - val_loss: -46.5477 - val_x_pred_binary_loss: 0.1840 - val_x_pred_categorical_loss: 1.5333 - val_x_pred_review_log_lambda_layer_loss: -44.6752 - val_x_pred_coordinates_mdn_layer_loss: -5.7809
# Epoch 43/50
# 174565/174565 [==============================] - 16s 91us/sample - loss: -108.6750 - x_pred_binary_loss: 0.4350 - x_pred_categorical_loss: 1.9326 - x_pred_review_log_lambda_layer_loss: -108.8004 - x_pred_coordinates_mdn_layer_loss: -4.9699 - val_loss: -47.1441 - val_x_pred_binary_loss: 0.1987 - val_x_pred_categorical_loss: 1.7305 - val_x_pred_review_log_lambda_layer_loss: -45.5458 - val_x_pred_coordinates_mdn_layer_loss: -6.1809
# Epoch 44/50
# 174565/174565 [==============================] - 13s 73us/sample - loss: -108.7408 - x_pred_binary_loss: 0.4352 - x_pred_categorical_loss: 1.9325 - x_pred_review_log_lambda_layer_loss: -108.8522 - x_pred_coordinates_mdn_layer_loss: -4.9840 - val_loss: -47.7399 - val_x_pred_binary_loss: 0.1190 - val_x_pred_categorical_loss: 1.5174 - val_x_pred_review_log_lambda_layer_loss: -45.7744 - val_x_pred_coordinates_mdn_layer_loss: -4.2702
# Epoch 45/50
# 174565/174565 [==============================] - 13s 77us/sample - loss: -108.7360 - x_pred_binary_loss: 0.4353 - x_pred_categorical_loss: 1.9327 - x_pred_review_log_lambda_layer_loss: -108.8359 - x_pred_coordinates_mdn_layer_loss: -5.0014 - val_loss: -46.7933 - val_x_pred_binary_loss: 0.1783 - val_x_pred_categorical_loss: 1.6200 - val_x_pred_review_log_lambda_layer_loss: -45.4911 - val_x_pred_coordinates_mdn_layer_loss: -5.9264
# Epoch 46/50
# 174565/174565 [==============================] - 16s 92us/sample - loss: -108.7819 - x_pred_binary_loss: 0.4357 - x_pred_categorical_loss: 1.9330 - x_pred_review_log_lambda_layer_loss: -108.8743 - x_pred_coordinates_mdn_layer_loss: -5.0120 - val_loss: -47.7776 - val_x_pred_binary_loss: 0.1288 - val_x_pred_categorical_loss: 1.3426 - val_x_pred_review_log_lambda_layer_loss: -44.6568 - val_x_pred_coordinates_mdn_layer_loss: -5.1405
# Epoch 47/50
# 174565/174565 [==============================] - 17s 98us/sample - loss: -108.7688 - x_pred_binary_loss: 0.4355 - x_pred_categorical_loss: 1.9327 - x_pred_review_log_lambda_layer_loss: -108.8502 - x_pred_coordinates_mdn_layer_loss: -5.0169 - val_loss: -46.7460 - val_x_pred_binary_loss: 0.2241 - val_x_pred_categorical_loss: 1.8342 - val_x_pred_review_log_lambda_layer_loss: -45.9888 - val_x_pred_coordinates_mdn_layer_loss: -5.9095
# Epoch 48/50
# 174565/174565 [==============================] - 16s 92us/sample - loss: -108.7521 - x_pred_binary_loss: 0.4353 - x_pred_categorical_loss: 1.9323 - x_pred_review_log_lambda_layer_loss: -108.8325 - x_pred_coordinates_mdn_layer_loss: -5.0231 - val_loss: -47.0044 - val_x_pred_binary_loss: 0.1756 - val_x_pred_categorical_loss: 1.6046 - val_x_pred_review_log_lambda_layer_loss: -45.5116 - val_x_pred_coordinates_mdn_layer_loss: -5.9837
# Epoch 49/50
# 174565/174565 [==============================] - 16s 89us/sample - loss: -108.7735 - x_pred_binary_loss: 0.4361 - x_pred_categorical_loss: 1.9322 - x_pred_review_log_lambda_layer_loss: -108.8460 - x_pred_coordinates_mdn_layer_loss: -5.0353 - val_loss: -47.4324 - val_x_pred_binary_loss: 0.1991 - val_x_pred_categorical_loss: 1.7043 - val_x_pred_review_log_lambda_layer_loss: -45.9555 - val_x_pred_coordinates_mdn_layer_loss: -5.7815
# Epoch 50/50
# 174565/174565 [==============================] - 14s 79us/sample - loss: -108.8151 - x_pred_binary_loss: 0.4358 - x_pred_categorical_loss: 1.9322 - x_pred_review_log_lambda_layer_loss: -108.8635 - x_pred_coordinates_mdn_layer_loss: -5.0513 - val_loss: -46.7653 - val_x_pred_binary_loss: 0.1812 - val_x_pred_categorical_loss: 1.6470 - val_x_pred_review_log_lambda_layer_loss: -45.4222 - val_x_pred_coordinates_mdn_layer_loss: -5.8104

# %% [markdown]
# ## Building the Decoder

# %%
decode_input = Input(shape=(latent_dim, ), name = 'decode_input')
decode_layer_1 = decode_1(decode_input)
decode_layer_2 = decode_2(decode_layer_1)

decode_x_pred_coordinates=x_pred_coordinates_mdn_layer(decode_layer_2)

decode_x_pred_review = x_pred_review_log_lambda_layer(decode_layer_2)

decode_x_pred_binary = x_pred_binary_layer(decode_layer_2) # binary cross entropy
decode_x_pred_categorical = x_pred_categorical_layer(decode_layer_2) # categorical cross entropy


decoder = Model(decode_input, [decode_x_pred_coordinates, decode_x_pred_review, decode_x_pred_categorical, decode_x_pred_binary])

# %%
tf.keras.utils.plot_model(
    decoder, to_file='./description/vae_decoder.png', show_shapes=True, show_layer_names=True,
    rankdir='TB', expand_nested=False, dpi=96
)

# %% [markdown]
# ### Saving the Models and Metadata
# #### Saving Models (Actually, only the decoder matter)

# %%
# model_json = vae.to_json()
# with open(full_model_file, "w") as json_file:
#     json_file.write(model_json)
vae.save_weights(full_model_weights)
print("Saved model to disk")

# encoder = Model(x, [z_mu, z_log_var])
model_json = encoder.to_json()
with open(encoder_file, "w") as json_file:
    json_file.write(model_json)
encoder.save_weights(encoder_weights)
print("Saved model to disk")

model_json = decoder.to_json()
with open(decoder_file, "w") as json_file:
    json_file.write(model_json)
decoder.save_weights(decoder_weights)
print("Saved model to disk")
# Out:
# Saved model to disk
# Saved model to disk
# Saved model to disk

# %% [markdown]
# #### Generating and Saving Metadata

# %%
vae_sample = train_dataset[np.random.choice(len(train_dataset), size=1000, replace=False)]
z_meta = encoder.predict(vae_sample, batch_size=batch_size)

np.save('./model/z_meta.npy', z_meta)

# %% [markdown]
# ### Generating some Samples for Testing
# #### Functions for data generation

# %%
reverse_categorical_map = {0:0, 1:0.5, 2:1, 3:1.5, 4:2, 5:2.5, 6:3, 7:3.5, 8:4, 9:4.5, 10:5}
def sample(decoder, sampler, input_z_params,samples_per_z=1):
    multiplied_input_z_params = np.repeat(input_z_params, samples_per_z, axis=0)
    z = sampler.predict(multiplied_input_z_params)
    predictions = decoder.predict(z, batch_size = None, steps = 1)
    return reconstruct(predictions)
    
def reconstruct(predictions):
    coordinates, review, categorical, binary = predictions
    # coordinates handled here
    coordinates_data = np.apply_along_axis(mdn.sample_from_output, 1, coordinates, OUTPUT_DIMS, N_MIXES, temp=1.0)
    coordinates_data = np.squeeze(coordinates_data, axis=1)
    scaler = load(open('./model/standard_scaler.pkl', 'rb'))
    coordinates_data = scaler.inverse_transform(coordinates_data)
    
    for i, c in enumerate(coordinates_data):
        if c[0] > 180.0:
            coordinates_data[i][0]= 180.0
        if c[0] < -180.0:
            coordinates_data[i][0]= -180.0
        if c[1] > 180.0:
            coordinates_data[i][1]= 180.0
        if c[1] < -180.0:
            coordinates_data[i][1]= -180.0
    
    ## review_count handled here
    exp_log_review = np.exp(review)
    review_data = np.random.poisson(lam=exp_log_review, size = review.shape)
    for i, r in enumerate(review_data):
        if r[0] < 0:
            review_data[i][0] = 0
        review_data[i][0] = float(int(review_data[i][0]))
    categorical = np.apply_along_axis(lambda t : np.random.multinomial(1,t), -1, categorical)
    categorical = np.apply_along_axis(lambda t : np.argmax(t), -1, categorical)
    categorical = np.expand_dims(categorical, axis = -1)
    categorical_data = np.apply_along_axis(lambda t : float(reverse_categorical_map[t[0]]), -1, categorical)
    categorical_data = np.expand_dims(categorical_data, axis = -1)
    binary_data = np.apply_along_axis(lambda t: np.random.binomial(1, t), -1, binary)
#     coordinates, reviews = np.split(continuous_data, indices_or_sections=[2], axis = 1)
    return np.concatenate([coordinates_data, categorical_data, review_data, binary_data], axis = 1)
    

def reparameterize(input_mu, input_log_var, eps):
    sigma = np.exp(0.5*input_log_var)
    return eps*sigma + input_mu

# %% [markdown]
# ### Generating Samples
# Make use of the funciton sample to generate samples with our model. U need to supply an array of mu and their respective log var in a separate array to do that.

# %%
vae_samples = sample(decoder, sampler, z_meta, samples_per_z=30)

# # Saving the samples in a separate file
file_name = './samples/vae_8_sample_' + str(len(z_meta))+'_times_'+ str(len(vae_samples)//len(z_meta)) + '.csv'
np.savetxt(file_name, vae_samples, delimiter = ',', header='latitude,longitude,stars,review_count,is_open')

# %%
vae_samples[1:10]
# Out:
# array([[  33.57787935, -112.17719004,    3.5       ,    9.        ,
#            1.        ],
#        [  36.09927431, -114.89873207,    3.5       ,    9.        ,
#            1.        ],
#        [  36.1161279 , -115.32066263,    2.5       ,   31.        ,
#            1.        ],
#        [  41.62079403,  -81.50316083,    3.5       ,   28.        ,
#            1.        ],
#        [  33.36052179, -111.59417113,    5.        ,    3.        ,
#            1.        ],
#        [  33.50433666, -111.8647239 ,    4.5       ,   47.        ,
#            1.        ],
#        [  33.56679236, -111.77841304,    4.5       ,    2.        ,
#            1.        ],
#        [  43.68963305,  -79.49008364,    3.        ,    4.        ,
#            0.        ],
#        [  43.14599082,  -79.96562887,    1.5       ,    3.        ,
#            1.        ]])
