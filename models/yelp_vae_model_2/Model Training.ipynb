# %% [markdown]
# # Model Training
# In this notebook, we will train our VAE model. This involves:
#
# 1. Encoder
# 2. Decoder
# 3. Full Model

# %% [markdown]
# ## Importing Packages
# We will be using Keras to build and train our VAE

# %%
from __future__ import absolute_import, division, print_function, unicode_literals
# %matplotlib notebook
import tensorflow as tf

import os
import time
import numpy as np
import glob
import matplotlib.pyplot as plt
import PIL
import imageio
import h5py

import keras
from keras import backend as K
from keras.layers import Input, Dense, Lambda, Layer, Add, Multiply, Concatenate
from keras.models import Model, Sequential
from keras.utils import to_categorical
from keras.models import model_from_json

from IPython import display
import numpy as np
import pandas as pd

from matplotlib.ticker import FormatStrFormatter
from keras.utils.vis_utils import model_to_dot, plot_model
from IPython.display import SVG
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ## Definition of Constants
# Hyper parameters and constants will all be located here for ease of adjustments

# %%
categorical_dim = 11
categorical_map = {0:0, 0.5:1, 1: 2, 1.5:3, 2:4, 2.5:5, 3:6, 3.5:7, 4:8, 4.5:9, 5:10}
reverse_categorical_map = {0:0, 1:0.5, 2:1, 3:1.5, 4:2, 5:2.5, 6:3, 7:3.5, 8:4, 9:4.5, 10:5}
continuous_dim = 3
binary_dim = 1
original_dim = binary_dim + continuous_dim + categorical_dim
intermediate_dim_1 = 50
intermediate_dim_2 = 50
latent_dim = 4
batch_size = 100
epochs = 50
epsilon_std = 1.0

# %% [markdown]
# ## Building the Model
# We have to write our own custom layer and custom loss function as these are not supported on Keras natively. There are a few things to be done:
#
# 1. Custom KLDivergence Layer
# 2. Custom Loss Functions
# 3. Building the Model

# %% [markdown]
# ### KL Divergence Layer
# To ensure modularity, we decided to create a separate layer for KL Divergence. This layer will account for the loss required.

# %%
class KLDivergenceLayer(Layer):

    """ Identity transform layer that adds KL divergence
    to the final model loss.
    """

    def __init__(self, *args, **kwargs):
        self.is_placeholder = True
        super(KLDivergenceLayer, self).__init__(*args, **kwargs)

    def call(self, inputs):

        mu, log_var = inputs

        kl_batch = - .5 * K.sum(1 + log_var -
                                K.square(mu) -
                                K.exp(log_var), axis=-1)

        self.add_loss(K.mean(kl_batch), inputs=inputs)

        return inputs

# %% [markdown]
# ### Custom Loss Functions
# As the yelp dataset contains binary, categorical as well as continuous data, we will build 3 custom loss functions.
#
# #### Binary Loss Function

# %%
def binary_loss(y_true, y_pred):
	# input dimension is (batchsize, 1)
    return K.binary_crossentropy(y_true, y_pred) # the dimension of return value is (batchsize , 1)

# %% [markdown]
# #### Categorical Loss Function

# %%
def categorical_loss(y_true, y_pred):
	# input dimension is (batchsize, number of categories)
  return K.categorical_crossentropy(y_true, y_pred) # the dimension of return value is (batchsize , 1)

# %% [markdown]
# #### Continuous Loss Function

# %%
def log_normal_pdf(sample, mean, logvar, raxis=1):
  log2pi = tf.math.log(2. * np.pi)
  return tf.reduce_sum(
      -.5 * ((sample - mean) ** 2. * tf.exp(-logvar) + logvar + log2pi),
      axis=raxis) # return a tensor of shape (batch_size, 1)

def continuous_loss(y_true, y_pred):
	# need to return log probability for continuous loss.
	# will get a (batchsize, 6 continuous variable input) where 3 of the 6 represents mu and the others logvar
	# y_true will be (batchsize, 3)
  mu, logvar = tf.split(y_pred, num_or_size_splits = 2, axis = 1)
  return -1 * log_normal_pdf(y_true, mu, logvar)

# %% [markdown]
# ### Model Architecture
# - tanh/sigmoid is used because Relu resulted in loss going to infinity

# %%
x = Input(shape=(original_dim,), name='input_x')
h = Dense(intermediate_dim_1, activation='tanh', name='hidden_enc_1')(x)
h = Dense(intermediate_dim_2, activation='tanh', name='hidden_enc_2')(h)

z_mu = Dense(latent_dim, name='z_mu')(h)
z_log_var = Dense(latent_dim, name='z_log_var')(h)

z_mu, z_log_var = KLDivergenceLayer(name='KL_Divergence')([z_mu, z_log_var])
z_sigma = Lambda(lambda t: K.exp(.5*t))(z_log_var)

eps = Input(name='input_eps',tensor=K.random_normal(stddev=epsilon_std,
                                   shape=(K.shape(x)[0], latent_dim)))
z_eps = Multiply()([z_sigma, eps])
z = Add()([z_mu, z_eps])

decode_1 = Dense(intermediate_dim_2, activation='tanh', name='hidden_dec_2')
h_dec = decode_1(z)

decode_2 = Dense(intermediate_dim_1, activation='tanh', name='hidden_dec_1')
h_dec = decode_2(h_dec)

x_pred_coordinates_mu_layer = Dense(2, activation='sigmoid',name='x_pred_coordinates_mu')
x_pred_coordinates_mu = x_pred_coordinates_mu_layer(h_dec)

x_pred_coordinates_log_var_layer = Dense(2, name='x_pred_coordinates_log_var')
x_pred_coordinates_log_var = x_pred_coordinates_log_var_layer(h_dec)

x_pred_coordinates_layer = Concatenate(axis=-1, name = 'x_pred_coordinates')
x_pred_coordinates = x_pred_coordinates_layer([x_pred_coordinates_mu, x_pred_coordinates_log_var])

x_pred_review_mu_layer = Dense(1, activation='relu', name='x_pred_review_mu')
x_pred_review_mu = x_pred_review_mu_layer(h_dec)

x_pred_review_log_var_layer = Dense(1, name='x_pred_review_log_var')
x_pred_review_log_var = x_pred_review_log_var_layer(h_dec)

x_pred_review_layer = Concatenate(axis=-1, name = 'x_pred_review')
x_pred_review = x_pred_review_layer([x_pred_review_mu, x_pred_review_log_var])

x_pred_binary_layer = Dense(binary_dim, activation='sigmoid', name='x_pred_binary')
x_pred_binary = x_pred_binary_layer(h_dec) # binary cross entropy

x_pred_categorical_layer = Dense(categorical_dim, activation='softmax', name='x_pred_categorical')
x_pred_categorical = x_pred_categorical_layer(h_dec) # categorical cross entropy

vae = Model(inputs=[x,eps], outputs=[x_pred_binary, x_pred_categorical, x_pred_review, x_pred_coordinates])

# %%
SVG(model_to_dot(vae, show_shapes=True)
    .create(prog='dot', format='svg'))

# %%
plot_model(
    model=vae, show_shapes=True,
    to_file='./description/vae_full_model.png'
)

# %% [markdown]
# ### Compiling Model and Setting Parameters

# %%
optimizer = keras.optimizers.Adam(lr=0.0001,clipvalue=1)
vae.compile(optimizer=optimizer, loss=[binary_loss, categorical_loss, continuous_loss, continuous_loss], loss_weights=[1, 1, 1, 1])

# %%
vae.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_x (InputLayer)            (None, 15)           0
# __________________________________________________________________________________________________
# hidden_enc_1 (Dense)            (None, 50)           800         input_x[0][0]
# __________________________________________________________________________________________________
# hidden_enc_2 (Dense)            (None, 50)           2550        hidden_enc_1[0][0]
# __________________________________________________________________________________________________
# z_mu (Dense)                    (None, 4)            204         hidden_enc_2[0][0]
# __________________________________________________________________________________________________
# z_log_var (Dense)               (None, 4)            204         hidden_enc_2[0][0]
# __________________________________________________________________________________________________
# KL_Divergence (KLDivergenceLaye [(None, 4), (None, 4 0           z_mu[0][0]
#                                                                  z_log_var[0][0]
# __________________________________________________________________________________________________
# lambda_1 (Lambda)               (None, 4)            0           KL_Divergence[0][1]
# __________________________________________________________________________________________________
# input_eps (InputLayer)          (None, 4)            0
# __________________________________________________________________________________________________
# multiply_1 (Multiply)           (None, 4)            0           lambda_1[0][0]
#                                                                  input_eps[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 4)            0           KL_Divergence[0][0]
#                                                                  multiply_1[0][0]
# __________________________________________________________________________________________________
# hidden_dec_2 (Dense)            (None, 50)           250         add_1[0][0]
# __________________________________________________________________________________________________
# hidden_dec_1 (Dense)            (None, 50)           2550        hidden_dec_2[0][0]
# __________________________________________________________________________________________________
# x_pred_review_mu (Dense)        (None, 1)            51          hidden_dec_1[0][0]
# __________________________________________________________________________________________________
# x_pred_review_log_var (Dense)   (None, 1)            51          hidden_dec_1[0][0]
# __________________________________________________________________________________________________
# x_pred_coordinates_mu (Dense)   (None, 2)            102         hidden_dec_1[0][0]
# __________________________________________________________________________________________________
# x_pred_coordinates_log_var (Den (None, 2)            102         hidden_dec_1[0][0]
# __________________________________________________________________________________________________
# x_pred_binary (Dense)           (None, 1)            51          hidden_dec_1[0][0]
# __________________________________________________________________________________________________
# x_pred_categorical (Dense)      (None, 11)           561         hidden_dec_1[0][0]
# __________________________________________________________________________________________________
# x_pred_review (Concatenate)     (None, 2)            0           x_pred_review_mu[0][0]
#                                                                  x_pred_review_log_var[0][0]
# __________________________________________________________________________________________________
# x_pred_coordinates (Concatenate (None, 4)            0           x_pred_coordinates_mu[0][0]
#                                                                  x_pred_coordinates_log_var[0][0]
# ==================================================================================================
# Total params: 7,476
# Trainable params: 7,476
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# ## Data Loading and Preprocessing

# %%
dataset = np.genfromtxt('../../datasets/yelp_business.csv',delimiter=',',skip_header=1)
dataset = dataset[~np.isnan(dataset).any(axis=1)]
test_set, train_set = np.split(dataset,[1], axis = 0)

def format_data(dataset):
  # handling the categorical variables
  coordinates, ratings, reviews, is_opens = np.split(dataset, [2, 3, 4], axis = 1)
  one_hot_array = np.zeros((ratings.shape[0], categorical_dim))

  for i, r in enumerate(ratings):
    one_hot_array[i][categorical_map[r[0]]] = 1
  
  for i, c in enumerate(coordinates):
    coordinates[i][0] = (c[0]+180)/360
    coordinates[i][1] = (c[1]+180)/360

  dataset = np.concatenate((coordinates, reviews, is_opens, one_hot_array), axis = 1)

  # creating the labels
  coordinates_labels = coordinates
  review_labels = reviews
  categorical_labels = one_hot_array
  binary_labels = is_opens
  return dataset, coordinates_labels, review_labels, categorical_labels, binary_labels

train_dataset, train_coordinates_labels, train_review_labels, train_categorical_labels, train_binary_labels = format_data(train_set)
test_dataset, test_coordinates_labels, test_review_labels, test_categorical_labels, test_binary_labels = format_data(test_set)

# %% [markdown]
# ## Training the Model

# %%
vae.fit(train_dataset , [train_binary_labels, train_categorical_labels, train_review_labels, train_coordinates_labels], shuffle = True, epochs = epochs, batch_size = batch_size, validation_data=(test_dataset , [test_binary_labels, test_categorical_labels, test_review_labels, test_coordinates_labels]))
# Out:
# Train on 174565 samples, validate on 1 samples
# Epoch 1/50
# 174565/174565 [==============================] - 10s 57us/step - loss: 144.6395 - x_pred_binary_loss: 0.4623 - x_pred_categorical_loss: 2.0862 - x_pred_review_loss: 140.2536 - x_pred_coordinates_loss: -1.1536 - val_loss: 3.7931 - val_x_pred_binary_loss: 0.1282 - val_x_pred_categorical_loss: 1.5089 - val_x_pred_review_loss: 5.0663 - val_x_pred_coordinates_loss: -4.5232
# Epoch 2/50
# 174565/174565 [==============================] - 7s 43us/step - loss: 5.0130 - x_pred_binary_loss: 0.4407 - x_pred_categorical_loss: 2.0062 - x_pred_review_loss: 4.7878 - x_pred_coordinates_loss: -3.4965 - val_loss: 3.7405 - val_x_pred_binary_loss: 0.1770 - val_x_pred_categorical_loss: 1.6437 - val_x_pred_review_loss: 4.6777 - val_x_pred_coordinates_loss: -3.8993
# Epoch 3/50
# 174565/174565 [==============================] - 8s 49us/step - loss: 4.3201 - x_pred_binary_loss: 0.4345 - x_pred_categorical_loss: 2.0020 - x_pred_review_loss: 4.5679 - x_pred_coordinates_loss: -3.7458 - val_loss: 3.3665 - val_x_pred_binary_loss: 0.1664 - val_x_pred_categorical_loss: 1.5932 - val_x_pred_review_loss: 4.4048 - val_x_pred_coordinates_loss: -3.8418
# Epoch 4/50
# 174565/174565 [==============================] - 8s 44us/step - loss: 3.7000 - x_pred_binary_loss: 0.4359 - x_pred_categorical_loss: 1.9971 - x_pred_review_loss: 4.3346 - x_pred_coordinates_loss: -4.0071 - val_loss: 2.0565 - val_x_pred_binary_loss: 0.1255 - val_x_pred_categorical_loss: 1.4338 - val_x_pred_review_loss: 5.1342 - val_x_pred_coordinates_loss: -5.4190
# Epoch 5/50
# 174565/174565 [==============================] - 7s 39us/step - loss: 2.9938 - x_pred_binary_loss: 0.4374 - x_pred_categorical_loss: 1.9837 - x_pred_review_loss: 3.9138 - x_pred_coordinates_loss: -4.1745 - val_loss: 2.0591 - val_x_pred_binary_loss: 0.1568 - val_x_pred_categorical_loss: 1.5329 - val_x_pred_review_loss: 4.7693 - val_x_pred_coordinates_loss: -5.1047
# Epoch 6/50
# 174565/174565 [==============================] - 7s 38us/step - loss: 2.7918 - x_pred_binary_loss: 0.4374 - x_pred_categorical_loss: 1.9740 - x_pred_review_loss: 3.8019 - x_pred_coordinates_loss: -4.2479 - val_loss: 1.8366 - val_x_pred_binary_loss: 0.1428 - val_x_pred_categorical_loss: 1.3676 - val_x_pred_review_loss: 5.0137 - val_x_pred_coordinates_loss: -5.4097
# Epoch 7/50
# 174565/174565 [==============================] - 7s 39us/step - loss: 2.6382 - x_pred_binary_loss: 0.4377 - x_pred_categorical_loss: 1.9535 - x_pred_review_loss: 3.7005 - x_pred_coordinates_loss: -4.3469 - val_loss: 2.7115 - val_x_pred_binary_loss: 0.1542 - val_x_pred_categorical_loss: 1.5928 - val_x_pred_review_loss: 4.8925 - val_x_pred_coordinates_loss: -4.7620
# Epoch 8/50
# 174565/174565 [==============================] - 7s 38us/step - loss: 2.4606 - x_pred_binary_loss: 0.4380 - x_pred_categorical_loss: 1.9267 - x_pred_review_loss: 3.6016 - x_pred_coordinates_loss: -4.5988 - val_loss: 1.9426 - val_x_pred_binary_loss: 0.1763 - val_x_pred_categorical_loss: 1.3972 - val_x_pred_review_loss: 4.3520 - val_x_pred_coordinates_loss: -4.8890
# Epoch 9/50
# 174565/174565 [==============================] - 7s 38us/step - loss: 2.2933 - x_pred_binary_loss: 0.4394 - x_pred_categorical_loss: 1.9109 - x_pred_review_loss: 3.4818 - x_pred_coordinates_loss: -4.9491 - val_loss: 2.0135 - val_x_pred_binary_loss: 0.1617 - val_x_pred_categorical_loss: 1.2794 - val_x_pred_review_loss: 4.4423 - val_x_pred_coordinates_loss: -5.1086
# Epoch 10/50
# 174565/174565 [==============================] - 6s 37us/step - loss: 2.1456 - x_pred_binary_loss: 0.4400 - x_pred_categorical_loss: 1.9047 - x_pred_review_loss: 3.3979 - x_pred_coordinates_loss: -5.3313 - val_loss: 2.3732 - val_x_pred_binary_loss: 0.1721 - val_x_pred_categorical_loss: 1.3579 - val_x_pred_review_loss: 4.9215 - val_x_pred_coordinates_loss: -5.6074
# Epoch 11/50
# 174565/174565 [==============================] - 7s 37us/step - loss: 2.0408 - x_pred_binary_loss: 0.4396 - x_pred_categorical_loss: 1.9015 - x_pred_review_loss: 3.3457 - x_pred_coordinates_loss: -5.6660 - val_loss: 1.1716 - val_x_pred_binary_loss: 0.1622 - val_x_pred_categorical_loss: 1.5467 - val_x_pred_review_loss: 4.4356 - val_x_pred_coordinates_loss: -6.7663
# Epoch 12/50
# 174565/174565 [==============================] - 7s 39us/step - loss: 1.9346 - x_pred_binary_loss: 0.4395 - x_pred_categorical_loss: 1.9084 - x_pred_review_loss: 3.3029 - x_pred_coordinates_loss: -5.9293 - val_loss: 1.7771 - val_x_pred_binary_loss: 0.1515 - val_x_pred_categorical_loss: 1.3706 - val_x_pred_review_loss: 4.3868 - val_x_pred_coordinates_loss: -6.1751
# Epoch 13/50
# 174565/174565 [==============================] - 7s 38us/step - loss: 1.8799 - x_pred_binary_loss: 0.4394 - x_pred_categorical_loss: 1.9088 - x_pred_review_loss: 3.2995 - x_pred_coordinates_loss: -6.1309 - val_loss: 0.6814 - val_x_pred_binary_loss: 0.1609 - val_x_pred_categorical_loss: 1.5335 - val_x_pred_review_loss: 4.0894 - val_x_pred_coordinates_loss: -7.2870
# Epoch 14/50
# 174565/174565 [==============================] - 8s 44us/step - loss: 1.8164 - x_pred_binary_loss: 0.4393 - x_pred_categorical_loss: 1.9127 - x_pred_review_loss: 3.2888 - x_pred_coordinates_loss: -6.2808 - val_loss: 0.7463 - val_x_pred_binary_loss: 0.1657 - val_x_pred_categorical_loss: 1.6606 - val_x_pred_review_loss: 4.2716 - val_x_pred_coordinates_loss: -7.6438
# Epoch 15/50
# 174565/174565 [==============================] - 11s 60us/step - loss: 1.7637 - x_pred_binary_loss: 0.4393 - x_pred_categorical_loss: 1.9149 - x_pred_review_loss: 3.2910 - x_pred_coordinates_loss: -6.4109 - val_loss: 1.3093 - val_x_pred_binary_loss: 0.1843 - val_x_pred_categorical_loss: 1.5849 - val_x_pred_review_loss: 4.4840 - val_x_pred_coordinates_loss: -7.2594
# Epoch 16/50
# 174565/174565 [==============================] - 10s 58us/step - loss: 1.7302 - x_pred_binary_loss: 0.4395 - x_pred_categorical_loss: 1.9162 - x_pred_review_loss: 3.2957 - x_pred_coordinates_loss: -6.5191 - val_loss: 1.3354 - val_x_pred_binary_loss: 0.1588 - val_x_pred_categorical_loss: 1.4271 - val_x_pred_review_loss: 4.3884 - val_x_pred_coordinates_loss: -7.0965
# Epoch 17/50
# 174565/174565 [==============================] - 9s 49us/step - loss: 1.6888 - x_pred_binary_loss: 0.4394 - x_pred_categorical_loss: 1.9154 - x_pred_review_loss: 3.2950 - x_pred_coordinates_loss: -6.6042 - val_loss: 0.7474 - val_x_pred_binary_loss: 0.1850 - val_x_pred_categorical_loss: 1.9002 - val_x_pred_review_loss: 4.0994 - val_x_pred_coordinates_loss: -7.9692
# Epoch 18/50
# 174565/174565 [==============================] - 8s 47us/step - loss: 1.6449 - x_pred_binary_loss: 0.4392 - x_pred_categorical_loss: 1.9111 - x_pred_review_loss: 3.3118 - x_pred_coordinates_loss: -6.6951 - val_loss: 0.4652 - val_x_pred_binary_loss: 0.1724 - val_x_pred_categorical_loss: 1.5569 - val_x_pred_review_loss: 4.4379 - val_x_pred_coordinates_loss: -8.2737
# Epoch 19/50
# 174565/174565 [==============================] - 9s 50us/step - loss: 1.6022 - x_pred_binary_loss: 0.4391 - x_pred_categorical_loss: 1.9121 - x_pred_review_loss: 3.3295 - x_pred_coordinates_loss: -6.7846 - val_loss: 1.4662 - val_x_pred_binary_loss: 0.1623 - val_x_pred_categorical_loss: 1.2317 - val_x_pred_review_loss: 5.6365 - val_x_pred_coordinates_loss: -8.0548
# Epoch 20/50
# 174565/174565 [==============================] - 9s 49us/step - loss: 1.5262 - x_pred_binary_loss: 0.4390 - x_pred_categorical_loss: 1.9120 - x_pred_review_loss: 3.3432 - x_pred_coordinates_loss: -6.9308 - val_loss: 1.2380 - val_x_pred_binary_loss: 0.1641 - val_x_pred_categorical_loss: 1.2871 - val_x_pred_review_loss: 5.1388 - val_x_pred_coordinates_loss: -7.9191
# Epoch 21/50
# 174565/174565 [==============================] - 8s 47us/step - loss: 1.3709 - x_pred_binary_loss: 0.4392 - x_pred_categorical_loss: 1.9130 - x_pred_review_loss: 3.3111 - x_pred_coordinates_loss: -7.0708 - val_loss: 0.6162 - val_x_pred_binary_loss: 0.1729 - val_x_pred_categorical_loss: 1.4698 - val_x_pred_review_loss: 4.6534 - val_x_pred_coordinates_loss: -8.2740
# Epoch 22/50
# 174565/174565 [==============================] - 9s 53us/step - loss: 1.5669 - x_pred_binary_loss: 0.4391 - x_pred_categorical_loss: 1.9130 - x_pred_review_loss: 3.5881 - x_pred_coordinates_loss: -7.0872 - val_loss: -0.6051 - val_x_pred_binary_loss: 0.1874 - val_x_pred_categorical_loss: 1.6374 - val_x_pred_review_loss: 3.9959 - val_x_pred_coordinates_loss: -8.9434
# Epoch 23/50
# 174565/174565 [==============================] - 8s 47us/step - loss: 1.2102 - x_pred_binary_loss: 0.4392 - x_pred_categorical_loss: 1.9155 - x_pred_review_loss: 3.3070 - x_pred_coordinates_loss: -7.0865 - val_loss: 1.3295 - val_x_pred_binary_loss: 0.1981 - val_x_pred_categorical_loss: 1.8062 - val_x_pred_review_loss: 5.6805 - val_x_pred_coordinates_loss: -8.8420
# Epoch 24/50
# 174565/174565 [==============================] - 9s 53us/step - loss: 1.1395 - x_pred_binary_loss: 0.4393 - x_pred_categorical_loss: 1.9160 - x_pred_review_loss: 3.3252 - x_pred_coordinates_loss: -7.1094 - val_loss: 0.0937 - val_x_pred_binary_loss: 0.1854 - val_x_pred_categorical_loss: 1.7769 - val_x_pred_review_loss: 4.0197 - val_x_pred_coordinates_loss: -8.3999
# Epoch 25/50
# 174565/174565 [==============================] - 9s 51us/step - loss: 1.0844 - x_pred_binary_loss: 0.4391 - x_pred_categorical_loss: 1.9137 - x_pred_review_loss: 3.3170 - x_pred_coordinates_loss: -7.1128 - val_loss: -0.6184 - val_x_pred_binary_loss: 0.1743 - val_x_pred_categorical_loss: 1.6799 - val_x_pred_review_loss: 3.9249 - val_x_pred_coordinates_loss: -8.7536
# Epoch 26/50
# 174565/174565 [==============================] - 11s 62us/step - loss: 1.0686 - x_pred_binary_loss: 0.4390 - x_pred_categorical_loss: 1.9093 - x_pred_review_loss: 3.3319 - x_pred_coordinates_loss: -7.1358 - val_loss: -0.0846 - val_x_pred_binary_loss: 0.1816 - val_x_pred_categorical_loss: 1.8706 - val_x_pred_review_loss: 4.0893 - val_x_pred_coordinates_loss: -8.6814
# Epoch 27/50
# 174565/174565 [==============================] - 8s 44us/step - loss: 1.0086 - x_pred_binary_loss: 0.4395 - x_pred_categorical_loss: 1.9090 - x_pred_review_loss: 3.2972 - x_pred_coordinates_loss: -7.1455 - val_loss: -0.4622 - val_x_pred_binary_loss: 0.1690 - val_x_pred_categorical_loss: 1.3515 - val_x_pred_review_loss: 4.3912 - val_x_pred_coordinates_loss: -8.7158
# Epoch 28/50
# 174565/174565 [==============================] - 8s 44us/step - loss: 0.9584 - x_pred_binary_loss: 0.4392 - x_pred_categorical_loss: 1.9114 - x_pred_review_loss: 3.2936 - x_pred_coordinates_loss: -7.1527 - val_loss: -0.4189 - val_x_pred_binary_loss: 0.1687 - val_x_pred_categorical_loss: 1.5302 - val_x_pred_review_loss: 4.2912 - val_x_pred_coordinates_loss: -8.6872
# Epoch 29/50
# 174565/174565 [==============================] - 8s 44us/step - loss: 0.9357 - x_pred_binary_loss: 0.4389 - x_pred_categorical_loss: 1.9153 - x_pred_review_loss: 3.2931 - x_pred_coordinates_loss: -7.1562 - val_loss: 0.5807 - val_x_pred_binary_loss: 0.1763 - val_x_pred_categorical_loss: 1.3791 - val_x_pred_review_loss: 4.5891 - val_x_pred_coordinates_loss: -7.7923
# Epoch 30/50
# 174565/174565 [==============================] - 7s 43us/step - loss: 1.1803 - x_pred_binary_loss: 0.4385 - x_pred_categorical_loss: 1.9140 - x_pred_review_loss: 3.5386 - x_pred_coordinates_loss: -7.1391 - val_loss: 0.6895 - val_x_pred_binary_loss: 0.1734 - val_x_pred_categorical_loss: 1.2526 - val_x_pred_review_loss: 5.0117 - val_x_pred_coordinates_loss: -7.9672
# Epoch 31/50
# 174565/174565 [==============================] - 8s 48us/step - loss: 0.9417 - x_pred_binary_loss: 0.4383 - x_pred_categorical_loss: 1.9141 - x_pred_review_loss: 3.2628 - x_pred_coordinates_loss: -7.1206 - val_loss: -0.8519 - val_x_pred_binary_loss: 0.1985 - val_x_pred_categorical_loss: 1.5612 - val_x_pred_review_loss: 4.0036 - val_x_pred_coordinates_loss: -8.8937
# Epoch 32/50
# 174565/174565 [==============================] - 7s 42us/step - loss: 0.9220 - x_pred_binary_loss: 0.4381 - x_pred_categorical_loss: 1.9155 - x_pred_review_loss: 3.2530 - x_pred_coordinates_loss: -7.1322 - val_loss: 1.3117 - val_x_pred_binary_loss: 0.1868 - val_x_pred_categorical_loss: 1.6854 - val_x_pred_review_loss: 4.0128 - val_x_pred_coordinates_loss: -6.7769
# Epoch 33/50
# 174565/174565 [==============================] - 8s 44us/step - loss: 0.9396 - x_pred_binary_loss: 0.4373 - x_pred_categorical_loss: 1.9138 - x_pred_review_loss: 3.2817 - x_pred_coordinates_loss: -7.1059 - val_loss: -0.6703 - val_x_pred_binary_loss: 0.1859 - val_x_pred_categorical_loss: 1.7637 - val_x_pred_review_loss: 4.0027 - val_x_pred_coordinates_loss: -8.8172
# Epoch 34/50
# 174565/174565 [==============================] - 10s 55us/step - loss: 0.9564 - x_pred_binary_loss: 0.4364 - x_pred_categorical_loss: 1.9105 - x_pred_review_loss: 3.2746 - x_pred_coordinates_loss: -7.0799 - val_loss: 0.6810 - val_x_pred_binary_loss: 0.1735 - val_x_pred_categorical_loss: 1.6390 - val_x_pred_review_loss: 4.2545 - val_x_pred_coordinates_loss: -7.6184
# Epoch 35/50
# 174565/174565 [==============================] - 8s 44us/step - loss: 0.9727 - x_pred_binary_loss: 0.4362 - x_pred_categorical_loss: 1.9077 - x_pred_review_loss: 3.3164 - x_pred_coordinates_loss: -7.0807 - val_loss: 1.7717 - val_x_pred_binary_loss: 0.1924 - val_x_pred_categorical_loss: 1.9318 - val_x_pred_review_loss: 5.8818 - val_x_pred_coordinates_loss: -8.5110
# Epoch 36/50
# 174565/174565 [==============================] - 8s 47us/step - loss: 0.9461 - x_pred_binary_loss: 0.4363 - x_pred_categorical_loss: 1.9102 - x_pred_review_loss: 3.3057 - x_pred_coordinates_loss: -7.0838 - val_loss: -0.3089 - val_x_pred_binary_loss: 0.2052 - val_x_pred_categorical_loss: 1.6524 - val_x_pred_review_loss: 3.7969 - val_x_pred_coordinates_loss: -8.2092
# Epoch 37/50
# 174565/174565 [==============================] - 7s 42us/step - loss: 0.9360 - x_pred_binary_loss: 0.4369 - x_pred_categorical_loss: 1.9109 - x_pred_review_loss: 3.3370 - x_pred_coordinates_loss: -7.0846 - val_loss: -0.3950 - val_x_pred_binary_loss: 0.1843 - val_x_pred_categorical_loss: 1.3820 - val_x_pred_review_loss: 4.4219 - val_x_pred_coordinates_loss: -8.4194
# Epoch 38/50
# 174565/174565 [==============================] - 8s 47us/step - loss: 1.3143 - x_pred_binary_loss: 0.4379 - x_pred_categorical_loss: 1.9113 - x_pred_review_loss: 3.7395 - x_pred_coordinates_loss: -7.0975 - val_loss: -0.8663 - val_x_pred_binary_loss: 0.1972 - val_x_pred_categorical_loss: 1.5473 - val_x_pred_review_loss: 3.9303 - val_x_pred_coordinates_loss: -8.5353
# Epoch 39/50
# 174565/174565 [==============================] - 7s 42us/step - loss: 0.9154 - x_pred_binary_loss: 0.4396 - x_pred_categorical_loss: 1.9066 - x_pred_review_loss: 3.3385 - x_pred_coordinates_loss: -7.1032 - val_loss: -0.4577 - val_x_pred_binary_loss: 0.1850 - val_x_pred_categorical_loss: 1.4926 - val_x_pred_review_loss: 3.9744 - val_x_pred_coordinates_loss: -8.1395
# Epoch 40/50
# 174565/174565 [==============================] - 8s 45us/step - loss: 0.8876 - x_pred_binary_loss: 0.4389 - x_pred_categorical_loss: 1.9119 - x_pred_review_loss: 3.2652 - x_pred_coordinates_loss: -7.1233 - val_loss: -0.9065 - val_x_pred_binary_loss: 0.1859 - val_x_pred_categorical_loss: 1.6533 - val_x_pred_review_loss: 3.8180 - val_x_pred_coordinates_loss: -8.6993
# Epoch 41/50
# 174565/174565 [==============================] - 7s 43us/step - loss: 0.9199 - x_pred_binary_loss: 0.4389 - x_pred_categorical_loss: 1.9137 - x_pred_review_loss: 3.2864 - x_pred_coordinates_loss: -7.1112 - val_loss: -0.5592 - val_x_pred_binary_loss: 0.1833 - val_x_pred_categorical_loss: 1.5110 - val_x_pred_review_loss: 4.0141 - val_x_pred_coordinates_loss: -8.5060
# Epoch 42/50
# 174565/174565 [==============================] - 7s 39us/step - loss: 0.8932 - x_pred_binary_loss: 0.4384 - x_pred_categorical_loss: 1.9138 - x_pred_review_loss: 3.2414 - x_pred_coordinates_loss: -7.0975 - val_loss: 1.3692 - val_x_pred_binary_loss: 0.1354 - val_x_pred_categorical_loss: 1.2621 - val_x_pred_review_loss: 5.8169 - val_x_pred_coordinates_loss: -8.0006
# Epoch 43/50
# 174565/174565 [==============================] - 8s 43us/step - loss: 0.9037 - x_pred_binary_loss: 0.4391 - x_pred_categorical_loss: 1.9163 - x_pred_review_loss: 3.2449 - x_pred_coordinates_loss: -7.1069 - val_loss: -0.1533 - val_x_pred_binary_loss: 0.1790 - val_x_pred_categorical_loss: 1.6093 - val_x_pred_review_loss: 3.9787 - val_x_pred_coordinates_loss: -8.0969
# Epoch 44/50
# 174565/174565 [==============================] - 7s 40us/step - loss: 0.8877 - x_pred_binary_loss: 0.4389 - x_pred_categorical_loss: 1.9125 - x_pred_review_loss: 3.2778 - x_pred_coordinates_loss: -7.1080 - val_loss: 0.8029 - val_x_pred_binary_loss: 0.1612 - val_x_pred_categorical_loss: 1.3541 - val_x_pred_review_loss: 4.8691 - val_x_pred_coordinates_loss: -7.7704
# Epoch 45/50
# 174565/174565 [==============================] - 7s 40us/step - loss: 0.9300 - x_pred_binary_loss: 0.4389 - x_pred_categorical_loss: 1.9167 - x_pred_review_loss: 3.2921 - x_pred_coordinates_loss: -7.0718 - val_loss: -0.0876 - val_x_pred_binary_loss: 0.1736 - val_x_pred_categorical_loss: 1.5586 - val_x_pred_review_loss: 4.4679 - val_x_pred_coordinates_loss: -8.3758
# Epoch 46/50
# 174565/174565 [==============================] - 8s 48us/step - loss: 0.8967 - x_pred_binary_loss: 0.4390 - x_pred_categorical_loss: 1.9136 - x_pred_review_loss: 3.2811 - x_pred_coordinates_loss: -7.0870 - val_loss: -0.6725 - val_x_pred_binary_loss: 0.1902 - val_x_pred_categorical_loss: 1.7353 - val_x_pred_review_loss: 3.8335 - val_x_pred_coordinates_loss: -8.5273
# Epoch 47/50
# 174565/174565 [==============================] - 11s 66us/step - loss: 0.9136 - x_pred_binary_loss: 0.4384 - x_pred_categorical_loss: 1.9127 - x_pred_review_loss: 3.2469 - x_pred_coordinates_loss: -7.0729 - val_loss: -0.6034 - val_x_pred_binary_loss: 0.1934 - val_x_pred_categorical_loss: 1.7918 - val_x_pred_review_loss: 3.6930 - val_x_pred_coordinates_loss: -8.4321
# Epoch 48/50
# 174565/174565 [==============================] - 8s 44us/step - loss: 0.8835 - x_pred_binary_loss: 0.4375 - x_pred_categorical_loss: 1.9111 - x_pred_review_loss: 3.2337 - x_pred_coordinates_loss: -7.0957 - val_loss: 1.8195 - val_x_pred_binary_loss: 0.1825 - val_x_pred_categorical_loss: 1.4280 - val_x_pred_review_loss: 4.1492 - val_x_pred_coordinates_loss: -6.0930
# Epoch 49/50
# 174565/174565 [==============================] - 6s 35us/step - loss: 0.9170 - x_pred_binary_loss: 0.4380 - x_pred_categorical_loss: 1.9121 - x_pred_review_loss: 3.2874 - x_pred_coordinates_loss: -7.0840 - val_loss: -0.4900 - val_x_pred_binary_loss: 0.1828 - val_x_pred_categorical_loss: 1.5682 - val_x_pred_review_loss: 3.9818 - val_x_pred_coordinates_loss: -8.3552
# Epoch 50/50
# 174565/174565 [==============================] - 7s 39us/step - loss: 5.8285 - x_pred_binary_loss: 0.4380 - x_pred_categorical_loss: 1.9141 - x_pred_review_loss: 8.2413 - x_pred_coordinates_loss: -7.1176 - val_loss: -0.6395 - val_x_pred_binary_loss: 0.1803 - val_x_pred_categorical_loss: 1.5390 - val_x_pred_review_loss: 4.1218 - val_x_pred_coordinates_loss: -8.4567

# %% [markdown]
# ## Building the Decoder

# %%
decode_input = Input(shape=(latent_dim, ), name = 'decode_input')
decode_layer_1 = decode_1(decode_input)
decode_layer_2 = decode_2(decode_layer_1)

x_pred_coordinates_mu = x_pred_coordinates_mu_layer(decode_layer_2)
x_pred_coordinates_log_var = x_pred_coordinates_log_var_layer(decode_layer_2)
decode_x_pred_coordinates = x_pred_coordinates_layer([x_pred_coordinates_mu, x_pred_coordinates_log_var])

x_pred_review_mu = x_pred_review_mu_layer(decode_layer_2)
x_pred_review_log_var = x_pred_review_log_var_layer(decode_layer_2)
decode_x_pred_review = x_pred_review_layer([x_pred_review_mu, x_pred_review_log_var])

decode_x_pred_binary = x_pred_binary_layer(decode_layer_2) # binary cross entropy
decode_x_pred_categorical = x_pred_categorical_layer(decode_layer_2) # categorical cross entropy


decoder = Model(decode_input, [decode_x_pred_coordinates, decode_x_pred_review, decode_x_pred_categorical, decode_x_pred_binary])

# %%
SVG(model_to_dot(decoder, show_shapes=True)
    .create(prog='dot', format='svg'))

# %% [markdown]
# ### Saving the Models and Metadata
# #### Saving Models (Actually, only the decoder matter)

# %%
model_json = vae.to_json()
with open("./model/vae_full_model.json", "w") as json_file:
    json_file.write(model_json)
vae.save_weights("./model/vae_full_model.h5")
print("Saved model to disk")

encoder = Model(x, [z_mu, z_log_var])
model_json = encoder.to_json()
with open("./model/vae_encoder.json", "w") as json_file:
    json_file.write(model_json)
encoder.save_weights("./model/vae_encoder.h5")
print("Saved model to disk")

model_json = decoder.to_json()
with open("./model/vae_decoder.json", "w") as json_file:
    json_file.write(model_json)
decoder.save_weights("./model/vae_decoder.h5")
print("Saved model to disk")
# Out:
# Saved model to disk
# Saved model to disk
# Saved model to disk

# %% [markdown]
# #### Generating and Saving Metadata

# %%
vae_sample = train_dataset[np.random.choice(len(train_dataset), size=10000, replace=False)]
vae_sample_mu, vae_sample_log_var = encoder.predict(vae_sample, batch_size=batch_size)
np.save('./model/sample_mu.npy', vae_sample_mu)
np.save('./model/sample_log_var.npy', vae_sample_log_var)

# %% [markdown]
# ### Generating some Samples for Testing
# #### Functions for data generation

# %%
reverse_categorical_map = {0:0, 1:0.5, 2:1, 3:1.5, 4:2, 5:2.5, 6:3, 7:3.5, 8:4, 9:4.5, 10:5}
def sample(model, input_mu, input_log_var):
    eps = np.random.normal(size=(input_mu.shape[0], latent_dim))
    z = reparameterize(input_mu, input_log_var, eps)
    predictions = model.predict(z, batch_size = None, steps = 1)
    return reconstruct(predictions)
    
def reconstruct(predictions):
    coordinates, review, categorical, binary = predictions
    mu, log_var = np.split(coordinates, indices_or_sections = 2,axis = 1)
    eps = np.random.normal(size=mu.shape)
    coordinates_data = reparameterize(mu, log_var, eps)
    print(coordinates_data)
    for i, c in enumerate(coordinates_data):
        if c[0] > 1.0:
            coordinates_data[i][0]=1.0
        if c[0] < 0.0:
            coordinates_data[i][0]=0.0
        if c[1] > 1.0:
            coordinates_data[i][1]=1.0
        if c[1] < 0.0:
            coordinates_data[i][1]=0.0
        coordinates_data[i][0] = (coordinates_data[i][0]*360)-180
        coordinates_data[i][1] = (coordinates_data[i][1]*360)-180
    mu2, log_var2 = np.split(review, indices_or_sections = 2,axis = 1)
    eps2 = np.random.normal(size=mu2.shape)
    review_data = reparameterize(mu2, log_var2, eps2)
    for i, r in enumerate(review_data):
        if r[0] < 0:
            review_data[i][0] = 0
        review_data[i][0] = float(int(review_data[i][0]))
    categorical = np.apply_along_axis(lambda t : np.random.multinomial(1,t), -1, categorical)
    categorical = np.apply_along_axis(lambda t : np.argmax(t), -1, categorical)
    categorical = np.expand_dims(categorical, axis = -1)
    categorical_data = np.apply_along_axis(lambda t : float(reverse_categorical_map[t[0]]), -1, categorical)
    categorical_data = np.expand_dims(categorical_data, axis = -1)
    binary_data = np.apply_along_axis(lambda t: np.random.binomial(1, t), -1, binary)
#     coordinates, reviews = np.split(continuous_data, indices_or_sections=[2], axis = 1)
    return np.concatenate([coordinates_data, categorical_data, review_data, binary_data], axis = 1)
    

def reparameterize(input_mu, input_log_var, eps):
    sigma = np.exp(0.5*input_log_var)
    return eps*sigma + input_mu

# %%
vae_samples = sample(decoder, vae_sample_mu, vae_sample_log_var)
file_name = './samples/vae_2_sample_' + str(len(vae_samples)) + '.csv'
np.savetxt(file_name, vae_samples, delimiter = ',', header='latitude,longitude,stars,review_count,is_open')
# Out:
# [[0.61239198 0.28302699]
#  [0.61246168 0.2729114 ]
#  [0.61217445 0.27658687]
#  ...
#  [0.61445705 0.26456331]
#  [0.59640373 0.18094593]
#  [0.60081799 0.28279818]]
