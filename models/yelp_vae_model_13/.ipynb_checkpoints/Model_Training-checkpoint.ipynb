# %% [markdown]
# # Model Training
# In this notebook, we will train our VAE model. This involves:
#
# 1. Encoder
# 2. Decoder
# 3. Full Model

# %% [markdown]
# ## Importing Packages
# We will be using Keras to build and train our VAE

# %%
from __future__ import absolute_import, division, print_function, unicode_literals
# %matplotlib notebook
import tensorflow as tf

import os
import time
import numpy as np
import glob
import matplotlib.pyplot as plt
import PIL
import imageio
import h5py

import keras
from keras import backend as K
from keras.layers import Input, Dense, Lambda, Layer, Add, Multiply, Concatenate
from keras.models import Model, Sequential
from keras.utils import to_categorical
from keras.models import model_from_json

from IPython import display
import numpy as np
import pandas as pd

from matplotlib.ticker import FormatStrFormatter
from keras.utils.vis_utils import model_to_dot, plot_model
from IPython.display import SVG
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ## Definition of Constants
# Hyper parameters and constants will all be located here for ease of adjustments

# %%
categorical_dim = 11
categorical_map = {0:0, 0.5:1, 1: 2, 1.5:3, 2:4, 2.5:5, 3:6, 3.5:7, 4:8, 4.5:9, 5:10}
reverse_categorical_map = {0:0, 1:0.5, 2:1, 3:1.5, 4:2, 5:2.5, 6:3, 7:3.5, 8:4, 9:4.5, 10:5}
continuous_dim = 3
binary_dim = 1
original_dim = binary_dim + continuous_dim + categorical_dim
intermediate_dim_1 = 12
intermediate_dim_2 = 8
latent_dim = 4
batch_size = 100
epochs = 50
epsilon_std = 1.0

# %% [markdown]
# ## Building the Model
# We have to write our own custom layer and custom loss function as these are not supported on Keras natively. There are a few things to be done:
#
# 1. Custom KLDivergence Layer
# 2. Custom Loss Functions
# 3. Building the Model

# %% [markdown]
# ### KL Divergence Layer
# To ensure modularity, we decided to create a separate layer for KL Divergence. This layer will account for the loss required.

# %%
class KLDivergenceLayer(Layer):

    """ Identity transform layer that adds KL divergence
    to the final model loss.
    """

    def __init__(self, *args, **kwargs):
        self.is_placeholder = True
        super(KLDivergenceLayer, self).__init__(*args, **kwargs)

    def call(self, inputs):

        mu, log_var = inputs

        kl_batch = - .5 * K.sum(1 + log_var -
                                K.square(mu) -
                                K.exp(log_var), axis=-1)

        self.add_loss(K.mean(kl_batch), inputs=inputs)

        return inputs

# %% [markdown]
# ### Custom Loss Functions
# As the yelp dataset contains binary, categorical as well as continuous data, we will build 3 custom loss functions.
#
# #### Binary Loss Function

# %%
def binary_loss(y_true, y_pred):
	# input dimension is (batchsize, 1)
    return K.binary_crossentropy(y_true, y_pred) # the dimension of return value is (batchsize , 1)

# %% [markdown]
# #### Categorical Loss Function

# %%
def categorical_loss(y_true, y_pred):
	# input dimension is (batchsize, number of categories)
  return K.categorical_crossentropy(y_true, y_pred) # the dimension of return value is (batchsize , 1)

# %% [markdown]
# #### Continuous Loss Function

# %%
def log_normal_pdf(sample, mean, logvar, raxis=1):
  log2pi = tf.math.log(2. * np.pi)
  return tf.reduce_sum(
      -.5 * ((sample - mean) ** 2. * tf.exp(-logvar) + logvar + log2pi),
      axis=raxis) # return a tensor of shape (batch_size, 1)

def continuous_loss(y_true, y_pred):
	# need to return log probability for continuous loss.
	# will get a (batchsize, 6 continuous variable input) where 3 of the 6 represents mu and the others logvar
	# y_true will be (batchsize, 3)
  mu, logvar = tf.split(y_pred, num_or_size_splits = 2, axis = 1)
  return -1 * log_normal_pdf(y_true, mu, logvar)

# %% [markdown]
# ### Model Architecture
# - tanh/sigmoid is used because Relu resulted in loss going to infinity

# %%
x = Input(shape=(original_dim,), name='input_x')
h = Dense(intermediate_dim_1, activation='tanh', name='hidden_enc_1')(x)
h = Dense(intermediate_dim_2, activation='tanh', name='hidden_enc_2')(h)

z_mu = Dense(latent_dim, name='z_mu')(h)
z_log_var = Dense(latent_dim, name='z_log_var')(h)

z_mu, z_log_var = KLDivergenceLayer(name='KL_Divergence')([z_mu, z_log_var])
z_sigma = Lambda(lambda t: K.exp(.5*t))(z_log_var)

eps = Input(name='input_eps',tensor=K.random_normal(stddev=epsilon_std,
                                   shape=(K.shape(x)[0], latent_dim)))
z_eps = Multiply()([z_sigma, eps])
z = Add()([z_mu, z_eps])

decode_1 = Dense(intermediate_dim_2, activation='tanh', name='hidden_dec_2')
h_dec = decode_1(z)

decode_2 = Dense(intermediate_dim_1, activation='tanh', name='hidden_dec_1')
h_dec = decode_2(h_dec)

x_pred_coordinates_mu_layer = Dense(2, activation='sigmoid',name='x_pred_coordinates_mu')
x_pred_coordinates_mu = x_pred_coordinates_mu_layer(h_dec)

x_pred_coordinates_log_var_layer = Dense(2, name='x_pred_coordinates_log_var')
x_pred_coordinates_log_var = x_pred_coordinates_log_var_layer(h_dec)

x_pred_coordinates_layer = Concatenate(axis=-1, name = 'x_pred_coordinates')
x_pred_coordinates = x_pred_coordinates_layer([x_pred_coordinates_mu, x_pred_coordinates_log_var])

x_pred_review_mu_layer = Dense(1, activation='relu', name='x_pred_review_mu')
x_pred_review_mu = x_pred_review_mu_layer(h_dec)

x_pred_review_log_var_layer = Dense(1, name='x_pred_review_log_var')
x_pred_review_log_var = x_pred_review_log_var_layer(h_dec)

x_pred_review_layer = Concatenate(axis=-1, name = 'x_pred_review')
x_pred_review = x_pred_review_layer([x_pred_review_mu, x_pred_review_log_var])

x_pred_binary_layer = Dense(binary_dim, activation='sigmoid', name='x_pred_binary')
x_pred_binary = x_pred_binary_layer(h_dec) # binary cross entropy

x_pred_categorical_layer = Dense(categorical_dim, activation='softmax', name='x_pred_categorical')
x_pred_categorical = x_pred_categorical_layer(h_dec) # categorical cross entropy

vae = Model(inputs=[x,eps], outputs=[x_pred_binary, x_pred_categorical, x_pred_review, x_pred_coordinates])

# %%
SVG(model_to_dot(vae, show_shapes=True)
    .create(prog='dot', format='svg'))

# %%
plot_model(
    model=vae, show_shapes=True,
    to_file='./description/vae_full_model.png'
)

# %% [markdown]
# ### Compiling Model and Setting Parameters

# %%
optimizer = keras.optimizers.Adam(lr=0.0001,clipvalue=1)
vae.compile(optimizer=optimizer, loss=[binary_loss, categorical_loss, continuous_loss, continuous_loss], loss_weights=[1, 1, 1, 1])

# %%
vae.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_x (InputLayer)            (None, 15)           0
# __________________________________________________________________________________________________
# hidden_enc_1 (Dense)            (None, 12)           192         input_x[0][0]
# __________________________________________________________________________________________________
# hidden_enc_2 (Dense)            (None, 8)            104         hidden_enc_1[0][0]
# __________________________________________________________________________________________________
# z_mu (Dense)                    (None, 4)            36          hidden_enc_2[0][0]
# __________________________________________________________________________________________________
# z_log_var (Dense)               (None, 4)            36          hidden_enc_2[0][0]
# __________________________________________________________________________________________________
# KL_Divergence (KLDivergenceLaye [(None, 4), (None, 4 0           z_mu[0][0]
#                                                                  z_log_var[0][0]
# __________________________________________________________________________________________________
# lambda_1 (Lambda)               (None, 4)            0           KL_Divergence[0][1]
# __________________________________________________________________________________________________
# input_eps (InputLayer)          (None, 4)            0
# __________________________________________________________________________________________________
# multiply_1 (Multiply)           (None, 4)            0           lambda_1[0][0]
#                                                                  input_eps[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 4)            0           KL_Divergence[0][0]
#                                                                  multiply_1[0][0]
# __________________________________________________________________________________________________
# hidden_dec_2 (Dense)            (None, 8)            40          add_1[0][0]
# __________________________________________________________________________________________________
# hidden_dec_1 (Dense)            (None, 12)           108         hidden_dec_2[0][0]
# __________________________________________________________________________________________________
# x_pred_review_mu (Dense)        (None, 1)            13          hidden_dec_1[0][0]
# __________________________________________________________________________________________________
# x_pred_review_log_var (Dense)   (None, 1)            13          hidden_dec_1[0][0]
# __________________________________________________________________________________________________
# x_pred_coordinates_mu (Dense)   (None, 2)            26          hidden_dec_1[0][0]
# __________________________________________________________________________________________________
# x_pred_coordinates_log_var (Den (None, 2)            26          hidden_dec_1[0][0]
# __________________________________________________________________________________________________
# x_pred_binary (Dense)           (None, 1)            13          hidden_dec_1[0][0]
# __________________________________________________________________________________________________
# x_pred_categorical (Dense)      (None, 11)           143         hidden_dec_1[0][0]
# __________________________________________________________________________________________________
# x_pred_review (Concatenate)     (None, 2)            0           x_pred_review_mu[0][0]
#                                                                  x_pred_review_log_var[0][0]
# __________________________________________________________________________________________________
# x_pred_coordinates (Concatenate (None, 4)            0           x_pred_coordinates_mu[0][0]
#                                                                  x_pred_coordinates_log_var[0][0]
# ==================================================================================================
# Total params: 750
# Trainable params: 750
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# ## Data Loading and Preprocessing

# %%
dataset = np.genfromtxt('./samples/yelp_business.csv',delimiter=',',skip_header=1)
dataset = dataset[~np.isnan(dataset).any(axis=1)]
test_set, train_set = np.split(dataset,[1], axis = 0)

def format_data(dataset):
  # handling the categorical variables
  coordinates, ratings, reviews, is_opens = np.split(dataset, [2, 3, 4], axis = 1)
  one_hot_array = np.zeros((ratings.shape[0], categorical_dim))

  for i, r in enumerate(ratings):
    one_hot_array[i][categorical_map[r[0]]] = 1
  
  for i, c in enumerate(coordinates):
    coordinates[i][0] = (c[0]+180)/360
    coordinates[i][1] = (c[1]+180)/360

  dataset = np.concatenate((coordinates, reviews, is_opens, one_hot_array), axis = 1)

  # creating the labels
  coordinates_labels = coordinates
  review_labels = reviews
  categorical_labels = one_hot_array
  binary_labels = is_opens
  return dataset, coordinates_labels, review_labels, categorical_labels, binary_labels

train_dataset, train_coordinates_labels, train_review_labels, train_categorical_labels, train_binary_labels = format_data(train_set)
test_dataset, test_coordinates_labels, test_review_labels, test_categorical_labels, test_binary_labels = format_data(test_set)

# %% [markdown]
# ## Training the Model

# %%
vae.fit(train_dataset , [train_binary_labels, train_categorical_labels, train_review_labels, train_coordinates_labels], shuffle = True, epochs = epochs, batch_size = batch_size, validation_data=(test_dataset , [test_binary_labels, test_categorical_labels, test_review_labels, test_coordinates_labels]))
# Out:
# Train on 174565 samples, validate on 1 samples
# Epoch 1/50
# 174565/174565 [==============================] - 6s 36us/step - loss: 1.1728 - x_pred_binary_loss: 0.4382 - x_pred_categorical_loss: 1.9414 - x_pred_review_loss: 3.6658 - x_pred_coordinates_loss: -7.0754 - val_loss: -0.5389 - val_x_pred_binary_loss: 0.1831 - val_x_pred_categorical_loss: 1.6237 - val_x_pred_review_loss: 3.9297 - val_x_pred_coordinates_loss: -8.3355
# Epoch 2/50
# 174565/174565 [==============================] - 10s 56us/step - loss: 1.1436 - x_pred_binary_loss: 0.4382 - x_pred_categorical_loss: 1.9424 - x_pred_review_loss: 3.5980 - x_pred_coordinates_loss: -7.0783 - val_loss: -1.0723 - val_x_pred_binary_loss: 0.1905 - val_x_pred_categorical_loss: 1.6199 - val_x_pred_review_loss: 3.8707 - val_x_pred_coordinates_loss: -8.9215
# Epoch 3/50
# 174565/174565 [==============================] - 8s 46us/step - loss: 1.0963 - x_pred_binary_loss: 0.4382 - x_pred_categorical_loss: 1.9432 - x_pred_review_loss: 3.5287 - x_pred_coordinates_loss: -7.0953 - val_loss: 1.0198 - val_x_pred_binary_loss: 0.1874 - val_x_pred_categorical_loss: 1.8729 - val_x_pred_review_loss: 4.6395 - val_x_pred_coordinates_loss: -7.9040
# Epoch 4/50
# 174565/174565 [==============================] - 11s 65us/step - loss: 1.1042 - x_pred_binary_loss: 0.4383 - x_pred_categorical_loss: 1.9429 - x_pred_review_loss: 3.4995 - x_pred_coordinates_loss: -7.0969 - val_loss: 0.2754 - val_x_pred_binary_loss: 0.1808 - val_x_pred_categorical_loss: 1.4090 - val_x_pred_review_loss: 4.5311 - val_x_pred_coordinates_loss: -8.1433
# Epoch 5/50
# 174565/174565 [==============================] - 13s 76us/step - loss: 1.1788 - x_pred_binary_loss: 0.4383 - x_pred_categorical_loss: 1.9437 - x_pred_review_loss: 3.5678 - x_pred_coordinates_loss: -7.0972 - val_loss: 0.4977 - val_x_pred_binary_loss: 0.1876 - val_x_pred_categorical_loss: 1.8659 - val_x_pred_review_loss: 4.7957 - val_x_pred_coordinates_loss: -8.6614
# Epoch 6/50
# 174565/174565 [==============================] - 9s 50us/step - loss: 1.0514 - x_pred_binary_loss: 0.4383 - x_pred_categorical_loss: 1.9444 - x_pred_review_loss: 3.4508 - x_pred_coordinates_loss: -7.1047 - val_loss: -0.6288 - val_x_pred_binary_loss: 0.1905 - val_x_pred_categorical_loss: 1.6289 - val_x_pred_review_loss: 3.7912 - val_x_pred_coordinates_loss: -8.5544
# Epoch 7/50
# 174565/174565 [==============================] - 8s 47us/step - loss: 1.0313 - x_pred_binary_loss: 0.4382 - x_pred_categorical_loss: 1.9435 - x_pred_review_loss: 3.4302 - x_pred_coordinates_loss: -7.1254 - val_loss: -0.6054 - val_x_pred_binary_loss: 0.1896 - val_x_pred_categorical_loss: 1.7273 - val_x_pred_review_loss: 3.8479 - val_x_pred_coordinates_loss: -8.7207
# Epoch 8/50
# 174565/174565 [==============================] - 14s 78us/step - loss: 1.0378 - x_pred_binary_loss: 0.4382 - x_pred_categorical_loss: 1.9434 - x_pred_review_loss: 3.4323 - x_pred_coordinates_loss: -7.1248 - val_loss: -0.2764 - val_x_pred_binary_loss: 0.1850 - val_x_pred_categorical_loss: 1.5551 - val_x_pred_review_loss: 3.9192 - val_x_pred_coordinates_loss: -8.2160
# Epoch 9/50
# 174565/174565 [==============================] - 9s 52us/step - loss: 1.0515 - x_pred_binary_loss: 0.4381 - x_pred_categorical_loss: 1.9435 - x_pred_review_loss: 3.4313 - x_pred_coordinates_loss: -7.1000 - val_loss: -0.2804 - val_x_pred_binary_loss: 0.1829 - val_x_pred_categorical_loss: 1.5985 - val_x_pred_review_loss: 3.8627 - val_x_pred_coordinates_loss: -8.2130
# Epoch 10/50
# 174565/174565 [==============================] - 11s 65us/step - loss: 1.0480 - x_pred_binary_loss: 0.4381 - x_pred_categorical_loss: 1.9437 - x_pred_review_loss: 3.4221 - x_pred_coordinates_loss: -7.0992 - val_loss: -0.0214 - val_x_pred_binary_loss: 0.1824 - val_x_pred_categorical_loss: 1.5437 - val_x_pred_review_loss: 4.0059 - val_x_pred_coordinates_loss: -8.0857
# Epoch 11/50
# 174565/174565 [==============================] - 13s 72us/step - loss: 1.0309 - x_pred_binary_loss: 0.4381 - x_pred_categorical_loss: 1.9439 - x_pred_review_loss: 3.4155 - x_pred_coordinates_loss: -7.1121 - val_loss: -0.1039 - val_x_pred_binary_loss: 0.1764 - val_x_pred_categorical_loss: 1.4866 - val_x_pred_review_loss: 4.1796 - val_x_pred_coordinates_loss: -8.2899
# Epoch 12/50
# 174565/174565 [==============================] - 11s 64us/step - loss: 1.0268 - x_pred_binary_loss: 0.4381 - x_pred_categorical_loss: 1.9443 - x_pred_review_loss: 3.4076 - x_pred_coordinates_loss: -7.1001 - val_loss: -0.1775 - val_x_pred_binary_loss: 0.1782 - val_x_pred_categorical_loss: 1.5127 - val_x_pred_review_loss: 4.0902 - val_x_pred_coordinates_loss: -8.2892
# Epoch 13/50
# 174565/174565 [==============================] - 9s 52us/step - loss: 1.0225 - x_pred_binary_loss: 0.4381 - x_pred_categorical_loss: 1.9442 - x_pred_review_loss: 3.3751 - x_pred_coordinates_loss: -7.0827 - val_loss: -0.4227 - val_x_pred_binary_loss: 0.1781 - val_x_pred_categorical_loss: 1.5246 - val_x_pred_review_loss: 4.0664 - val_x_pred_coordinates_loss: -8.5110
# Epoch 14/50
# 174565/174565 [==============================] - 11s 61us/step - loss: 0.9967 - x_pred_binary_loss: 0.4381 - x_pred_categorical_loss: 1.9434 - x_pred_review_loss: 3.3560 - x_pred_coordinates_loss: -7.0992 - val_loss: -0.9873 - val_x_pred_binary_loss: 0.1841 - val_x_pred_categorical_loss: 1.6213 - val_x_pred_review_loss: 3.7495 - val_x_pred_coordinates_loss: -8.9897
# Epoch 15/50
# 174565/174565 [==============================] - 12s 69us/step - loss: 1.0255 - x_pred_binary_loss: 0.4380 - x_pred_categorical_loss: 1.9433 - x_pred_review_loss: 3.3844 - x_pred_coordinates_loss: -7.1048 - val_loss: 0.7975 - val_x_pred_binary_loss: 0.1915 - val_x_pred_categorical_loss: 1.8468 - val_x_pred_review_loss: 4.6599 - val_x_pred_coordinates_loss: -8.3407
# Epoch 16/50
# 174565/174565 [==============================] - 8s 43us/step - loss: 1.1330 - x_pred_binary_loss: 0.4384 - x_pred_categorical_loss: 1.9440 - x_pred_review_loss: 3.5049 - x_pred_coordinates_loss: -7.1152 - val_loss: -0.8148 - val_x_pred_binary_loss: 0.1849 - val_x_pred_categorical_loss: 1.6629 - val_x_pred_review_loss: 3.7431 - val_x_pred_coordinates_loss: -8.7742
# Epoch 17/50
# 174565/174565 [==============================] - 8s 44us/step - loss: 0.9944 - x_pred_binary_loss: 0.4384 - x_pred_categorical_loss: 1.9438 - x_pred_review_loss: 3.3857 - x_pred_coordinates_loss: -7.1294 - val_loss: -0.0802 - val_x_pred_binary_loss: 0.1779 - val_x_pred_categorical_loss: 1.4692 - val_x_pred_review_loss: 4.3714 - val_x_pred_coordinates_loss: -8.4842
# Epoch 18/50
# 174565/174565 [==============================] - 8s 44us/step - loss: 1.2473 - x_pred_binary_loss: 0.4383 - x_pred_categorical_loss: 1.9438 - x_pred_review_loss: 3.6400 - x_pred_coordinates_loss: -7.1310 - val_loss: 1.6486 - val_x_pred_binary_loss: 0.1416 - val_x_pred_categorical_loss: 1.2031 - val_x_pred_review_loss: 5.9167 - val_x_pred_coordinates_loss: -7.9754
# Epoch 19/50
# 174565/174565 [==============================] - 9s 54us/step - loss: 1.6422 - x_pred_binary_loss: 0.4382 - x_pred_categorical_loss: 1.9433 - x_pred_review_loss: 4.0476 - x_pred_coordinates_loss: -7.1348 - val_loss: -0.2452 - val_x_pred_binary_loss: 0.1849 - val_x_pred_categorical_loss: 1.6990 - val_x_pred_review_loss: 3.7300 - val_x_pred_coordinates_loss: -8.2858
# Epoch 20/50
# 174565/174565 [==============================] - 9s 54us/step - loss: 1.4229 - x_pred_binary_loss: 0.4382 - x_pred_categorical_loss: 1.9427 - x_pred_review_loss: 3.8295 - x_pred_coordinates_loss: -7.1309 - val_loss: -0.2197 - val_x_pred_binary_loss: 0.1804 - val_x_pred_categorical_loss: 1.5588 - val_x_pred_review_loss: 4.0007 - val_x_pred_coordinates_loss: -8.2841
# Epoch 21/50
# 174565/174565 [==============================] - 9s 54us/step - loss: 0.9881 - x_pred_binary_loss: 0.4387 - x_pred_categorical_loss: 1.9440 - x_pred_review_loss: 3.3681 - x_pred_coordinates_loss: -7.1268 - val_loss: -0.2978 - val_x_pred_binary_loss: 0.1876 - val_x_pred_categorical_loss: 1.7372 - val_x_pred_review_loss: 3.8069 - val_x_pred_coordinates_loss: -8.4000
# Epoch 22/50
# 174565/174565 [==============================] - 12s 72us/step - loss: 0.9885 - x_pred_binary_loss: 0.4386 - x_pred_categorical_loss: 1.9440 - x_pred_review_loss: 3.3403 - x_pred_coordinates_loss: -7.1096 - val_loss: -0.1509 - val_x_pred_binary_loss: 0.1810 - val_x_pred_categorical_loss: 1.5659 - val_x_pred_review_loss: 3.9161 - val_x_pred_coordinates_loss: -8.1418_loss: 0.4398 - x_pred_categorical_loss: 1.9475 - x_pred_review_loss: 3.3545 - x_pred_coordinates_l - ETA: 13s - loss: 0.9515 - x_pred_binary_loss: 0.4414 - x_pred_categorical_loss: 1.9454 - x_pred_review_loss: 3.3507 - x_pre - ETA: 12s - loss: 0.9919 - x_pred_binary_loss: 0.4422 - x_pred_categorical_loss: 1.9395 - x_pred_review_loss: 3.35 - ETA: 11s - loss: 0.9993 - x_pred_binary_loss: 0.4430 - x_pred_categorical_loss:  - ETA: 6s -
# Epoch 23/50
# 174565/174565 [==============================] - 10s 55us/step - loss: 0.9803 - x_pred_binary_loss: 0.4386 - x_pred_categorical_loss: 1.9434 - x_pred_review_loss: 3.3318 - x_pred_coordinates_loss: -7.1127 - val_loss: -0.1482 - val_x_pred_binary_loss: 0.1803 - val_x_pred_categorical_loss: 1.4569 - val_x_pred_review_loss: 4.4073 - val_x_pred_coordinates_loss: -8.5746
# Epoch 24/50
# 174565/174565 [==============================] - 6s 34us/step - loss: 0.9741 - x_pred_binary_loss: 0.4386 - x_pred_categorical_loss: 1.9432 - x_pred_review_loss: 3.3363 - x_pred_coordinates_loss: -7.1299 - val_loss: -0.0974 - val_x_pred_binary_loss: 0.1818 - val_x_pred_categorical_loss: 1.5079 - val_x_pred_review_loss: 4.1879 - val_x_pred_coordinates_loss: -8.3371
# Epoch 25/50
# 174565/174565 [==============================] - 6s 35us/step - loss: 1.1698 - x_pred_binary_loss: 0.4388 - x_pred_categorical_loss: 1.9428 - x_pred_review_loss: 3.5378 - x_pred_coordinates_loss: -7.1411 - val_loss: -0.0309 - val_x_pred_binary_loss: 0.1852 - val_x_pred_categorical_loss: 1.6023 - val_x_pred_review_loss: 3.8961 - val_x_pred_coordinates_loss: -8.0222
# Epoch 26/50
# 174565/174565 [==============================] - 6s 34us/step - loss: 4.4921 - x_pred_binary_loss: 0.4390 - x_pred_categorical_loss: 1.9430 - x_pred_review_loss: 6.8803 - x_pred_coordinates_loss: -7.1402 - val_loss: -0.2052 - val_x_pred_binary_loss: 0.1759 - val_x_pred_categorical_loss: 1.4680 - val_x_pred_review_loss: 4.5164 - val_x_pred_coordinates_loss: -8.6750
# Epoch 27/50
# 174565/174565 [==============================] - 6s 33us/step - loss: 1.0297 - x_pred_binary_loss: 0.4385 - x_pred_categorical_loss: 1.9432 - x_pred_review_loss: 3.4141 - x_pred_coordinates_loss: -7.1498 - val_loss: 0.6818 - val_x_pred_binary_loss: 0.1599 - val_x_pred_categorical_loss: 1.3071 - val_x_pred_review_loss: 5.3431 - val_x_pred_coordinates_loss: -8.4461
# Epoch 28/50
# 174565/174565 [==============================] - 6s 33us/step - loss: 1.3655 - x_pred_binary_loss: 0.4382 - x_pred_categorical_loss: 1.9430 - x_pred_review_loss: 3.7560 - x_pred_coordinates_loss: -7.1681 - val_loss: -0.9456 - val_x_pred_binary_loss: 0.1797 - val_x_pred_categorical_loss: 1.6498 - val_x_pred_review_loss: 3.7886 - val_x_pred_coordinates_loss: -8.8218
# Epoch 29/50
# 174565/174565 [==============================] - 5s 30us/step - loss: 17.0907 - x_pred_binary_loss: 0.4381 - x_pred_categorical_loss: 1.9433 - x_pred_review_loss: 19.5011 - x_pred_coordinates_loss: -7.1672 - val_loss: -0.2813 - val_x_pred_binary_loss: 0.1751 - val_x_pred_categorical_loss: 1.5443 - val_x_pred_review_loss: 4.2018 - val_x_pred_coordinates_loss: -8.5041
# Epoch 30/50
# 174565/174565 [==============================] - 5s 31us/step - loss: 1.0259 - x_pred_binary_loss: 0.4383 - x_pred_categorical_loss: 1.9439 - x_pred_review_loss: 3.4237 - x_pred_coordinates_loss: -7.1759 - val_loss: -0.1349 - val_x_pred_binary_loss: 0.1737 - val_x_pred_categorical_loss: 1.5446 - val_x_pred_review_loss: 4.1197 - val_x_pred_coordinates_loss: -8.2824 x_pred_categorical_loss: 1.9435 - x_pred_review_loss: 3.4415 - x_pred_coordinates_loss: - ETA: 3s - loss: 1
# Epoch 31/50
# 174565/174565 [==============================] - 5s 31us/step - loss: 1.0104 - x_pred_binary_loss: 0.4384 - x_pred_categorical_loss: 1.9428 - x_pred_review_loss: 3.4020 - x_pred_coordinates_loss: -7.1785 - val_loss: 0.6472 - val_x_pred_binary_loss: 0.1872 - val_x_pred_categorical_loss: 1.8150 - val_x_pred_review_loss: 4.0989 - val_x_pred_coordinates_loss: -7.8437
# Epoch 32/50
# 174565/174565 [==============================] - 5s 31us/step - loss: 1.2401 - x_pred_binary_loss: 0.4379 - x_pred_categorical_loss: 1.9432 - x_pred_review_loss: 3.6172 - x_pred_coordinates_loss: -7.1582 - val_loss: -0.2260 - val_x_pred_binary_loss: 0.1721 - val_x_pred_categorical_loss: 1.5318 - val_x_pred_review_loss: 4.2087 - val_x_pred_coordinates_loss: -8.5314
# Epoch 33/50
# 174565/174565 [==============================] - 6s 36us/step - loss: 1.0102 - x_pred_binary_loss: 0.4380 - x_pred_categorical_loss: 1.9436 - x_pred_review_loss: 3.3885 - x_pred_coordinates_loss: -7.1790 - val_loss: 0.0460 - val_x_pred_binary_loss: 0.1805 - val_x_pred_categorical_loss: 1.6826 - val_x_pred_review_loss: 3.7186 - val_x_pred_coordinates_loss: -7.9652
# Epoch 34/50
# 174565/174565 [==============================] - 11s 63us/step - loss: 0.9965 - x_pred_binary_loss: 0.4382 - x_pred_categorical_loss: 1.9432 - x_pred_review_loss: 3.3608 - x_pred_coordinates_loss: -7.1794 - val_loss: -0.1565 - val_x_pred_binary_loss: 0.1793 - val_x_pred_categorical_loss: 1.5654 - val_x_pred_review_loss: 4.0009 - val_x_pred_coordinates_loss: -8.3848
# Epoch 35/50
# 174565/174565 [==============================] - 11s 66us/step - loss: 1.0932 - x_pred_binary_loss: 0.4382 - x_pred_categorical_loss: 1.9442 - x_pred_review_loss: 3.4741 - x_pred_coordinates_loss: -7.1898 - val_loss: -0.8895 - val_x_pred_binary_loss: 0.1787 - val_x_pred_categorical_loss: 1.6589 - val_x_pred_review_loss: 3.6861 - val_x_pred_coordinates_loss: -8.8894
# Epoch 36/50
# 174565/174565 [==============================] - 14s 79us/step - loss: 1.0252 - x_pred_binary_loss: 0.4383 - x_pred_categorical_loss: 1.9436 - x_pred_review_loss: 3.3875 - x_pred_coordinates_loss: -7.1778 - val_loss: 0.4938 - val_x_pred_binary_loss: 0.1734 - val_x_pred_categorical_loss: 1.4822 - val_x_pred_review_loss: 4.3203 - val_x_pred_coordinates_loss: -8.0095
# Epoch 37/50
# 174565/174565 [==============================] - 10s 57us/step - loss: 1.0023 - x_pred_binary_loss: 0.4384 - x_pred_categorical_loss: 1.9454 - x_pred_review_loss: 3.3753 - x_pred_coordinates_loss: -7.1927 - val_loss: -0.4285 - val_x_pred_binary_loss: 0.1790 - val_x_pred_categorical_loss: 1.6164 - val_x_pred_review_loss: 3.8441 - val_x_pred_coordinates_loss: -8.5755
# Epoch 38/50
# 174565/174565 [==============================] - 8s 47us/step - loss: 1.0018 - x_pred_binary_loss: 0.4383 - x_pred_categorical_loss: 1.9459 - x_pred_review_loss: 3.3747 - x_pred_coordinates_loss: -7.1843 - val_loss: 23.3149 - val_x_pred_binary_loss: 0.1741 - val_x_pred_categorical_loss: 1.4964 - val_x_pred_review_loss: 3.8165 - val_x_pred_coordinates_loss: 15.3567
# Epoch 39/50
# 174565/174565 [==============================] - 12s 71us/step - loss: 1.0103 - x_pred_binary_loss: 0.4383 - x_pred_categorical_loss: 1.9463 - x_pred_review_loss: 3.3900 - x_pred_coordinates_loss: -7.1908 - val_loss: -0.0056 - val_x_pred_binary_loss: 0.1748 - val_x_pred_categorical_loss: 1.5036 - val_x_pred_review_loss: 4.3650 - val_x_pred_coordinates_loss: -8.5862
# Epoch 40/50
# 174565/174565 [==============================] - 12s 69us/step - loss: 0.9830 - x_pred_binary_loss: 0.4383 - x_pred_categorical_loss: 1.9465 - x_pred_review_loss: 3.3770 - x_pred_coordinates_loss: -7.1961 - val_loss: 0.8584 - val_x_pred_binary_loss: 0.1671 - val_x_pred_categorical_loss: 1.4177 - val_x_pred_review_loss: 4.7728 - val_x_pred_coordinates_loss: -8.0079
# Epoch 41/50
# 174565/174565 [==============================] - 11s 61us/step - loss: 0.9653 - x_pred_binary_loss: 0.4383 - x_pred_categorical_loss: 1.9465 - x_pred_review_loss: 3.3579 - x_pred_coordinates_loss: -7.1895 - val_loss: 0.8607 - val_x_pred_binary_loss: 0.1539 - val_x_pred_categorical_loss: 1.2995 - val_x_pred_review_loss: 5.3378 - val_x_pred_coordinates_loss: -8.4542
# Epoch 42/50
# 174565/174565 [==============================] - 11s 64us/step - loss: 2.4590 - x_pred_binary_loss: 0.4378 - x_pred_categorical_loss: 1.9436 - x_pred_review_loss: 4.8615 - x_pred_coordinates_loss: -7.1779 - val_loss: -0.5471 - val_x_pred_binary_loss: 0.1792 - val_x_pred_categorical_loss: 1.6494 - val_x_pred_review_loss: 3.7351 - val_x_pred_coordinates_loss: -8.5982
# Epoch 43/50
# 174565/174565 [==============================] - 9s 53us/step - loss: 0.9662 - x_pred_binary_loss: 0.4378 - x_pred_categorical_loss: 1.9413 - x_pred_review_loss: 3.3425 - x_pred_coordinates_loss: -7.1586 - val_loss: 0.2139 - val_x_pred_binary_loss: 0.1683 - val_x_pred_categorical_loss: 1.4346 - val_x_pred_review_loss: 4.6043 - val_x_pred_coordinates_loss: -8.4863
# Epoch 44/50
# 174565/174565 [==============================] - 9s 50us/step - loss: 1.5484 - x_pred_binary_loss: 0.4376 - x_pred_categorical_loss: 1.9412 - x_pred_review_loss: 3.9523 - x_pred_coordinates_loss: -7.1587 - val_loss: 0.5570 - val_x_pred_binary_loss: 0.1579 - val_x_pred_categorical_loss: 1.3694 - val_x_pred_review_loss: 5.1105 - val_x_pred_coordinates_loss: -8.5626
# Epoch 45/50
# 174565/174565 [==============================] - 10s 55us/step - loss: 1.5147 - x_pred_binary_loss: 0.4380 - x_pred_categorical_loss: 1.9423 - x_pred_review_loss: 3.9393 - x_pred_coordinates_loss: -7.1844 - val_loss: 0.5454 - val_x_pred_binary_loss: 0.1893 - val_x_pred_categorical_loss: 1.8518 - val_x_pred_review_loss: 4.5595 - val_x_pred_coordinates_loss: -8.5299.9609 - x_pred_bin
# Epoch 46/50
# 174565/174565 [==============================] - 9s 52us/step - loss: 0.9342 - x_pred_binary_loss: 0.4382 - x_pred_categorical_loss: 1.9440 - x_pred_review_loss: 3.3604 - x_pred_coordinates_loss: -7.1947 - val_loss: 0.4354 - val_x_pred_binary_loss: 0.1740 - val_x_pred_categorical_loss: 1.5023 - val_x_pred_review_loss: 4.3615 - val_x_pred_coordinates_loss: -8.1102
# Epoch 47/50
# 174565/174565 [==============================] - 9s 51us/step - loss: 0.9401 - x_pred_binary_loss: 0.4384 - x_pred_categorical_loss: 1.9454 - x_pred_review_loss: 3.3548 - x_pred_coordinates_loss: -7.1967 - val_loss: -0.4889 - val_x_pred_binary_loss: 0.1864 - val_x_pred_categorical_loss: 1.6656 - val_x_pred_review_loss: 3.6938 - val_x_pred_coordinates_loss: -8.5523
# Epoch 48/50
# 174565/174565 [==============================] - 9s 53us/step - loss: 0.9263 - x_pred_binary_loss: 0.4385 - x_pred_categorical_loss: 1.9457 - x_pred_review_loss: 3.3604 - x_pred_coordinates_loss: -7.2062 - val_loss: -0.1722 - val_x_pred_binary_loss: 0.1817 - val_x_pred_categorical_loss: 1.5736 - val_x_pred_review_loss: 3.9301 - val_x_pred_coordinates_loss: -8.3442
# Epoch 49/50
# 174565/174565 [==============================] - 9s 53us/step - loss: 0.9249 - x_pred_binary_loss: 0.4385 - x_pred_categorical_loss: 1.9464 - x_pred_review_loss: 3.3441 - x_pred_coordinates_loss: -7.1911 - val_loss: 0.0829 - val_x_pred_binary_loss: 0.1807 - val_x_pred_categorical_loss: 1.6458 - val_x_pred_review_loss: 3.7035 - val_x_pred_coordinates_loss: -7.9776
# Epoch 50/50
# 174565/174565 [==============================] - 9s 52us/step - loss: 0.9208 - x_pred_binary_loss: 0.4385 - x_pred_categorical_loss: 1.9441 - x_pred_review_loss: 3.3343 - x_pred_coordinates_loss: -7.1732 - val_loss: -0.2326 - val_x_pred_binary_loss: 0.1822 - val_x_pred_categorical_loss: 1.7099 - val_x_pred_review_loss: 3.6486 - val_x_pred_coordinates_loss: -8.2978

# %% [markdown]
# ## Building the Decoder

# %%
decode_input = Input(shape=(latent_dim, ), name = 'decode_input')
decode_layer_1 = decode_1(decode_input)
decode_layer_2 = decode_2(decode_layer_1)

x_pred_coordinates_mu = x_pred_coordinates_mu_layer(decode_layer_2)
x_pred_coordinates_log_var = x_pred_coordinates_log_var_layer(decode_layer_2)
decode_x_pred_coordinates = x_pred_coordinates_layer([x_pred_coordinates_mu, x_pred_coordinates_log_var])

x_pred_review_mu = x_pred_review_mu_layer(decode_layer_2)
x_pred_review_log_var = x_pred_review_log_var_layer(decode_layer_2)
decode_x_pred_review = x_pred_review_layer([x_pred_review_mu, x_pred_review_log_var])

decode_x_pred_binary = x_pred_binary_layer(decode_layer_2) # binary cross entropy
decode_x_pred_categorical = x_pred_categorical_layer(decode_layer_2) # categorical cross entropy


decoder = Model(decode_input, [decode_x_pred_coordinates, decode_x_pred_review, decode_x_pred_categorical, decode_x_pred_binary])

# %%
SVG(model_to_dot(decoder, show_shapes=True)
    .create(prog='dot', format='svg'))

# %% [markdown]
# ### Saving the Models and Metadata
# #### Saving Models (Actually, only the decoder matter)

# %%
model_json = vae.to_json()
with open("./model/vae_full_model.json", "w") as json_file:
    json_file.write(model_json)
vae.save_weights("./model/vae_full_model.h5")
print("Saved model to disk")

encoder = Model(x, [z_mu, z_log_var])
model_json = encoder.to_json()
with open("./model/vae_encoder.json", "w") as json_file:
    json_file.write(model_json)
encoder.save_weights("./model/vae_encoder.h5")
print("Saved model to disk")

model_json = decoder.to_json()
with open("./model/vae_decoder.json", "w") as json_file:
    json_file.write(model_json)
decoder.save_weights("./model/vae_decoder.h5")
print("Saved model to disk")
# Out:
# Saved model to disk
# Saved model to disk
# Saved model to disk

# %% [markdown]
# #### Generating and Saving Metadata

# %%
vae_sample = train_dataset[np.random.choice(len(train_dataset), size=10000, replace=False)]
vae_sample_mu, vae_sample_log_var = encoder.predict(vae_sample, batch_size=batch_size)
np.save('./model/sample_mu.npy', vae_sample_mu)
np.save('./model/sample_log_var.npy', vae_sample_log_var)

# %% [markdown]
# ### Generating some Samples for Testing
# #### Functions for data generation

# %%
reverse_categorical_map = {0:0, 1:0.5, 2:1, 3:1.5, 4:2, 5:2.5, 6:3, 7:3.5, 8:4, 9:4.5, 10:5}
def sample(model, input_mu, input_log_var, samples_per_z=1):
    multiplied_input_mu = np.repeat(input_mu, samples_per_z, axis=0)
    multiplied_input_log_var = np.repeat(input_log_var, samples_per_z, axis=0)
    eps = np.random.normal(size=(multiplied_input_mu.shape[0], latent_dim))
    z = reparameterize(multiplied_input_mu, multiplied_input_log_var, eps)
    predictions = model.predict(z, batch_size = None, steps = 1)
    return reconstruct(predictions)
    
def reconstruct(predictions):
    coordinates, review, categorical, binary = predictions
    mu, log_var = np.split(coordinates, indices_or_sections = 2,axis = 1)
    eps = np.random.normal(size=mu.shape)
    coordinates_data = reparameterize(mu, log_var, eps)
    print(coordinates_data)
    for i, c in enumerate(coordinates_data):
        if c[0] > 1.0:
            coordinates_data[i][0]=1.0
        if c[0] < 0.0:
            coordinates_data[i][0]=0.0
        if c[1] > 1.0:
            coordinates_data[i][1]=1.0
        if c[1] < 0.0:
            coordinates_data[i][1]=0.0
        coordinates_data[i][0] = (coordinates_data[i][0]*360)-180
        coordinates_data[i][1] = (coordinates_data[i][1]*360)-180
    mu2, log_var2 = np.split(review, indices_or_sections = 2,axis = 1)
    eps2 = np.random.normal(size=mu2.shape)
    review_data = reparameterize(mu2, log_var2, eps2)
    for i, r in enumerate(review_data):
        if r[0] < 0:
            review_data[i][0] = 0
        review_data[i][0] = float(int(review_data[i][0]))
    categorical = np.apply_along_axis(lambda t : np.random.multinomial(1,t), -1, categorical)
    categorical = np.apply_along_axis(lambda t : np.argmax(t), -1, categorical)
    categorical = np.expand_dims(categorical, axis = -1)
    categorical_data = np.apply_along_axis(lambda t : float(reverse_categorical_map[t[0]]), -1, categorical)
    categorical_data = np.expand_dims(categorical_data, axis = -1)
    binary_data = np.apply_along_axis(lambda t: np.random.binomial(1, t), -1, binary)
#     coordinates, reviews = np.split(continuous_data, indices_or_sections=[2], axis = 1)
    return np.concatenate([coordinates_data, categorical_data, review_data, binary_data], axis = 1)
    

def reparameterize(input_mu, input_log_var, eps):
    sigma = np.exp(0.5*input_log_var)
    return eps*sigma + input_mu

# %% [markdown]
# ### Generating Samples
# Make use of the funciton sample to generate samples with our model. U need to supply an array of mu and their respective log var in a separate array to do that.

# %%
vae_samples = sample(decoder, vae_sample_mu, vae_sample_log_var)

# Saving the samples in a separate file
file_name = './samples/vae_3_sample_' + str(len(vae_samples)) + '.csv'
np.savetxt(file_name, vae_samples, delimiter = ',', header='latitude,longitude,stars,review_count,is_open')
# Out:
# [[0.62671493 0.29857437]
#  [0.59624077 0.18579363]
#  [0.62353369 0.28608704]
#  ...
#  [0.59723529 0.18847103]
#  [0.64680217 0.50363678]
#  [0.5973617  0.1845022 ]]

# %%
vae_samples[1:10]
# Out:
# array([[  34.6466784 , -113.11429171,    4.5       ,    4.        ,
#            0.        ],
#        [  44.47212863,  -77.00866647,    2.5       ,    7.        ,
#            1.        ],
#        [  40.67123489,  -80.58512095,    4.        ,    0.        ,
#            1.        ],
#        [  36.96850839, -110.17529572,    4.        ,   59.        ,
#            1.        ],
#        [  41.7360412 ,  -82.52277987,    4.        ,    0.        ,
#            1.        ],
#        [  41.7964105 ,  -78.62447006,    3.5       ,   19.        ,
#            1.        ],
#        [  46.2417926 ,  -76.93917101,    4.        ,    0.        ,
#            1.        ],
#        [  34.44739808, -113.25305354,    4.        ,   13.        ,
#            1.        ],
#        [  46.01539315,  -77.00811228,    5.        ,   44.        ,
#            1.        ]])
