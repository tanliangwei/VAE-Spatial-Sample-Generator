# %% [markdown]
# # Model Training
# In this notebook, we will train our VAE model. This involves:
#
# 1. Encoder
# 2. Decoder
# 3. Full Model

# %% [markdown]
# ## Importing Packages
# We will be using Keras to build and train our VAE

# %%
from __future__ import absolute_import, division, print_function, unicode_literals
# %matplotlib notebook
import tensorflow as tf

import os
import time
import numpy as np
import glob
import matplotlib.pyplot as plt
import PIL
import imageio
import h5py

# import keras
from tensorflow.keras import backend as K
from tensorflow.keras.layers import Input, Dense, Lambda, Layer, Add, Multiply, Concatenate
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import model_from_json
import mdn

import tensorflow_probability as tfp

from IPython import display
import numpy as np
import pandas as pd
from sklearn import preprocessing
from pickle import dump, load

from matplotlib.ticker import FormatStrFormatter
from IPython.display import SVG

# %% [markdown]
# ## Definition of Constants
# Hyper parameters and constants will all be located here for ease of adjustments

# %%
categorical_dim = 11
categorical_map = {0:0, 0.5:1, 1: 2, 1.5:3, 2:4, 2.5:5, 3:6, 3.5:7, 4:8, 4.5:9, 5:10}
reverse_categorical_map = {0:0, 1:0.5, 2:1, 3:1.5, 4:2, 5:2.5, 6:3, 7:3.5, 8:4, 9:4.5, 10:5}
continuous_dim = 3
binary_dim = 1
original_dim = binary_dim + continuous_dim + categorical_dim
intermediate_dim_1 = 50
intermediate_dim_2 = 50
latent_dim = 4
batch_size = 100
epochs = 50
epsilon_std = 1.0

## Constants for the Mixture layer
N_HIDDEN = 15  # number of hidden units in the Dense layer
N_MIXES = 10  # number of mixture components
OUTPUT_DIMS = 2  # number of real-values predicted by each mixture component

# Model File Paths
full_model_file = "./model/vae_full_model.json"
full_model_weights = "./model/vae_full_model.h5"
encoder_file = "./model/vae_encoder.json"
encoder_weights = "./model/vae_encoder.h5"
decoder_file = './model/vae_decoder.json'
decoder_weights = './model/vae_decoder.h5'
z_meta_file = './model/z_meta.npy'

# %% [markdown]
# ## Building the Model
# We have to write our own custom layer and custom loss function as these are not supported on Keras natively. There are a few things to be done:
#
# 1. Custom KLDivergence Layer
# 2. Custom Loss Functions
# 3. Building the Model

# %% [markdown]
# ### Custom Loss Functions
# As the yelp dataset contains binary, categorical as well as continuous data, we will build 3 custom loss functions.
#
# #### Binary Loss Function

# %%
def binary_loss(y_true, y_pred):
	# input dimension is (batchsize, 1)
    return K.binary_crossentropy(y_true, y_pred) # the dimension of return value is (batchsize , 1)

# %% [markdown]
# #### Categorical Loss Function

# %%
def categorical_loss(y_true, y_pred):
	# input dimension is (batchsize, number of categories)
  return K.categorical_crossentropy(y_true, y_pred) # the dimension of return value is (batchsize , 1)

# %% [markdown]
# #### Continuous Loss Function

# %%
def log_normal_pdf(sample, mean, logvar, raxis=1):
  log2pi = tf.math.log(2. * np.pi)
  return tf.reduce_sum(
      -.5 * ((sample - mean) ** 2. * tf.exp(-logvar) + logvar + log2pi),
      axis=raxis) # return a tensor of shape (batch_size, 1)

# Added a postfix because now we also have poisson as a distribution
def continuous_loss_gaussian(y_true, y_pred):
	# need to return log probability for continuous gaussian loss.
	# will get a (batchsize, 6 continuous variable input) where 3 of the 6 represents mu and the others logvar
	# y_true will be (batchsize, 3)
  mu, logvar = tf.split(y_pred, num_or_size_splits = 2, axis = 1)
  return -1 * log_normal_pdf(y_true, mu, logvar) 

def continuous_loss_poisson(y_true, y_pred):
	# need to return log probability for continuous poisson loss.
	# will get a (batchsize, 6 continuous variable input) where 3 of the 6 represents mu and the others logvar
	# y_true will be (batchsize, 3)
  return tf.nn.log_poisson_loss(y_true, y_pred)

# %% [markdown]
# ### Model Architecture
# - tanh/sigmoid is used because Relu resulted in loss going to infinity
# - going to delete review_log_var and review_mu since we are trying out the Poission distribution which only takes 1 parameter.

# %%
tfk = tf.keras
tfkl = tf.keras.layers
tfpl = tfp.layers
tfd = tfp.distributions
tfb = tfp.bijectors
class NF(tfkl.Layer):

    def __init__(self, params, event_shape=None, hidden_units=None, activation=None, use_bias=True,
                 kernel_regularizer=None, bias_regularizer=None):

        super(NF, self).__init__()

        self.params = params
        self.event_shape = event_shape
        self.hidden_units = hidden_units
        self.activation = activation
        self.use_bias = use_bias
        self.kernel_regularizer = kernel_regularizer
        self.bias_regularizer = bias_regularizer
        
        self.made = tfb.AutoregressiveNetwork(params=params, hidden_units=[50, 50])
        
        self.network = tfb.MaskedAutoregressiveFlow(self.made)

    def call(self, x):

        return self.network.forward(x)

# %%
tfk = tf.keras
tfkl = tf.keras.layers
tfpl = tfp.layers
tfd = tfp.distributions
tfb = tfp.bijectors


input_shape = (original_dim,)
prior = tfd.Independent(tfd.Normal(loc=tf.zeros(latent_dim), scale=1), reinterpreted_batch_ndims=1)

## Encoder
encoder = tfk.Sequential([
    tfkl.InputLayer(input_shape=input_shape, name = 'input_x'),
    tfkl.Dense(intermediate_dim_1, activation='tanh', name='hidden_enc_1'),
    tfkl.Dense(intermediate_dim_2, activation='tanh', name='hidden_enc_2'),
    tfkl.Dense(tfpl.IndependentNormal.params_size(latent_dim), activation=None, name = 'z_probability_distribution'),
])

### Need to replace this section with Normalizing Flows ###
# Vanilla Sampling from a Gaussian Distribution
sampler = tfk.Sequential([
    tfkl.InputLayer(input_shape=(tfpl.IndependentNormal.params_size(latent_dim), ), name = 'input_z_params'),
    tfpl.IndependentNormal( latent_dim, name = 'sample_layer'),
    tfpl.KLDivergenceAddLoss(
        tfd.MultivariateNormalDiag(loc=tf.zeros(latent_dim))),
    
])
# Normalizing Flow Sampling

# z_dist_layer = tfpl.DistributionLambda(make_distribution_fn=lambda t: tfd.Normal( loc=t[:latent_dim], scale=tf.exp(t[latent_dim:])))
# z_dist = z_dist_layer(encoder.outputs[0])

# made = tfb.AutoregressiveNetwork(params=2, hidden_units=[10, 10])

# distribution = tfd.TransformedDistribution(
#     distribution=tfd.Normal(loc=tf.zeros(latent_dim), scale = [1,1,1,1]),
#     bijector=tfb.MaskedAutoregressiveFlow(made),
#     event_shape=[2])
a = sampler(encoder.outputs[0])
print(a)
z = NF(2)(a)
z = NF(2)(z)
z = NF(2)(z)
z = NF(2)(z)
z = NF(2)(z)
z = NF(2)(z)
z = NF(2)(z)
z = NF(2)(z)
z = NF(2)(z)
z = NF(2)(z)



# print(tf.executing_eagerly())
# print(z)



decode_1 = tfkl.Dense(intermediate_dim_2, activation='tanh', name='hidden_dec_2')
h_dec = decode_1(z)
print(h_dec)

decode_2 = tfkl.Dense(intermediate_dim_1, activation='tanh', name='hidden_dec_1')
h_dec = decode_2(h_dec)

x_pred_coordinates_mdn_layer = mdn.MDN(OUTPUT_DIMS, N_MIXES, name = 'x_pred_coordinates_mdn_layer')
x_pred_coordinates = x_pred_coordinates_mdn_layer(h_dec)


## This outputs the lambda require for poisson distribution and thats all that we need
x_pred_review_log_lambda_layer = tfkl.Dense(1,name = 'x_pred_review_log_lambda_layer')
x_pred_review = x_pred_review_log_lambda_layer(h_dec)

x_pred_binary_layer = tfkl.Dense(binary_dim, activation='sigmoid', name='x_pred_binary')
x_pred_binary = x_pred_binary_layer(h_dec) # binary cross entropy

x_pred_categorical_layer = tfkl.Dense(categorical_dim, name='x_pred_categorical')
x_pred_categorical_layer_activation = tfkl.Activation(tf.nn.softmax)
x_pred_categorical = x_pred_categorical_layer(h_dec) # categorical cross entropy
x_pred_categorical = x_pred_categorical_layer_activation(x_pred_categorical)

vae = tfk.Model(inputs=encoder.inputs, outputs=[x_pred_binary, x_pred_categorical, x_pred_review, x_pred_coordinates])
# Out:
# Tensor("sequential_1/Identity:0", shape=(None, 4), dtype=float32)
# WARNING:tensorflow:From /Users/tanliangwei/Desktop/fyp_repo/tf_1/lib/python3.6/site-packages/tensorflow_probability/python/bijectors/masked_autoregressive.py:310: AffineScalar.__init__ (from tensorflow_probability.python.bijectors.affine_scalar) is deprecated and will be removed after 2020-01-01.
# Instructions for updating:
# `AffineScalar` bijector is deprecated; please use `tfb.Shift(loc)(tfb.Scale(...))` instead.
# Tensor("hidden_dec_2/Identity:0", shape=(None, 50), dtype=float32)

# %% [markdown]
# ### Visualizing the Model

# %%
tf.keras.utils.plot_model(
    vae, to_file='./description/vae_full_model.png', show_shapes=True, show_layer_names=True,
    rankdir='TB', expand_nested=False, dpi=96
)

# %% [markdown]
# ### Compiling Model and Setting Parameters

# %%
optimizer = tf.keras.optimizers.Adam(lr=0.0001)
vae.compile(optimizer=optimizer, loss=[binary_loss, categorical_loss, continuous_loss_poisson, mdn.get_mixture_loss_func(OUTPUT_DIMS,N_MIXES)], loss_weights=[1, 1, 1, 1])

# %% [markdown]
# ### Alternatively, you can upload the weights which was trained during the previous time

# %%
vae.load_weights(full_model_weights)

# %%
vae.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_x (InputLayer)            [(None, 15)]         0
# __________________________________________________________________________________________________
# hidden_enc_1 (Dense)            (None, 50)           800         input_x[0][0]
# __________________________________________________________________________________________________
# hidden_enc_2 (Dense)            (None, 50)           2550        hidden_enc_1[0][0]
# __________________________________________________________________________________________________
# z_probability_distribution (Den (None, 8)            408         hidden_enc_2[0][0]
# __________________________________________________________________________________________________
# sequential_1 (Sequential)       (None, 4)            0           z_probability_distribution[0][0]
# __________________________________________________________________________________________________
# nf (NF)                         (None, 4)            3208        sequential_1[1][0]
# __________________________________________________________________________________________________
# nf_1 (NF)                       (None, 4)            3208        nf[0][0]
# __________________________________________________________________________________________________
# nf_2 (NF)                       (None, 4)            3208        nf_1[0][0]
# __________________________________________________________________________________________________
# nf_3 (NF)                       (None, 4)            3208        nf_2[0][0]
# __________________________________________________________________________________________________
# nf_4 (NF)                       (None, 4)            3208        nf_3[0][0]
# __________________________________________________________________________________________________
# nf_5 (NF)                       (None, 4)            3208        nf_4[0][0]
# __________________________________________________________________________________________________
# nf_6 (NF)                       (None, 4)            3208        nf_5[0][0]
# __________________________________________________________________________________________________
# nf_7 (NF)                       (None, 4)            3208        nf_6[0][0]
# __________________________________________________________________________________________________
# nf_8 (NF)                       (None, 4)            3208        nf_7[0][0]
# __________________________________________________________________________________________________
# nf_9 (NF)                       (None, 4)            3208        nf_8[0][0]
# __________________________________________________________________________________________________
# hidden_dec_2 (Dense)            (None, 50)           250         nf_9[0][0]
# __________________________________________________________________________________________________
# hidden_dec_1 (Dense)            (None, 50)           2550        hidden_dec_2[0][0]
# __________________________________________________________________________________________________
# x_pred_categorical (Dense)      (None, 11)           561         hidden_dec_1[0][0]
# __________________________________________________________________________________________________
# x_pred_binary (Dense)           (None, 1)            51          hidden_dec_1[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 11)           0           x_pred_categorical[0][0]
# __________________________________________________________________________________________________
# x_pred_review_log_lambda_layer  (None, 1)            51          hidden_dec_1[0][0]
# __________________________________________________________________________________________________
# x_pred_coordinates_mdn_layer (M (None, 50)           2550        hidden_dec_1[0][0]
# ==================================================================================================
# Total params: 41,851
# Trainable params: 41,851
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# ## Data Loading and Preprocessing

# %% [markdown]
# ### Converting Coordinates to 2D Euclidean space (mercator)

# %%
import math
def lonlat2meters(lon, lat):
    semimajoraxis = 6378137.0
    east = lon * 0.017453292519943295
    north = lat * 0.017453292519943295
    t = math.sin(north)
    return semimajoraxis * east, 3189068.5 * math.log((1 + t) / (1 - t))

def meters2lonlat(x, y):
    semimajoraxis = 6378137.0
    lon = x / semimajoraxis / 0.017453292519943295
    t = math.exp(y / 3189068.5)
    lat = math.asin((t - 1) / (t + 1)) / 0.017453292519943295
    return lon, lat

# %%
dataset = np.genfromtxt('../../datasets/yelp_business.csv',delimiter=',',skip_header=1)
dataset = dataset[~np.isnan(dataset).any(axis=1)]
test_set, train_set = np.split(dataset,[1], axis = 0)

def format_data(dataset, scaler_to_use=None ,save_scaler=True):
    # handling the categorical variables
    coordinates, ratings, reviews, is_opens = np.split(dataset, [2, 3, 4], axis = 1)
    one_hot_array = np.zeros((ratings.shape[0], categorical_dim))

    for i, r in enumerate(ratings):
        one_hot_array[i][categorical_map[r[0]]] = 1
    
#     # handling coordinates
#     for i, c in enumerate(coordinates):
#         lon = coordinates[i][1]
#         lat = coordinates[i][0]
#         x, y = lonlat2meters(lon, lat)
#         coordinates[i][1] = x
#         coordinates[i][0] = y
    
    if scaler_to_use is None:
        scaler_to_use = preprocessing.StandardScaler()
        scaler_to_use.fit(coordinates)
    
    coordinates = scaler_to_use.transform(coordinates)
    
    if save_scaler:
        dump(scaler_to_use, open('./model/standard_scaler.pkl', 'wb'))
    
    dataset = np.concatenate((coordinates, reviews, is_opens, one_hot_array), axis = 1)

    # creating the labels
    coordinates_labels = coordinates
    review_labels = reviews
    categorical_labels = one_hot_array
    binary_labels = is_opens
    return dataset, coordinates_labels, review_labels, categorical_labels, binary_labels

train_dataset, train_coordinates_labels, train_review_labels, train_categorical_labels, train_binary_labels = format_data(train_set)

## Open scaler
scaler = load(open('./model/standard_scaler.pkl', 'rb'))
test_dataset, test_coordinates_labels, test_review_labels, test_categorical_labels, test_binary_labels = format_data(test_set, scaler, False)

# %% [markdown]
# ### Distribution of Review_Count

# %%
import matplotlib.pyplot as plt
plt.hist(train_review_labels, 1000)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ## Training the Model

# %%
vae.fit(train_dataset , [train_binary_labels, train_categorical_labels, train_review_labels, train_coordinates_labels], shuffle = True, epochs = epochs, batch_size = batch_size, validation_data=(test_dataset , [test_binary_labels, test_categorical_labels, test_review_labels, test_coordinates_labels]))
# Out:
# Train on 174565 samples, validate on 1 samples
# Epoch 1/50
# 174565/174565 [==============================] - 61s 352us/sample - loss: -108.7187 - x_pred_binary_loss: 0.4366 - activation_loss: 1.9517 - x_pred_review_log_lambda_layer_loss: -108.8609 - x_pred_coordinates_mdn_layer_loss: -3.6641 - val_loss: -46.2842 - val_x_pred_binary_loss: 0.1904 - val_activation_loss: 1.5387 - val_x_pred_review_log_lambda_layer_loss: -44.9100 - val_x_pred_coordinates_mdn_layer_loss: -4.7194
# Epoch 2/50
# 174565/174565 [==============================] - 48s 277us/sample - loss: -108.7450 - x_pred_binary_loss: 0.4365 - activation_loss: 1.9504 - x_pred_review_log_lambda_layer_loss: -108.8976 - x_pred_coordinates_mdn_layer_loss: -3.6728 - val_loss: -47.3766 - val_x_pred_binary_loss: 0.1844 - val_activation_loss: 1.4613 - val_x_pred_review_log_lambda_layer_loss: -45.9926 - val_x_pred_coordinates_mdn_layer_loss: -5.1449
# Epoch 3/50
# 174565/174565 [==============================] - 53s 306us/sample - loss: -108.6803 - x_pred_binary_loss: 0.4367 - activation_loss: 1.9503 - x_pred_review_log_lambda_layer_loss: -108.8205 - x_pred_coordinates_mdn_layer_loss: -3.6720 - val_loss: -46.8919 - val_x_pred_binary_loss: 0.1751 - val_activation_loss: 1.4456 - val_x_pred_review_log_lambda_layer_loss: -45.1436 - val_x_pred_coordinates_mdn_layer_loss: -4.6759
# Epoch 4/50
# 174565/174565 [==============================] - 42s 243us/sample - loss: -108.6829 - x_pred_binary_loss: 0.4367 - activation_loss: 1.9505 - x_pred_review_log_lambda_layer_loss: -108.8087 - x_pred_coordinates_mdn_layer_loss: -3.6780 - val_loss: -47.0727 - val_x_pred_binary_loss: 0.1874 - val_activation_loss: 1.5236 - val_x_pred_review_log_lambda_layer_loss: -45.3484 - val_x_pred_coordinates_mdn_layer_loss: -4.9094
# Epoch 5/50
# 174565/174565 [==============================] - 45s 255us/sample - loss: -108.7683 - x_pred_binary_loss: 0.4368 - activation_loss: 1.9497 - x_pred_review_log_lambda_layer_loss: -108.8910 - x_pred_coordinates_mdn_layer_loss: -3.6721 - val_loss: -46.9887 - val_x_pred_binary_loss: 0.1803 - val_activation_loss: 1.4479 - val_x_pred_review_log_lambda_layer_loss: -45.9965 - val_x_pred_coordinates_mdn_layer_loss: -4.7756
# Epoch 6/50
# 174565/174565 [==============================] - 43s 245us/sample - loss: -108.7196 - x_pred_binary_loss: 0.4365 - activation_loss: 1.9486 - x_pred_review_log_lambda_layer_loss: -108.8566 - x_pred_coordinates_mdn_layer_loss: -3.6722 - val_loss: -47.5651 - val_x_pred_binary_loss: 0.1832 - val_activation_loss: 1.4744 - val_x_pred_review_log_lambda_layer_loss: -46.0021 - val_x_pred_coordinates_mdn_layer_loss: -5.4185
# Epoch 7/50
# 174565/174565 [==============================] - 43s 248us/sample - loss: -108.6848 - x_pred_binary_loss: 0.4368 - activation_loss: 1.9493 - x_pred_review_log_lambda_layer_loss: -108.8144 - x_pred_coordinates_mdn_layer_loss: -3.6729 - val_loss: -48.2129 - val_x_pred_binary_loss: 0.2019 - val_activation_loss: 1.5426 - val_x_pred_review_log_lambda_layer_loss: -44.3921 - val_x_pred_coordinates_mdn_layer_loss: -4.9312
# Epoch 8/50
# 174565/174565 [==============================] - 43s 249us/sample - loss: -108.7741 - x_pred_binary_loss: 0.4368 - activation_loss: 1.9490 - x_pred_review_log_lambda_layer_loss: -108.9157 - x_pred_coordinates_mdn_layer_loss: -3.6768 - val_loss: -47.3905 - val_x_pred_binary_loss: 0.1792 - val_activation_loss: 1.4408 - val_x_pred_review_log_lambda_layer_loss: -45.4083 - val_x_pred_coordinates_mdn_layer_loss: -5.2127
# Epoch 9/50
# 174565/174565 [==============================] - 44s 253us/sample - loss: -108.6846 - x_pred_binary_loss: 0.4367 - activation_loss: 1.9477 - x_pred_review_log_lambda_layer_loss: -108.8262 - x_pred_coordinates_mdn_layer_loss: -3.6749 - val_loss: -46.9962 - val_x_pred_binary_loss: 0.1879 - val_activation_loss: 1.4782 - val_x_pred_review_log_lambda_layer_loss: -46.0029 - val_x_pred_coordinates_mdn_layer_loss: -4.9037
# Epoch 10/50
# 174565/174565 [==============================] - 44s 253us/sample - loss: -108.7479 - x_pred_binary_loss: 0.4365 - activation_loss: 1.9476 - x_pred_review_log_lambda_layer_loss: -108.8826 - x_pred_coordinates_mdn_layer_loss: -3.6740 - val_loss: -47.0694 - val_x_pred_binary_loss: 0.1883 - val_activation_loss: 1.4781 - val_x_pred_review_log_lambda_layer_loss: -46.0014 - val_x_pred_coordinates_mdn_layer_loss: -4.9950
# Epoch 11/50
# 174565/174565 [==============================] - 44s 250us/sample - loss: -108.7102 - x_pred_binary_loss: 0.4363 - activation_loss: 1.9467 - x_pred_review_log_lambda_layer_loss: -108.8460 - x_pred_coordinates_mdn_layer_loss: -3.6757 - val_loss: -46.9152 - val_x_pred_binary_loss: 0.1916 - val_activation_loss: 1.5124 - val_x_pred_review_log_lambda_layer_loss: -45.7298 - val_x_pred_coordinates_mdn_layer_loss: -4.8380
# Epoch 12/50
# 174565/174565 [==============================] - 44s 250us/sample - loss: -108.7273 - x_pred_binary_loss: 0.4364 - activation_loss: 1.9464 - x_pred_review_log_lambda_layer_loss: -108.8990 - x_pred_coordinates_mdn_layer_loss: -3.6777 - val_loss: -47.0867 - val_x_pred_binary_loss: 0.1936 - val_activation_loss: 1.5009 - val_x_pred_review_log_lambda_layer_loss: -45.7136 - val_x_pred_coordinates_mdn_layer_loss: -5.0140
# Epoch 13/50
# 174565/174565 [==============================] - 44s 251us/sample - loss: -108.7843 - x_pred_binary_loss: 0.4365 - activation_loss: 1.9465 - x_pred_review_log_lambda_layer_loss: -108.9078 - x_pred_coordinates_mdn_layer_loss: -3.6806 - val_loss: -46.8526 - val_x_pred_binary_loss: 0.1884 - val_activation_loss: 1.4680 - val_x_pred_review_log_lambda_layer_loss: -45.9959 - val_x_pred_coordinates_mdn_layer_loss: -4.6648
# Epoch 14/50
# 174565/174565 [==============================] - 44s 255us/sample - loss: -108.6976 - x_pred_binary_loss: 0.4363 - activation_loss: 1.9450 - x_pred_review_log_lambda_layer_loss: -108.8356 - x_pred_coordinates_mdn_layer_loss: -3.6782 - val_loss: -47.1195 - val_x_pred_binary_loss: 0.1924 - val_activation_loss: 1.5188 - val_x_pred_review_log_lambda_layer_loss: -45.4328 - val_x_pred_coordinates_mdn_layer_loss: -5.1542
# Epoch 15/50
# 174565/174565 [==============================] - 44s 251us/sample - loss: -108.6928 - x_pred_binary_loss: 0.4363 - activation_loss: 1.9456 - x_pred_review_log_lambda_layer_loss: -108.8328 - x_pred_coordinates_mdn_layer_loss: -3.6781 - val_loss: -46.7789 - val_x_pred_binary_loss: 0.1910 - val_activation_loss: 1.4911 - val_x_pred_review_log_lambda_layer_loss: -45.5861 - val_x_pred_coordinates_mdn_layer_loss: -4.9249
# Epoch 16/50
# 174565/174565 [==============================] - 45s 256us/sample - loss: -108.7646 - x_pred_binary_loss: 0.4363 - activation_loss: 1.9447 - x_pred_review_log_lambda_layer_loss: -108.9018 - x_pred_coordinates_mdn_layer_loss: -3.6752 - val_loss: -47.3133 - val_x_pred_binary_loss: 0.1759 - val_activation_loss: 1.4174 - val_x_pred_review_log_lambda_layer_loss: -44.5494 - val_x_pred_coordinates_mdn_layer_loss: -4.8244
# Epoch 17/50
# 174565/174565 [==============================] - 46s 262us/sample - loss: -108.7955 - x_pred_binary_loss: 0.4363 - activation_loss: 1.9448 - x_pred_review_log_lambda_layer_loss: -108.9308 - x_pred_coordinates_mdn_layer_loss: -3.6762 - val_loss: -47.4705 - val_x_pred_binary_loss: 0.1839 - val_activation_loss: 1.4658 - val_x_pred_review_log_lambda_layer_loss: -45.6732 - val_x_pred_coordinates_mdn_layer_loss: -5.0359
# Epoch 18/50
# 174565/174565 [==============================] - 45s 257us/sample - loss: -108.6832 - x_pred_binary_loss: 0.4364 - activation_loss: 1.9444 - x_pred_review_log_lambda_layer_loss: -108.8079 - x_pred_coordinates_mdn_layer_loss: -3.6812 - val_loss: -47.0325 - val_x_pred_binary_loss: 0.1860 - val_activation_loss: 1.4285 - val_x_pred_review_log_lambda_layer_loss: -45.7661 - val_x_pred_coordinates_mdn_layer_loss: -4.8177
# Epoch 19/50
# 174565/174565 [==============================] - 46s 263us/sample - loss: -108.6905 - x_pred_binary_loss: 0.4359 - activation_loss: 1.9437 - x_pred_review_log_lambda_layer_loss: -108.8214 - x_pred_coordinates_mdn_layer_loss: -3.6841 - val_loss: -47.5240 - val_x_pred_binary_loss: 0.1859 - val_activation_loss: 1.4556 - val_x_pred_review_log_lambda_layer_loss: -45.8929 - val_x_pred_coordinates_mdn_layer_loss: -5.1389
# Epoch 20/50
# 174565/174565 [==============================] - 43s 244us/sample - loss: -108.6987 - x_pred_binary_loss: 0.4360 - activation_loss: 1.9437 - x_pred_review_log_lambda_layer_loss: -108.8429 - x_pred_coordinates_mdn_layer_loss: -3.6766 - val_loss: -47.0610 - val_x_pred_binary_loss: 0.1928 - val_activation_loss: 1.5016 - val_x_pred_review_log_lambda_layer_loss: -45.9752 - val_x_pred_coordinates_mdn_layer_loss: -4.8913
# Epoch 21/50
# 174565/174565 [==============================] - 43s 248us/sample - loss: -108.8395 - x_pred_binary_loss: 0.4362 - activation_loss: 1.9442 - x_pred_review_log_lambda_layer_loss: -109.0979 - x_pred_coordinates_mdn_layer_loss: -3.6806 - val_loss: -47.0493 - val_x_pred_binary_loss: 0.1926 - val_activation_loss: 1.5060 - val_x_pred_review_log_lambda_layer_loss: -45.8690 - val_x_pred_coordinates_mdn_layer_loss: -4.8791
# Epoch 22/50
# 174565/174565 [==============================] - 42s 242us/sample - loss: -108.7386 - x_pred_binary_loss: 0.4363 - activation_loss: 1.9430 - x_pred_review_log_lambda_layer_loss: -108.8591 - x_pred_coordinates_mdn_layer_loss: -3.6803 - val_loss: -47.1688 - val_x_pred_binary_loss: 0.1853 - val_activation_loss: 1.4740 - val_x_pred_review_log_lambda_layer_loss: -45.7910 - val_x_pred_coordinates_mdn_layer_loss: -4.8295
# Epoch 23/50
# 174565/174565 [==============================] - 43s 244us/sample - loss: -108.8045 - x_pred_binary_loss: 0.4363 - activation_loss: 1.9422 - x_pred_review_log_lambda_layer_loss: -108.9238 - x_pred_coordinates_mdn_layer_loss: -3.6853 - val_loss: -47.4876 - val_x_pred_binary_loss: 0.1868 - val_activation_loss: 1.4549 - val_x_pred_review_log_lambda_layer_loss: -45.7619 - val_x_pred_coordinates_mdn_layer_loss: -5.1641
# Epoch 24/50
# 174565/174565 [==============================] - 46s 262us/sample - loss: -108.6811 - x_pred_binary_loss: 0.4362 - activation_loss: 1.9422 - x_pred_review_log_lambda_layer_loss: -108.8023 - x_pred_coordinates_mdn_layer_loss: -3.6806 - val_loss: -46.9492 - val_x_pred_binary_loss: 0.1769 - val_activation_loss: 1.4306 - val_x_pred_review_log_lambda_layer_loss: -45.0172 - val_x_pred_coordinates_mdn_layer_loss: -4.8815
# Epoch 25/50
# 174565/174565 [==============================] - 49s 279us/sample - loss: -108.7679 - x_pred_binary_loss: 0.4361 - activation_loss: 1.9407 - x_pred_review_log_lambda_layer_loss: -108.9146 - x_pred_coordinates_mdn_layer_loss: -3.6846 - val_loss: -47.2887 - val_x_pred_binary_loss: 0.1822 - val_activation_loss: 1.4240 - val_x_pred_review_log_lambda_layer_loss: -45.5948 - val_x_pred_coordinates_mdn_layer_loss: -4.9961
# Epoch 26/50
# 174565/174565 [==============================] - 52s 297us/sample - loss: -108.7855 - x_pred_binary_loss: 0.4361 - activation_loss: 1.9405 - x_pred_review_log_lambda_layer_loss: -108.9177 - x_pred_coordinates_mdn_layer_loss: -3.6793 - val_loss: -47.3735 - val_x_pred_binary_loss: 0.1946 - val_activation_loss: 1.4729 - val_x_pred_review_log_lambda_layer_loss: -45.8870 - val_x_pred_coordinates_mdn_layer_loss: -5.1219
# Epoch 27/50
# 174565/174565 [==============================] - 45s 258us/sample - loss: -108.7901 - x_pred_binary_loss: 0.4359 - activation_loss: 1.9396 - x_pred_review_log_lambda_layer_loss: -108.9067 - x_pred_coordinates_mdn_layer_loss: -3.6847 - val_loss: -46.8024 - val_x_pred_binary_loss: 0.1982 - val_activation_loss: 1.4887 - val_x_pred_review_log_lambda_layer_loss: -45.3660 - val_x_pred_coordinates_mdn_layer_loss: -4.8217
# Epoch 28/50
# 174565/174565 [==============================] - 47s 268us/sample - loss: -108.7177 - x_pred_binary_loss: 0.4357 - activation_loss: 1.9387 - x_pred_review_log_lambda_layer_loss: -108.8503 - x_pred_coordinates_mdn_layer_loss: -3.6821 - val_loss: -47.3800 - val_x_pred_binary_loss: 0.1720 - val_activation_loss: 1.3745 - val_x_pred_review_log_lambda_layer_loss: -43.1267 - val_x_pred_coordinates_mdn_layer_loss: -5.1952
# Epoch 29/50
# 174565/174565 [==============================] - 47s 269us/sample - loss: -108.7047 - x_pred_binary_loss: 0.4352 - activation_loss: 1.9388 - x_pred_review_log_lambda_layer_loss: -108.8443 - x_pred_coordinates_mdn_layer_loss: -3.6838 - val_loss: -47.3083 - val_x_pred_binary_loss: 0.1867 - val_activation_loss: 1.4704 - val_x_pred_review_log_lambda_layer_loss: -45.9617 - val_x_pred_coordinates_mdn_layer_loss: -5.1453
# Epoch 30/50
# 174565/174565 [==============================] - 51s 292us/sample - loss: -108.6436 - x_pred_binary_loss: 0.4350 - activation_loss: 1.9389 - x_pred_review_log_lambda_layer_loss: -108.7821 - x_pred_coordinates_mdn_layer_loss: -3.6872 - val_loss: -47.0330 - val_x_pred_binary_loss: 0.1879 - val_activation_loss: 1.4497 - val_x_pred_review_log_lambda_layer_loss: -45.9487 - val_x_pred_coordinates_mdn_layer_loss: -4.8592
# Epoch 31/50
# 174565/174565 [==============================] - 53s 303us/sample - loss: -108.7851 - x_pred_binary_loss: 0.4353 - activation_loss: 1.9388 - x_pred_review_log_lambda_layer_loss: -108.8964 - x_pred_coordinates_mdn_layer_loss: -3.6900 - val_loss: -46.9743 - val_x_pred_binary_loss: 0.2023 - val_activation_loss: 1.5163 - val_x_pred_review_log_lambda_layer_loss: -45.1740 - val_x_pred_coordinates_mdn_layer_loss: -4.9554
# Epoch 32/50
# 174565/174565 [==============================] - 45s 255us/sample - loss: -108.7396 - x_pred_binary_loss: 0.4352 - activation_loss: 1.9386 - x_pred_review_log_lambda_layer_loss: -108.8471 - x_pred_coordinates_mdn_layer_loss: -3.6902 - val_loss: -47.2349 - val_x_pred_binary_loss: 0.1836 - val_activation_loss: 1.4322 - val_x_pred_review_log_lambda_layer_loss: -45.7966 - val_x_pred_coordinates_mdn_layer_loss: -4.9016
# Epoch 33/50
# 174565/174565 [==============================] - 43s 249us/sample - loss: -108.7159 - x_pred_binary_loss: 0.4354 - activation_loss: 1.9376 - x_pred_review_log_lambda_layer_loss: -108.8279 - x_pred_coordinates_mdn_layer_loss: -3.6873 - val_loss: -46.8112 - val_x_pred_binary_loss: 0.1909 - val_activation_loss: 1.4804 - val_x_pred_review_log_lambda_layer_loss: -45.7939 - val_x_pred_coordinates_mdn_layer_loss: -4.5915
# Epoch 34/50
# 174565/174565 [==============================] - 57s 329us/sample - loss: -108.8110 - x_pred_binary_loss: 0.4353 - activation_loss: 1.9356 - x_pred_review_log_lambda_layer_loss: -108.9206 - x_pred_coordinates_mdn_layer_loss: -3.6871 - val_loss: -47.2018 - val_x_pred_binary_loss: 0.1971 - val_activation_loss: 1.4871 - val_x_pred_review_log_lambda_layer_loss: -45.9679 - val_x_pred_coordinates_mdn_layer_loss: -5.0601
# Epoch 35/50
# 174565/174565 [==============================] - 52s 295us/sample - loss: -108.7325 - x_pred_binary_loss: 0.4356 - activation_loss: 1.9354 - x_pred_review_log_lambda_layer_loss: -108.8417 - x_pred_coordinates_mdn_layer_loss: -3.6878 - val_loss: -46.9534 - val_x_pred_binary_loss: 0.1991 - val_activation_loss: 1.5053 - val_x_pred_review_log_lambda_layer_loss: -45.2534 - val_x_pred_coordinates_mdn_layer_loss: -4.8261
# Epoch 36/50
# 174565/174565 [==============================] - 49s 280us/sample - loss: -108.8055 - x_pred_binary_loss: 0.4355 - activation_loss: 1.9354 - x_pred_review_log_lambda_layer_loss: -108.9102 - x_pred_coordinates_mdn_layer_loss: -3.6867 - val_loss: -47.4710 - val_x_pred_binary_loss: 0.1928 - val_activation_loss: 1.4271 - val_x_pred_review_log_lambda_layer_loss: -45.9836 - val_x_pred_coordinates_mdn_layer_loss: -5.1644
# Epoch 37/50
# 174565/174565 [==============================] - 44s 251us/sample - loss: -108.6791 - x_pred_binary_loss: 0.4355 - activation_loss: 1.9342 - x_pred_review_log_lambda_layer_loss: -108.7828 - x_pred_coordinates_mdn_layer_loss: -3.6888 - val_loss: -46.6144 - val_x_pred_binary_loss: 0.2030 - val_activation_loss: 1.5397 - val_x_pred_review_log_lambda_layer_loss: -44.1745 - val_x_pred_coordinates_mdn_layer_loss: -4.9380
# Epoch 38/50
# 174565/174565 [==============================] - 54s 312us/sample - loss: -108.7270 - x_pred_binary_loss: 0.4351 - activation_loss: 1.9324 - x_pred_review_log_lambda_layer_loss: -108.8292 - x_pred_coordinates_mdn_layer_loss: -3.6916 - val_loss: -46.9292 - val_x_pred_binary_loss: 0.1955 - val_activation_loss: 1.4748 - val_x_pred_review_log_lambda_layer_loss: -45.8521 - val_x_pred_coordinates_mdn_layer_loss: -4.8274
# Epoch 39/50
# 174565/174565 [==============================] - 47s 271us/sample - loss: -108.8027 - x_pred_binary_loss: 0.4353 - activation_loss: 1.9324 - x_pred_review_log_lambda_layer_loss: -108.9119 - x_pred_coordinates_mdn_layer_loss: -3.6917 - val_loss: -47.1732 - val_x_pred_binary_loss: 0.1882 - val_activation_loss: 1.4566 - val_x_pred_review_log_lambda_layer_loss: -46.0022 - val_x_pred_coordinates_mdn_layer_loss: -5.0025
# Epoch 40/50
# 174565/174565 [==============================] - 44s 250us/sample - loss: -108.7959 - x_pred_binary_loss: 0.4356 - activation_loss: 1.9315 - x_pred_review_log_lambda_layer_loss: -108.9527 - x_pred_coordinates_mdn_layer_loss: -3.6915 - val_loss: -47.3655 - val_x_pred_binary_loss: 0.1891 - val_activation_loss: 1.4588 - val_x_pred_review_log_lambda_layer_loss: -45.9974 - val_x_pred_coordinates_mdn_layer_loss: -5.0555
# Epoch 41/50
# 174565/174565 [==============================] - 49s 278us/sample - loss: -108.7331 - x_pred_binary_loss: 0.4357 - activation_loss: 1.9321 - x_pred_review_log_lambda_layer_loss: -108.8411 - x_pred_coordinates_mdn_layer_loss: -3.6920 - val_loss: -47.0477 - val_x_pred_binary_loss: 0.1873 - val_activation_loss: 1.4597 - val_x_pred_review_log_lambda_layer_loss: -45.7981 - val_x_pred_coordinates_mdn_layer_loss: -4.7657
# Epoch 42/50
# 174565/174565 [==============================] - 48s 277us/sample - loss: -108.8153 - x_pred_binary_loss: 0.4351 - activation_loss: 1.9299 - x_pred_review_log_lambda_layer_loss: -108.9555 - x_pred_coordinates_mdn_layer_loss: -3.6994 - val_loss: -46.6915 - val_x_pred_binary_loss: 0.1956 - val_activation_loss: 1.4963 - val_x_pred_review_log_lambda_layer_loss: -45.3599 - val_x_pred_coordinates_mdn_layer_loss: -4.5749
# Epoch 43/50
# 174565/174565 [==============================] - 47s 271us/sample - loss: -108.7440 - x_pred_binary_loss: 0.4355 - activation_loss: 1.9297 - x_pred_review_log_lambda_layer_loss: -108.8614 - x_pred_coordinates_mdn_layer_loss: -3.6945 - val_loss: -47.2226 - val_x_pred_binary_loss: 0.1885 - val_activation_loss: 1.4694 - val_x_pred_review_log_lambda_layer_loss: -46.0028 - val_x_pred_coordinates_mdn_layer_loss: -5.0342
# Epoch 44/50
# 174565/174565 [==============================] - 45s 257us/sample - loss: -108.8242 - x_pred_binary_loss: 0.4356 - activation_loss: 1.9306 - x_pred_review_log_lambda_layer_loss: -108.9334 - x_pred_coordinates_mdn_layer_loss: -3.6970 - val_loss: -47.1076 - val_x_pred_binary_loss: 0.1927 - val_activation_loss: 1.4717 - val_x_pred_review_log_lambda_layer_loss: -45.9882 - val_x_pred_coordinates_mdn_layer_loss: -4.9771
# Epoch 45/50
# 174565/174565 [==============================] - 45s 259us/sample - loss: -108.8099 - x_pred_binary_loss: 0.4355 - activation_loss: 1.9306 - x_pred_review_log_lambda_layer_loss: -108.9019 - x_pred_coordinates_mdn_layer_loss: -3.6961 - val_loss: -46.7220 - val_x_pred_binary_loss: 0.2031 - val_activation_loss: 1.5033 - val_x_pred_review_log_lambda_layer_loss: -44.8619 - val_x_pred_coordinates_mdn_layer_loss: -4.4725
# Epoch 46/50
# 174565/174565 [==============================] - 45s 260us/sample - loss: -108.7223 - x_pred_binary_loss: 0.4355 - activation_loss: 1.9295 - x_pred_review_log_lambda_layer_loss: -108.8291 - x_pred_coordinates_mdn_layer_loss: -3.6905 - val_loss: -47.2013 - val_x_pred_binary_loss: 0.1875 - val_activation_loss: 1.4400 - val_x_pred_review_log_lambda_layer_loss: -45.9186 - val_x_pred_coordinates_mdn_layer_loss: -4.9921
# Epoch 47/50
# 174565/174565 [==============================] - 45s 259us/sample - loss: -108.8427 - x_pred_binary_loss: 0.4354 - activation_loss: 1.9299 - x_pred_review_log_lambda_layer_loss: -108.9782 - x_pred_coordinates_mdn_layer_loss: -3.7005 - val_loss: -45.9373 - val_x_pred_binary_loss: 0.2006 - val_activation_loss: 1.5360 - val_x_pred_review_log_lambda_layer_loss: -44.7987 - val_x_pred_coordinates_mdn_layer_loss: -4.6936
# Epoch 48/50
# 174565/174565 [==============================] - 45s 260us/sample - loss: -108.6053 - x_pred_binary_loss: 0.4356 - activation_loss: 1.9301 - x_pred_review_log_lambda_layer_loss: -108.7038 - x_pred_coordinates_mdn_layer_loss: -3.6984 - val_loss: -47.3021 - val_x_pred_binary_loss: 0.1852 - val_activation_loss: 1.4733 - val_x_pred_review_log_lambda_layer_loss: -45.9759 - val_x_pred_coordinates_mdn_layer_loss: -5.0952
# Epoch 49/50
# 174565/174565 [==============================] - 47s 268us/sample - loss: -108.6954 - x_pred_binary_loss: 0.4347 - activation_loss: 1.9298 - x_pred_review_log_lambda_layer_loss: -108.8008 - x_pred_coordinates_mdn_layer_loss: -3.6995 - val_loss: -47.1714 - val_x_pred_binary_loss: 0.1951 - val_activation_loss: 1.4808 - val_x_pred_review_log_lambda_layer_loss: -45.8614 - val_x_pred_coordinates_mdn_layer_loss: -5.0553
# Epoch 50/50
# 174565/174565 [==============================] - 47s 268us/sample - loss: -108.8281 - x_pred_binary_loss: 0.4350 - activation_loss: 1.9294 - x_pred_review_log_lambda_layer_loss: -108.9330 - x_pred_coordinates_mdn_layer_loss: -3.7030 - val_loss: -47.3137 - val_x_pred_binary_loss: 0.1999 - val_activation_loss: 1.5068 - val_x_pred_review_log_lambda_layer_loss: -45.7628 - val_x_pred_coordinates_mdn_layer_loss: -4.9260

# %% [markdown]
# ## Building the Decoder

# %%
# decode_input = Input(shape=(latent_dim, ), name = 'decode_input')
decode_sampler = tfk.Sequential([
    tfkl.InputLayer(input_shape=(tfpl.IndependentNormal.params_size(latent_dim), ), name = 'input_z_params'),
    tfpl.IndependentNormal( latent_dim, name = 'sample_layer'),
])
x = vae.get_layer('nf')(decode_sampler.outputs[0])
x = vae.get_layer('nf_1')(x)
x = vae.get_layer('nf_2')(x)
x = vae.get_layer('nf_3')(x)
x = vae.get_layer('nf_4')(x)
x = vae.get_layer('nf_5')(x)
x = vae.get_layer('nf_6')(x)
x = vae.get_layer('nf_7')(x)
x = vae.get_layer('nf_8')(x)
x = vae.get_layer('nf_9')(x)


decode_layer_1 = decode_1(x)
decode_layer_2 = decode_2(decode_layer_1)

decode_x_pred_coordinates=x_pred_coordinates_mdn_layer(decode_layer_2)

decode_x_pred_review = x_pred_review_log_lambda_layer(decode_layer_2)

decode_x_pred_binary = x_pred_binary_layer(decode_layer_2) # binary cross entropy
decode_x_pred_categorical = x_pred_categorical_layer(decode_layer_2) # categorical cross entropy
decode_x_pred_categorical = x_pred_categorical_layer_activation(decode_x_pred_categorical)

# sampler.inputs
decoder = Model(inputs=decode_sampler.inputs, outputs=[decode_x_pred_coordinates, decode_x_pred_review, decode_x_pred_categorical, decode_x_pred_binary])
# decoder = Model(, [decode_x_pred_coordinates, decode_x_pred_review, decode_x_pred_categorical, decode_x_pred_binary])

# %%
tf.keras.utils.plot_model(
    decoder, to_file='./description/vae_decoder.png', show_shapes=True, show_layer_names=True,
    rankdir='TB', expand_nested=False, dpi=96
)

# %% [markdown]
# ### Saving the Models and Metadata
# #### Saving Models (Actually, only the decoder matter)

# %%
# model_json = vae.to_json()
# with open(full_model_file, "w") as json_file:
#     json_file.write(model_json)
vae.save_weights(full_model_weights)
# vae.save(full_model_file)
print("Saved model to disk")

# encoder = Model(x, [z_mu, z_log_var])
model_json = encoder.to_json()
with open(encoder_file, "w") as json_file:
    json_file.write(model_json)
encoder.save_weights(encoder_weights)
print("Saved model to disk")

# model_json = decoder.to_json()
# with open(decoder_file, "w") as json_file:
#     json_file.write(model_json)
# decoder.save(decoder_file)
decoder.save_weights(decoder_weights)
print("Saved model to disk")
# Out:
# Saved model to disk
# Saved model to disk
# Saved model to disk

# %% [markdown]
# #### Generating and Saving Metadata

# %%
vae_sample = train_dataset[np.random.choice(len(train_dataset), size=1700, replace=False)]
z_meta = encoder.predict(vae_sample, batch_size=batch_size)

np.save('./model/z_meta.npy', z_meta)

# %% [markdown]
# ### Generating some Samples for Testing
# #### Functions for data generation

# %%
reverse_categorical_map = {0:0, 1:0.5, 2:1, 3:1.5, 4:2, 5:2.5, 6:3, 7:3.5, 8:4, 9:4.5, 10:5}
def sample(decoder, input_z_params,samples_per_z=1):
    multiplied_input_z_params = np.repeat(input_z_params, samples_per_z, axis=0)
    predictions = decoder.predict(multiplied_input_z_params, batch_size = None, steps = 1)
    return reconstruct(predictions)
    
def reconstruct(predictions):
    coordinates, review, categorical, binary = predictions
    # coordinates handled here
    coordinates_data = np.apply_along_axis(mdn.sample_from_output, 1, coordinates, OUTPUT_DIMS, N_MIXES, temp=1.0)
    coordinates_data = np.squeeze(coordinates_data, axis=1)
    scaler = load(open('./model/standard_scaler.pkl', 'rb'))
    coordinates_data = scaler.inverse_transform(coordinates_data)
    
#     for i, c in enumerate(coordinates_data):
#         x = coordinates_data[i][1]
#         y = coordinates_data[i][0]
#         lon, lat = meters2lonlat(x, y)
#         coordinates_data[i][1] = lon
#         coordinates_data[i][0] = lat
    
    for i, c in enumerate(coordinates_data):
        if c[0] > 180.0:
            coordinates_data[i][0]= 180.0
        if c[0] < -180.0:
            coordinates_data[i][0]= -180.0
        if c[1] > 180.0:
            coordinates_data[i][1]= 180.0
        if c[1] < -180.0:
            coordinates_data[i][1]= -180.0
    
    ## review_count handled here
    exp_log_review = np.exp(review)
    review_data = np.random.poisson(lam=exp_log_review, size = review.shape)
    for i, r in enumerate(review_data):
        if r[0] < 0:
            review_data[i][0] = 0
        review_data[i][0] = float(int(review_data[i][0]))

    categorical = categorical.astype(np.float64)
    for i, c in enumerate(categorical):
        if np.sum(c, dtype=np.float64) > 1.0:
            sum_of_all = np.sum(c, dtype=np.float64)
            for j in range(len(categorical[i])):
                categorical[i][j] = categorical[i][j]/sum_of_all
            sum_of_all = np.sum(c, dtype=np.float32)
#             print(sum_of_all)
    
    categorical = np.apply_along_axis(lambda t : np.random.multinomial(1,t), -1, categorical)
    categorical = np.apply_along_axis(lambda t : np.argmax(t), -1, categorical)
    categorical = np.expand_dims(categorical, axis = -1)
    categorical_data = np.apply_along_axis(lambda t : float(reverse_categorical_map[t[0]]), -1, categorical)
    categorical_data = np.expand_dims(categorical_data, axis = -1)
    binary_data = np.apply_along_axis(lambda t: np.random.binomial(1, t), -1, binary)
#     coordinates, reviews = np.split(continuous_data, indices_or_sections=[2], axis = 1)
    return np.concatenate([coordinates_data, categorical_data, review_data, binary_data], axis = 1)
    

def reparameterize(input_mu, input_log_var, eps):
    sigma = np.exp(0.5*input_log_var)
    return eps*sigma + input_mu

# %% [markdown]
# ### Generating Samples
# Make use of the funciton sample to generate samples with our model. U need to supply an array of mu and their respective log var in a separate array to do that.

# %%
vae_samples = sample(decoder, z_meta, samples_per_z=10)

# # Saving the samples in a separate file
file_name = './samples/vae_12_sample_' + str(len(z_meta))+'_times_'+ str(len(vae_samples)//len(z_meta)) + '.csv'
np.savetxt(file_name, vae_samples, delimiter = ',', header='latitude,longitude,stars,review_count,is_open')
print(file_name)
# Out:
# ./samples/vae_12_sample_1700_times_10.csv

# %%
vae_samples[1:10]
# Out:
# array([[  40.47436423,  -86.39805903,    4.5       ,  158.        ,
#            0.        ],
#        [  36.10675108, -115.2335289 ,    2.        ,    4.        ,
#            1.        ],
#        [  33.23612648, -111.82343548,    3.5       ,    5.        ,
#            0.        ],
#        [  33.51070799, -111.73790158,    4.5       ,    6.        ,
#            1.        ],
#        [  33.53953601, -111.6928901 ,    5.        ,   22.        ,
#            1.        ],
#        [  43.49592692,  -79.76031813,    5.        ,    3.        ,
#            1.        ],
#        [  33.42581167, -112.14368517,    3.        ,    5.        ,
#            0.        ],
#        [  40.61667979,  -84.97374726,    3.5       ,   17.        ,
#            1.        ],
#        [  41.58088822,  -82.41983999,    3.        ,    4.        ,
#            1.        ]])
