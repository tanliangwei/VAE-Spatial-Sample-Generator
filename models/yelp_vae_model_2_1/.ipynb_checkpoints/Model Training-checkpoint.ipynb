# %% [markdown]
# # Model Training
# In this notebook, we will train our VAE model. This involves:
#
# 1. Encoder
# 2. Decoder
# 3. Full Model

# %% [markdown]
# ## Importing Packages
# We will be using Keras to build and train our VAE

# %%
from __future__ import absolute_import, division, print_function, unicode_literals
# %matplotlib notebook
import tensorflow as tf

import os
import time
import numpy as np
import glob
import matplotlib.pyplot as plt
import PIL
import imageio
import h5py

import keras
from keras import backend as K
from keras.layers import Input, Dense, Lambda, Layer, Add, Multiply, Concatenate
from keras.models import Model, Sequential
from keras.utils import to_categorical
from keras.models import model_from_json

from IPython import display
import numpy as np
import pandas as pd

from matplotlib.ticker import FormatStrFormatter
from keras.utils.vis_utils import model_to_dot, plot_model
from IPython.display import SVG
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ## Definition of Constants
# Hyper parameters and constants will all be located here for ease of adjustments

# %%
categorical_dim = 11
categorical_map = {0:0, 0.5:1, 1: 2, 1.5:3, 2:4, 2.5:5, 3:6, 3.5:7, 4:8, 4.5:9, 5:10}
reverse_categorical_map = {0:0, 1:0.5, 2:1, 3:1.5, 4:2, 5:2.5, 6:3, 7:3.5, 8:4, 9:4.5, 10:5}
continuous_dim = 3
binary_dim = 1
original_dim = binary_dim + continuous_dim + categorical_dim
intermediate_dim_1 = 50
intermediate_dim_2 = 50
latent_dim = 4
batch_size = 100
epochs = 50
epsilon_std = 1.0

# %% [markdown]
# ## Building the Model
# We have to write our own custom layer and custom loss function as these are not supported on Keras natively. There are a few things to be done:
#
# 1. Custom KLDivergence Layer
# 2. Custom Loss Functions
# 3. Building the Model

# %% [markdown]
# ### KL Divergence Layer
# To ensure modularity, we decided to create a separate layer for KL Divergence. This layer will account for the loss required.

# %%
class KLDivergenceLayer(Layer):

    """ Identity transform layer that adds KL divergence
    to the final model loss.
    """

    def __init__(self, *args, **kwargs):
        self.is_placeholder = True
        super(KLDivergenceLayer, self).__init__(*args, **kwargs)

    def call(self, inputs):

        mu, log_var = inputs

        kl_batch = - .5 * K.sum(1 + log_var -
                                K.square(mu) -
                                K.exp(log_var), axis=-1)

        self.add_loss(K.mean(kl_batch), inputs=inputs)

        return inputs

# %% [markdown]
# ### Custom Loss Functions
# As the yelp dataset contains binary, categorical as well as continuous data, we will build 3 custom loss functions.
#
# #### Binary Loss Function

# %%
def binary_loss(y_true, y_pred):
	# input dimension is (batchsize, 1)
    return K.binary_crossentropy(y_true, y_pred) # the dimension of return value is (batchsize , 1)

# %% [markdown]
# #### Categorical Loss Function

# %%
def categorical_loss(y_true, y_pred):
	# input dimension is (batchsize, number of categories)
  return K.categorical_crossentropy(y_true, y_pred) # the dimension of return value is (batchsize , 1)

# %% [markdown]
# #### Continuous Loss Function

# %%
def log_normal_pdf(sample, mean, logvar, raxis=1):
    log2pi = tf.math.log(2. * np.pi)
    return tf.reduce_sum(
      -.5 * ((sample - mean) ** 2. * tf.exp(-logvar) + logvar + log2pi),
      axis=raxis) # return a tensor of shape (batch_size, 1)

def continuous_loss(y_true, y_pred):
	# need to return log probability for continuous loss.
	# will get a (batchsize, 6 continuous variable input) where 3 of the 6 represents mu and the others logvar
	# y_true will be (batchsize, 3)
    mu, logvar = tf.split(y_pred, num_or_size_splits = 2, axis = 1)
    return -1 * log_normal_pdf(y_true, mu, logvar) 

def continuous_log_loss(y_true, y_pred):
	# need to return log probability for continuous loss.
	# will get a (batchsize, 6 continuous variable input) where 3 of the 6 represents mu and the others logvar
	# y_true will be (batchsize, 3)
    log_mu, logvar = tf.split(y_pred, num_or_size_splits = 2, axis = 1)
    mu = K.exp(log_mu)
    return -1 * log_normal_pdf(y_true, mu, logvar)

# %% [markdown]
# ### Model Architecture
# - tanh/sigmoid is used because Relu resulted in loss going to infinity

# %%
x = Input(shape=(original_dim,), name='input_x')
h = Dense(intermediate_dim_1, activation='tanh', name='hidden_enc_1')(x)
h = Dense(intermediate_dim_2, activation='tanh', name='hidden_enc_2')(h)

z_mu = Dense(latent_dim, name='z_mu')(h)
z_log_var = Dense(latent_dim, name='z_log_var')(h)

z_mu, z_log_var = KLDivergenceLayer(name='KL_Divergence')([z_mu, z_log_var])
z_sigma = Lambda(lambda t: K.exp(.5*t))(z_log_var)

eps = Input(name='input_eps',tensor=K.random_normal(stddev=epsilon_std,
                                   shape=(K.shape(x)[0], latent_dim)))
z_eps = Multiply()([z_sigma, eps])
z = Add()([z_mu, z_eps])

decode_1 = Dense(intermediate_dim_2, activation='tanh', name='hidden_dec_2')
h_dec = decode_1(z)

decode_2 = Dense(intermediate_dim_1, activation='tanh', name='hidden_dec_1')
h_dec = decode_2(h_dec)

x_pred_coordinates_mu_layer = Dense(2, activation='sigmoid',name='x_pred_coordinates_mu')
x_pred_coordinates_mu = x_pred_coordinates_mu_layer(h_dec)

x_pred_coordinates_log_var_layer = Dense(2, name='x_pred_coordinates_log_var')
x_pred_coordinates_log_var = x_pred_coordinates_log_var_layer(h_dec)

x_pred_coordinates_layer = Concatenate(axis=-1, name = 'x_pred_coordinates')
x_pred_coordinates = x_pred_coordinates_layer([x_pred_coordinates_mu, x_pred_coordinates_log_var])

x_pred_review_log_mu_layer = Dense(1, name='x_pred_review_log_mu')
x_pred_review_log_mu = x_pred_review_log_mu_layer(h_dec)

x_pred_review_log_var_layer = Dense(1, name='x_pred_review_log_var')
x_pred_review_log_var = x_pred_review_log_var_layer(h_dec)

x_pred_review_layer = Concatenate(axis=-1, name = 'x_pred_review')
x_pred_review = x_pred_review_layer([x_pred_review_log_mu, x_pred_review_log_var])

x_pred_binary_layer = Dense(binary_dim, activation='sigmoid', name='x_pred_binary')
x_pred_binary = x_pred_binary_layer(h_dec) # binary cross entropy

x_pred_categorical_layer = Dense(categorical_dim, activation='softmax', name='x_pred_categorical')
x_pred_categorical = x_pred_categorical_layer(h_dec) # categorical cross entropy

vae = Model(inputs=[x,eps], outputs=[x_pred_binary, x_pred_categorical, x_pred_review, x_pred_coordinates])

# %%
SVG(model_to_dot(vae, show_shapes=True)
    .create(prog='dot', format='svg'))

# %%
plot_model(
    model=vae, show_shapes=True,
    to_file='./description/vae_full_model.png'
)

# %% [markdown]
# ### Compiling Model and Setting Parameters

# %%
optimizer = keras.optimizers.Adam(lr=0.0001,clipvalue=1)
vae.compile(optimizer=optimizer, loss=[binary_loss, categorical_loss, continuous_log_loss, continuous_loss], loss_weights=[1, 1, 1, 1])

# %%
vae.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_x (InputLayer)            (None, 15)           0
# __________________________________________________________________________________________________
# hidden_enc_1 (Dense)            (None, 50)           800         input_x[0][0]
# __________________________________________________________________________________________________
# hidden_enc_2 (Dense)            (None, 50)           2550        hidden_enc_1[0][0]
# __________________________________________________________________________________________________
# z_mu (Dense)                    (None, 4)            204         hidden_enc_2[0][0]
# __________________________________________________________________________________________________
# z_log_var (Dense)               (None, 4)            204         hidden_enc_2[0][0]
# __________________________________________________________________________________________________
# KL_Divergence (KLDivergenceLaye [(None, 4), (None, 4 0           z_mu[0][0]
#                                                                  z_log_var[0][0]
# __________________________________________________________________________________________________
# lambda_1 (Lambda)               (None, 4)            0           KL_Divergence[0][1]
# __________________________________________________________________________________________________
# input_eps (InputLayer)          (None, 4)            0
# __________________________________________________________________________________________________
# multiply_1 (Multiply)           (None, 4)            0           lambda_1[0][0]
#                                                                  input_eps[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 4)            0           KL_Divergence[0][0]
#                                                                  multiply_1[0][0]
# __________________________________________________________________________________________________
# hidden_dec_2 (Dense)            (None, 50)           250         add_1[0][0]
# __________________________________________________________________________________________________
# hidden_dec_1 (Dense)            (None, 50)           2550        hidden_dec_2[0][0]
# __________________________________________________________________________________________________
# x_pred_review_log_mu (Dense)    (None, 1)            51          hidden_dec_1[0][0]
# __________________________________________________________________________________________________
# x_pred_review_log_var (Dense)   (None, 1)            51          hidden_dec_1[0][0]
# __________________________________________________________________________________________________
# x_pred_coordinates_mu (Dense)   (None, 2)            102         hidden_dec_1[0][0]
# __________________________________________________________________________________________________
# x_pred_coordinates_log_var (Den (None, 2)            102         hidden_dec_1[0][0]
# __________________________________________________________________________________________________
# x_pred_binary (Dense)           (None, 1)            51          hidden_dec_1[0][0]
# __________________________________________________________________________________________________
# x_pred_categorical (Dense)      (None, 11)           561         hidden_dec_1[0][0]
# __________________________________________________________________________________________________
# x_pred_review (Concatenate)     (None, 2)            0           x_pred_review_log_mu[0][0]
#                                                                  x_pred_review_log_var[0][0]
# __________________________________________________________________________________________________
# x_pred_coordinates (Concatenate (None, 4)            0           x_pred_coordinates_mu[0][0]
#                                                                  x_pred_coordinates_log_var[0][0]
# ==================================================================================================
# Total params: 7,476
# Trainable params: 7,476
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# ## Data Loading and Preprocessing

# %%
dataset = np.genfromtxt('../../datasets/yelp_business.csv',delimiter=',',skip_header=1)
dataset = dataset[~np.isnan(dataset).any(axis=1)]
test_set, train_set = np.split(dataset,[1], axis = 0)

def format_data(dataset):
  # handling the categorical variables
  coordinates, ratings, reviews, is_opens = np.split(dataset, [2, 3, 4], axis = 1)
  one_hot_array = np.zeros((ratings.shape[0], categorical_dim))

  for i, r in enumerate(ratings):
    one_hot_array[i][categorical_map[r[0]]] = 1
  
  for i, c in enumerate(coordinates):
    coordinates[i][0] = (c[0]+180)/360
    coordinates[i][1] = (c[1]+180)/360

  dataset = np.concatenate((coordinates, reviews, is_opens, one_hot_array), axis = 1)

  # creating the labels
  coordinates_labels = coordinates
  review_labels = reviews
  categorical_labels = one_hot_array
  binary_labels = is_opens
  return dataset, coordinates_labels, review_labels, categorical_labels, binary_labels

train_dataset, train_coordinates_labels, train_review_labels, train_categorical_labels, train_binary_labels = format_data(train_set)
test_dataset, test_coordinates_labels, test_review_labels, test_categorical_labels, test_binary_labels = format_data(test_set)

# %% [markdown]
# ## Training the Model

# %%
vae.fit(train_dataset , [train_binary_labels, train_categorical_labels, train_review_labels, train_coordinates_labels], shuffle = True, epochs = epochs, batch_size = batch_size, validation_data=(test_dataset , [test_binary_labels, test_categorical_labels, test_review_labels, test_coordinates_labels]))
# Out:
# Train on 174565 samples, validate on 1 samples
# Epoch 1/50
# 174565/174565 [==============================] - 8s 48us/step - loss: 140.9234 - x_pred_binary_loss: 0.5176 - x_pred_categorical_loss: 2.1414 - x_pred_review_loss: 134.8584 - x_pred_coordinates_loss: 0.2964 - val_loss: 5.8419 - val_x_pred_binary_loss: 0.1984 - val_x_pred_categorical_loss: 1.5035 - val_x_pred_review_loss: 4.5523 - val_x_pred_coordinates_loss: -2.4716
# Epoch 2/50
# 174565/174565 [==============================] - 7s 41us/step - loss: 5.4299 - x_pred_binary_loss: 0.4502 - x_pred_categorical_loss: 2.0198 - x_pred_review_loss: 4.8680 - x_pred_coordinates_loss: -3.2112 - val_loss: 3.6820 - val_x_pred_binary_loss: 0.1928 - val_x_pred_categorical_loss: 1.6099 - val_x_pred_review_loss: 4.4789 - val_x_pred_coordinates_loss: -3.6335
# Epoch 3/50
# 174565/174565 [==============================] - 7s 39us/step - loss: 4.2862 - x_pred_binary_loss: 0.4416 - x_pred_categorical_loss: 2.0102 - x_pred_review_loss: 4.5482 - x_pred_coordinates_loss: -3.5775 - val_loss: 2.7588 - val_x_pred_binary_loss: 0.1309 - val_x_pred_categorical_loss: 1.6621 - val_x_pred_review_loss: 4.9302 - val_x_pred_coordinates_loss: -4.7498
# Epoch 4/50
# 174565/174565 [==============================] - 7s 40us/step - loss: 3.4036 - x_pred_binary_loss: 0.4381 - x_pred_categorical_loss: 2.0034 - x_pred_review_loss: 4.1403 - x_pred_coordinates_loss: -3.8934 - val_loss: 2.1040 - val_x_pred_binary_loss: 0.1767 - val_x_pred_categorical_loss: 1.3408 - val_x_pred_review_loss: 4.5605 - val_x_pred_coordinates_loss: -4.6194
# Epoch 5/50
# 174565/174565 [==============================] - 8s 47us/step - loss: 2.7619 - x_pred_binary_loss: 0.4388 - x_pred_categorical_loss: 1.9847 - x_pred_review_loss: 3.6806 - x_pred_coordinates_loss: -4.1541 - val_loss: 1.7997 - val_x_pred_binary_loss: 0.1538 - val_x_pred_categorical_loss: 1.4662 - val_x_pred_review_loss: 4.3665 - val_x_pred_coordinates_loss: -4.9134
# Epoch 6/50
# 174565/174565 [==============================] - 8s 47us/step - loss: 2.5899 - x_pred_binary_loss: 0.4390 - x_pred_categorical_loss: 1.9718 - x_pred_review_loss: 3.4504 - x_pred_coordinates_loss: -4.1663 - val_loss: 2.2089 - val_x_pred_binary_loss: 0.1599 - val_x_pred_categorical_loss: 1.4625 - val_x_pred_review_loss: 4.5566 - val_x_pred_coordinates_loss: -4.8449
# Epoch 7/50
# 174565/174565 [==============================] - 8s 46us/step - loss: 2.4686 - x_pred_binary_loss: 0.4397 - x_pred_categorical_loss: 1.9667 - x_pred_review_loss: 3.2455 - x_pred_coordinates_loss: -4.1615 - val_loss: 2.4165 - val_x_pred_binary_loss: 0.1642 - val_x_pred_categorical_loss: 1.4046 - val_x_pred_review_loss: 4.4374 - val_x_pred_coordinates_loss: -4.6541
# Epoch 8/50
# 174565/174565 [==============================] - 8s 44us/step - loss: 2.3660 - x_pred_binary_loss: 0.4404 - x_pred_categorical_loss: 1.9630 - x_pred_review_loss: 3.0563 - x_pred_coordinates_loss: -4.1592 - val_loss: 1.6827 - val_x_pred_binary_loss: 0.1745 - val_x_pred_categorical_loss: 1.3914 - val_x_pred_review_loss: 4.1231 - val_x_pred_coordinates_loss: -5.2583
# Epoch 9/50
# 174565/174565 [==============================] - 8s 48us/step - loss: 2.2726 - x_pred_binary_loss: 0.4402 - x_pred_categorical_loss: 1.9538 - x_pred_review_loss: 2.9300 - x_pred_coordinates_loss: -4.2281 - val_loss: 2.2123 - val_x_pred_binary_loss: 0.1534 - val_x_pred_categorical_loss: 1.4455 - val_x_pred_review_loss: 3.9236 - val_x_pred_coordinates_loss: -4.5807
# Epoch 10/50
# 174565/174565 [==============================] - 9s 49us/step - loss: 2.0489 - x_pred_binary_loss: 0.4401 - x_pred_categorical_loss: 1.9385 - x_pred_review_loss: 2.7684 - x_pred_coordinates_loss: -4.5650 - val_loss: 2.0445 - val_x_pred_binary_loss: 0.1640 - val_x_pred_categorical_loss: 1.3226 - val_x_pred_review_loss: 4.5891 - val_x_pred_coordinates_loss: -5.5286
# Epoch 11/50
# 174565/174565 [==============================] - 8s 45us/step - loss: 1.8239 - x_pred_binary_loss: 0.4398 - x_pred_categorical_loss: 1.9274 - x_pred_review_loss: 2.6218 - x_pred_coordinates_loss: -5.0866 - val_loss: 2.5053 - val_x_pred_binary_loss: 0.1659 - val_x_pred_categorical_loss: 1.6675 - val_x_pred_review_loss: 4.0399 - val_x_pred_coordinates_loss: -5.3194
# Epoch 12/50
# 174565/174565 [==============================] - 7s 42us/step - loss: 1.6492 - x_pred_binary_loss: 0.4393 - x_pred_categorical_loss: 1.9275 - x_pred_review_loss: 2.5224 - x_pred_coordinates_loss: -5.7029 - val_loss: 2.2380 - val_x_pred_binary_loss: 0.1657 - val_x_pred_categorical_loss: 1.5489 - val_x_pred_review_loss: 3.0772 - val_x_pred_coordinates_loss: -5.0286
# Epoch 13/50
# 174565/174565 [==============================] - 7s 41us/step - loss: 1.5046 - x_pred_binary_loss: 0.4388 - x_pred_categorical_loss: 1.9280 - x_pred_review_loss: 2.4657 - x_pred_coordinates_loss: -6.1837 - val_loss: 0.5850 - val_x_pred_binary_loss: 0.1492 - val_x_pred_categorical_loss: 1.4875 - val_x_pred_review_loss: 2.9988 - val_x_pred_coordinates_loss: -6.8113
# Epoch 14/50
# 174565/174565 [==============================] - 9s 50us/step - loss: 1.4265 - x_pred_binary_loss: 0.4387 - x_pred_categorical_loss: 1.9269 - x_pred_review_loss: 2.4073 - x_pred_coordinates_loss: -6.4119 - val_loss: -0.2064 - val_x_pred_binary_loss: 0.1720 - val_x_pred_categorical_loss: 1.7205 - val_x_pred_review_loss: 3.1590 - val_x_pred_coordinates_loss: -8.1136
# Epoch 15/50
# 174565/174565 [==============================] - 6s 37us/step - loss: 1.3697 - x_pred_binary_loss: 0.4385 - x_pred_categorical_loss: 1.9259 - x_pred_review_loss: 2.3300 - x_pred_coordinates_loss: -6.5341 - val_loss: -0.1795 - val_x_pred_binary_loss: 0.1847 - val_x_pred_categorical_loss: 1.6822 - val_x_pred_review_loss: 2.8647 - val_x_pred_coordinates_loss: -7.8708
# Epoch 16/50
# 174565/174565 [==============================] - 7s 38us/step - loss: 1.3150 - x_pred_binary_loss: 0.4386 - x_pred_categorical_loss: 1.9244 - x_pred_review_loss: 2.2607 - x_pred_coordinates_loss: -6.5985 - val_loss: 1.8640 - val_x_pred_binary_loss: 0.1730 - val_x_pred_categorical_loss: 1.5499 - val_x_pred_review_loss: 4.3026 - val_x_pred_coordinates_loss: -7.2705
# Epoch 17/50
# 174565/174565 [==============================] - 7s 41us/step - loss: 1.3140 - x_pred_binary_loss: 0.4383 - x_pred_categorical_loss: 1.9233 - x_pred_review_loss: 2.2618 - x_pred_coordinates_loss: -6.6536 - val_loss: 0.2371 - val_x_pred_binary_loss: 0.1904 - val_x_pred_categorical_loss: 1.7475 - val_x_pred_review_loss: 3.3866 - val_x_pred_coordinates_loss: -8.1058
# Epoch 18/50
# 174565/174565 [==============================] - 8s 44us/step - loss: 1.2616 - x_pred_binary_loss: 0.4382 - x_pred_categorical_loss: 1.9222 - x_pred_review_loss: 2.2519 - x_pred_coordinates_loss: -6.6937 - val_loss: 0.2764 - val_x_pred_binary_loss: 0.1843 - val_x_pred_categorical_loss: 1.6076 - val_x_pred_review_loss: 3.1883 - val_x_pred_coordinates_loss: -7.6997
# Epoch 19/50
# 174565/174565 [==============================] - 7s 42us/step - loss: 1.1960 - x_pred_binary_loss: 0.4379 - x_pred_categorical_loss: 1.9216 - x_pred_review_loss: 2.2179 - x_pred_coordinates_loss: -6.7080 - val_loss: -0.7113 - val_x_pred_binary_loss: 0.1866 - val_x_pred_categorical_loss: 1.6339 - val_x_pred_review_loss: 2.8183 - val_x_pred_coordinates_loss: -8.2196
# Epoch 20/50
# 174565/174565 [==============================] - 7s 41us/step - loss: 1.1238 - x_pred_binary_loss: 0.4378 - x_pred_categorical_loss: 1.9195 - x_pred_review_loss: 2.2084 - x_pred_coordinates_loss: -6.7330 - val_loss: -1.0095 - val_x_pred_binary_loss: 0.1842 - val_x_pred_categorical_loss: 1.5895 - val_x_pred_review_loss: 2.8174 - val_x_pred_coordinates_loss: -8.4145
# Epoch 21/50
# 174565/174565 [==============================] - 8s 44us/step - loss: 1.0417 - x_pred_binary_loss: 0.4372 - x_pred_categorical_loss: 1.9206 - x_pred_review_loss: 2.1659 - x_pred_coordinates_loss: -6.7592 - val_loss: -1.0231 - val_x_pred_binary_loss: 0.1824 - val_x_pred_categorical_loss: 1.6146 - val_x_pred_review_loss: 2.7892 - val_x_pred_coordinates_loss: -8.4440
# Epoch 22/50
# 174565/174565 [==============================] - 7s 38us/step - loss: 1.0114 - x_pred_binary_loss: 0.4372 - x_pred_categorical_loss: 1.9198 - x_pred_review_loss: 2.1665 - x_pred_coordinates_loss: -6.7807 - val_loss: -0.4634 - val_x_pred_binary_loss: 0.1768 - val_x_pred_categorical_loss: 1.4816 - val_x_pred_review_loss: 3.3942 - val_x_pred_coordinates_loss: -8.3582
# Epoch 23/50
# 174565/174565 [==============================] - 6s 36us/step - loss: 0.9511 - x_pred_binary_loss: 0.4373 - x_pred_categorical_loss: 1.9208 - x_pred_review_loss: 2.1581 - x_pred_coordinates_loss: -6.8429 - val_loss: -0.5425 - val_x_pred_binary_loss: 0.1783 - val_x_pred_categorical_loss: 1.5054 - val_x_pred_review_loss: 3.2934 - val_x_pred_coordinates_loss: -8.3779
# Epoch 24/50
# 174565/174565 [==============================] - 7s 40us/step - loss: 0.8403 - x_pred_binary_loss: 0.4373 - x_pred_categorical_loss: 1.9212 - x_pred_review_loss: 2.0746 - x_pred_coordinates_loss: -6.9300 - val_loss: 3.5951 - val_x_pred_binary_loss: 0.1821 - val_x_pred_categorical_loss: 1.7326 - val_x_pred_review_loss: 7.5437 - val_x_pred_coordinates_loss: -8.8165
# Epoch 25/50
# 174565/174565 [==============================] - 7s 41us/step - loss: 0.7444 - x_pred_binary_loss: 0.4372 - x_pred_categorical_loss: 1.9211 - x_pred_review_loss: 2.0584 - x_pred_coordinates_loss: -7.0669 - val_loss: 0.0452 - val_x_pred_binary_loss: 0.1682 - val_x_pred_categorical_loss: 1.4832 - val_x_pred_review_loss: 3.6844 - val_x_pred_coordinates_loss: -8.3290
# Epoch 26/50
# 174565/174565 [==============================] - 7s 41us/step - loss: 0.6183 - x_pred_binary_loss: 0.4373 - x_pred_categorical_loss: 1.9204 - x_pred_review_loss: 2.0138 - x_pred_coordinates_loss: -7.1530 - val_loss: -0.3525 - val_x_pred_binary_loss: 0.1627 - val_x_pred_categorical_loss: 1.4855 - val_x_pred_review_loss: 3.6679 - val_x_pred_coordinates_loss: -8.7014
# Epoch 27/50
# 174565/174565 [==============================] - 7s 38us/step - loss: 0.5558 - x_pred_binary_loss: 0.4375 - x_pred_categorical_loss: 1.9203 - x_pred_review_loss: 1.9941 - x_pred_coordinates_loss: -7.1678 - val_loss: 0.9397 - val_x_pred_binary_loss: 0.1641 - val_x_pred_categorical_loss: 1.4486 - val_x_pred_review_loss: 3.5274 - val_x_pred_coordinates_loss: -7.2829
# Epoch 28/50
# 174565/174565 [==============================] - 6s 35us/step - loss: 0.5540 - x_pred_binary_loss: 0.4378 - x_pred_categorical_loss: 1.9198 - x_pred_review_loss: 2.0265 - x_pred_coordinates_loss: -7.1555 - val_loss: -0.6213 - val_x_pred_binary_loss: 0.1723 - val_x_pred_categorical_loss: 1.5026 - val_x_pred_review_loss: 2.7637 - val_x_pred_coordinates_loss: -8.0932
# Epoch 29/50
# 174565/174565 [==============================] - 7s 39us/step - loss: 0.5098 - x_pred_binary_loss: 0.4379 - x_pred_categorical_loss: 1.9185 - x_pred_review_loss: 2.0098 - x_pred_coordinates_loss: -7.1436 - val_loss: -0.3664 - val_x_pred_binary_loss: 0.1860 - val_x_pred_categorical_loss: 1.6612 - val_x_pred_review_loss: 2.8752 - val_x_pred_coordinates_loss: -8.1631
# Epoch 30/50
# 174565/174565 [==============================] - 8s 44us/step - loss: 0.5248 - x_pred_binary_loss: 0.4379 - x_pred_categorical_loss: 1.9170 - x_pred_review_loss: 2.0552 - x_pred_coordinates_loss: -7.1444 - val_loss: 0.8337 - val_x_pred_binary_loss: 0.1546 - val_x_pred_categorical_loss: 1.4205 - val_x_pred_review_loss: 4.6892 - val_x_pred_coordinates_loss: -8.4186
# Epoch 31/50
# 174565/174565 [==============================] - 8s 47us/step - loss: 1.6413 - x_pred_binary_loss: 0.4382 - x_pred_categorical_loss: 1.9152 - x_pred_review_loss: 3.2193 - x_pred_coordinates_loss: -7.1352 - val_loss: -1.3268 - val_x_pred_binary_loss: 0.1756 - val_x_pred_categorical_loss: 1.5215 - val_x_pred_review_loss: 2.8495 - val_x_pred_coordinates_loss: -8.7738
# Epoch 32/50
# 174565/174565 [==============================] - 6s 34us/step - loss: 0.4970 - x_pred_binary_loss: 0.4384 - x_pred_categorical_loss: 1.9141 - x_pred_review_loss: 2.0279 - x_pred_coordinates_loss: -7.1261 - val_loss: 0.0034 - val_x_pred_binary_loss: 0.1735 - val_x_pred_categorical_loss: 1.5621 - val_x_pred_review_loss: 2.9366 - val_x_pred_coordinates_loss: -7.6886
# Epoch 33/50
# 174565/174565 [==============================] - 7s 39us/step - loss: 0.4278 - x_pred_binary_loss: 0.4382 - x_pred_categorical_loss: 1.9134 - x_pred_review_loss: 1.9307 - x_pred_coordinates_loss: -7.1362 - val_loss: 0.6064 - val_x_pred_binary_loss: 0.1675 - val_x_pred_categorical_loss: 1.4926 - val_x_pred_review_loss: 4.1194 - val_x_pred_coordinates_loss: -8.2210
# Epoch 34/50
# 174565/174565 [==============================] - 6s 34us/step - loss: 0.5681 - x_pred_binary_loss: 0.4381 - x_pred_categorical_loss: 1.9131 - x_pred_review_loss: 2.0456 - x_pred_coordinates_loss: -7.1187 - val_loss: -1.0763 - val_x_pred_binary_loss: 0.1734 - val_x_pred_categorical_loss: 1.5365 - val_x_pred_review_loss: 2.9149 - val_x_pred_coordinates_loss: -8.7412
# Epoch 35/50
# 174565/174565 [==============================] - 6s 35us/step - loss: 0.4907 - x_pred_binary_loss: 0.4378 - x_pred_categorical_loss: 1.9118 - x_pred_review_loss: 1.9676 - x_pred_coordinates_loss: -7.1140 - val_loss: -1.0881 - val_x_pred_binary_loss: 0.1714 - val_x_pred_categorical_loss: 1.5705 - val_x_pred_review_loss: 2.8014 - val_x_pred_coordinates_loss: -8.7058
# Epoch 36/50
# 174565/174565 [==============================] - 6s 35us/step - loss: 0.4527 - x_pred_binary_loss: 0.4372 - x_pred_categorical_loss: 1.9104 - x_pred_review_loss: 1.8842 - x_pred_coordinates_loss: -7.1089 - val_loss: 0.3971 - val_x_pred_binary_loss: 0.1704 - val_x_pred_categorical_loss: 1.4722 - val_x_pred_review_loss: 3.0473 - val_x_pred_coordinates_loss: -7.3406
# Epoch 37/50
# 174565/174565 [==============================] - 6s 34us/step - loss: 0.3688 - x_pred_binary_loss: 0.4372 - x_pred_categorical_loss: 1.9089 - x_pred_review_loss: 1.7743 - x_pred_coordinates_loss: -7.1211 - val_loss: -0.4173 - val_x_pred_binary_loss: 0.1845 - val_x_pred_categorical_loss: 1.6254 - val_x_pred_review_loss: 2.9756 - val_x_pred_coordinates_loss: -8.2876
# Epoch 38/50
# 174565/174565 [==============================] - 6s 35us/step - loss: 0.3791 - x_pred_binary_loss: 0.4371 - x_pred_categorical_loss: 1.9087 - x_pred_review_loss: 1.7637 - x_pred_coordinates_loss: -7.1092 - val_loss: -1.2248 - val_x_pred_binary_loss: 0.1730 - val_x_pred_categorical_loss: 1.5672 - val_x_pred_review_loss: 2.6820 - val_x_pred_coordinates_loss: -8.7311
# Epoch 39/50
# 174565/174565 [==============================] - 6s 33us/step - loss: 0.4428 - x_pred_binary_loss: 0.4378 - x_pred_categorical_loss: 1.9091 - x_pred_review_loss: 1.8489 - x_pred_coordinates_loss: -7.1154 - val_loss: -0.8895 - val_x_pred_binary_loss: 0.1798 - val_x_pred_categorical_loss: 1.5371 - val_x_pred_review_loss: 2.8335 - val_x_pred_coordinates_loss: -8.4022
# Epoch 40/50
# 174565/174565 [==============================] - 6s 36us/step - loss: 0.3385 - x_pred_binary_loss: 0.4375 - x_pred_categorical_loss: 1.9088 - x_pred_review_loss: 1.7315 - x_pred_coordinates_loss: -7.1246 - val_loss: -0.6000 - val_x_pred_binary_loss: 0.1722 - val_x_pred_categorical_loss: 1.5269 - val_x_pred_review_loss: 2.9509 - val_x_pred_coordinates_loss: -8.3803
# Epoch 41/50
# 174565/174565 [==============================] - 6s 35us/step - loss: 0.3103 - x_pred_binary_loss: 0.4374 - x_pred_categorical_loss: 1.9090 - x_pred_review_loss: 1.6737 - x_pred_coordinates_loss: -7.1379 - val_loss: -0.0347 - val_x_pred_binary_loss: 0.1489 - val_x_pred_categorical_loss: 1.4548 - val_x_pred_review_loss: 3.6164 - val_x_pred_coordinates_loss: -8.3383
# Epoch 42/50
# 174565/174565 [==============================] - 6s 32us/step - loss: 0.2856 - x_pred_binary_loss: 0.4375 - x_pred_categorical_loss: 1.9083 - x_pred_review_loss: 1.6359 - x_pred_coordinates_loss: -7.1463 - val_loss: -0.5502 - val_x_pred_binary_loss: 0.1755 - val_x_pred_categorical_loss: 1.6357 - val_x_pred_review_loss: 2.6248 - val_x_pred_coordinates_loss: -8.0798
# Epoch 43/50
# 174565/174565 [==============================] - 6s 34us/step - loss: 0.2793 - x_pred_binary_loss: 0.4376 - x_pred_categorical_loss: 1.9099 - x_pred_review_loss: 1.6326 - x_pred_coordinates_loss: -7.1359 - val_loss: -0.1769 - val_x_pred_binary_loss: 0.1654 - val_x_pred_categorical_loss: 1.6407 - val_x_pred_review_loss: 3.0865 - val_x_pred_coordinates_loss: -8.2497
# Epoch 44/50
# 174565/174565 [==============================] - 6s 34us/step - loss: 0.2917 - x_pred_binary_loss: 0.4378 - x_pred_categorical_loss: 1.9094 - x_pred_review_loss: 1.6092 - x_pred_coordinates_loss: -7.1268 - val_loss: -0.4382 - val_x_pred_binary_loss: 0.1651 - val_x_pred_categorical_loss: 1.5851 - val_x_pred_review_loss: 2.6587 - val_x_pred_coordinates_loss: -7.9698
# Epoch 45/50
# 174565/174565 [==============================] - 6s 35us/step - loss: 0.2777 - x_pred_binary_loss: 0.4377 - x_pred_categorical_loss: 1.9097 - x_pred_review_loss: 1.5972 - x_pred_coordinates_loss: -7.1307 - val_loss: 0.7999 - val_x_pred_binary_loss: 0.1949 - val_x_pred_categorical_loss: 1.6687 - val_x_pred_review_loss: 2.9958 - val_x_pred_coordinates_loss: -7.2396
# Epoch 46/50
# 174565/174565 [==============================] - 6s 34us/step - loss: 0.2579 - x_pred_binary_loss: 0.4375 - x_pred_categorical_loss: 1.9111 - x_pred_review_loss: 1.5575 - x_pred_coordinates_loss: -7.1343 - val_loss: -1.3113 - val_x_pred_binary_loss: 0.1704 - val_x_pred_categorical_loss: 1.4998 - val_x_pred_review_loss: 2.5430 - val_x_pred_coordinates_loss: -8.6930
# Epoch 47/50
# 174565/174565 [==============================] - 8s 43us/step - loss: 0.2712 - x_pred_binary_loss: 0.4379 - x_pred_categorical_loss: 1.9109 - x_pred_review_loss: 1.5568 - x_pred_coordinates_loss: -7.1311 - val_loss: -0.3479 - val_x_pred_binary_loss: 0.1904 - val_x_pred_categorical_loss: 1.6000 - val_x_pred_review_loss: 2.6155 - val_x_pred_coordinates_loss: -7.8522
# Epoch 48/50
# 174565/174565 [==============================] - 9s 50us/step - loss: 0.2536 - x_pred_binary_loss: 0.4376 - x_pred_categorical_loss: 1.9090 - x_pred_review_loss: 1.5332 - x_pred_coordinates_loss: -7.1287 - val_loss: -1.0158 - val_x_pred_binary_loss: 0.1699 - val_x_pred_categorical_loss: 1.5634 - val_x_pred_review_loss: 2.5398 - val_x_pred_coordinates_loss: -8.4709
# Epoch 49/50
# 174565/174565 [==============================] - 7s 38us/step - loss: 0.2340 - x_pred_binary_loss: 0.4376 - x_pred_categorical_loss: 1.9089 - x_pred_review_loss: 1.4653 - x_pred_coordinates_loss: -7.1211 - val_loss: -0.3722 - val_x_pred_binary_loss: 0.1895 - val_x_pred_categorical_loss: 1.6361 - val_x_pred_review_loss: 2.6560 - val_x_pred_coordinates_loss: -8.0035
# Epoch 50/50
# 174565/174565 [==============================] - 7s 37us/step - loss: 0.2249 - x_pred_binary_loss: 0.4375 - x_pred_categorical_loss: 1.9083 - x_pred_review_loss: 1.4171 - x_pred_coordinates_loss: -7.1159 - val_loss: 0.6126 - val_x_pred_binary_loss: 0.1517 - val_x_pred_categorical_loss: 1.5455 - val_x_pred_review_loss: 3.7949 - val_x_pred_coordinates_loss: -8.0578

# %% [markdown]
# ## Building the Decoder

# %%
decode_input = Input(shape=(latent_dim, ), name = 'decode_input')
decode_layer_1 = decode_1(decode_input)
decode_layer_2 = decode_2(decode_layer_1)

x_pred_coordinates_mu = x_pred_coordinates_mu_layer(decode_layer_2)
x_pred_coordinates_log_var = x_pred_coordinates_log_var_layer(decode_layer_2)
decode_x_pred_coordinates = x_pred_coordinates_layer([x_pred_coordinates_mu, x_pred_coordinates_log_var])

x_pred_review_log_mu = x_pred_review_log_mu_layer(decode_layer_2)
x_pred_review_log_var = x_pred_review_log_var_layer(decode_layer_2)
decode_x_pred_review = x_pred_review_layer([x_pred_review_log_mu, x_pred_review_log_var])

decode_x_pred_binary = x_pred_binary_layer(decode_layer_2) # binary cross entropy
decode_x_pred_categorical = x_pred_categorical_layer(decode_layer_2) # categorical cross entropy


decoder = Model(decode_input, [decode_x_pred_coordinates, decode_x_pred_review, decode_x_pred_categorical, decode_x_pred_binary])

# %%
SVG(model_to_dot(decoder, show_shapes=True)
    .create(prog='dot', format='svg'))

# %% [markdown]
# ### Saving the Models and Metadata
# #### Saving Models (Actually, only the decoder matter)

# %%
model_json = vae.to_json()
with open("./model/vae_full_model.json", "w") as json_file:
    json_file.write(model_json)
vae.save_weights("./model/vae_full_model.h5")
print("Saved model to disk")

encoder = Model(x, [z_mu, z_log_var])
model_json = encoder.to_json()
with open("./model/vae_encoder.json", "w") as json_file:
    json_file.write(model_json)
encoder.save_weights("./model/vae_encoder.h5")
print("Saved model to disk")

model_json = decoder.to_json()
with open("./model/vae_decoder.json", "w") as json_file:
    json_file.write(model_json)
decoder.save_weights("./model/vae_decoder.h5")
print("Saved model to disk")
# Out:
# Saved model to disk
# Saved model to disk
# Saved model to disk

# %% [markdown]
# #### Generating and Saving Metadata

# %%
vae_sample = train_dataset[np.random.choice(len(train_dataset), size=10000, replace=False)]
vae_sample_mu, vae_sample_log_var = encoder.predict(vae_sample, batch_size=batch_size)
np.save('./model/sample_mu.npy', vae_sample_mu)
np.save('./model/sample_log_var.npy', vae_sample_log_var)

# %% [markdown]
# ### Generating some Samples for Testing
# #### Functions for data generation

# %%
reverse_categorical_map = {0:0, 1:0.5, 2:1, 3:1.5, 4:2, 5:2.5, 6:3, 7:3.5, 8:4, 9:4.5, 10:5}
def sample(model, input_mu, input_log_var):
    eps = np.random.normal(size=(input_mu.shape[0], latent_dim))
    z = reparameterize(input_mu, input_log_var, eps)
    predictions = model.predict(z, batch_size = None, steps = 1)
    return reconstruct(predictions)
    
def reconstruct(predictions):
    coordinates, review, categorical, binary = predictions
    mu, log_var = np.split(coordinates, indices_or_sections = 2,axis = 1)
    eps = np.random.normal(size=mu.shape)
    coordinates_data = reparameterize(mu, log_var, eps)
    print(coordinates_data)
    for i, c in enumerate(coordinates_data):
        if c[0] > 1.0:
            coordinates_data[i][0]=1.0
        if c[0] < 0.0:
            coordinates_data[i][0]=0.0
        if c[1] > 1.0:
            coordinates_data[i][1]=1.0
        if c[1] < 0.0:
            coordinates_data[i][1]=0.0
        coordinates_data[i][0] = (coordinates_data[i][0]*360)-180
        coordinates_data[i][1] = (coordinates_data[i][1]*360)-180
    log_mu2, log_var2 = np.split(review, indices_or_sections = 2,axis = 1)
    mu2 = np.exp(log_mu2)
    eps2 = np.random.normal(size=mu2.shape)
    review_data = reparameterize(mu2, log_var2, eps2)
    for i, r in enumerate(review_data):
        if r[0] < 0:
            review_data[i][0] = 0
        review_data[i][0] = float(int(review_data[i][0]))
    categorical = np.apply_along_axis(lambda t : np.random.multinomial(1,t), -1, categorical)
    categorical = np.apply_along_axis(lambda t : np.argmax(t), -1, categorical)
    categorical = np.expand_dims(categorical, axis = -1)
    categorical_data = np.apply_along_axis(lambda t : float(reverse_categorical_map[t[0]]), -1, categorical)
    categorical_data = np.expand_dims(categorical_data, axis = -1)
    binary_data = np.apply_along_axis(lambda t: np.random.binomial(1, t), -1, binary)
#     coordinates, reviews = np.split(continuous_data, indices_or_sections=[2], axis = 1)
    return np.concatenate([coordinates_data, categorical_data, review_data, binary_data], axis = 1)
    

def reparameterize(input_mu, input_log_var, eps):
    sigma = np.exp(0.5*input_log_var)
    return eps*sigma + input_mu

# %%
vae_samples = sample(decoder, vae_sample_mu, vae_sample_log_var)
file_name = './samples/vae_2_1_sample_' + str(len(vae_samples)) + '.csv'
np.savetxt(file_name, vae_samples, delimiter = ',', header='latitude,longitude,stars,review_count,is_open')
# Out:
# [[0.60344388 0.27746426]
#  [0.60597194 0.27612589]
#  [0.60216403 0.29921982]
#  ...
#  [0.59947749 0.18256424]
#  [0.59943942 0.18659712]
#  [0.6237338  0.27850319]]
