# %% [markdown]
# # Model Training
# In this notebook, we will train our VAE model. This involves:
#
# 1. Encoder
# 2. Decoder
# 3. Full Model

# %% [markdown]
# ## Importing Packages
# We will be using Keras to build and train our VAE

# %%
from __future__ import absolute_import, division, print_function, unicode_literals
# %matplotlib notebook
import tensorflow as tf

import os
import time
import numpy as np
import glob
import matplotlib.pyplot as plt
import PIL
import imageio
import h5py

import keras
from keras import backend as K
from keras.layers import Input, Dense, Lambda, Layer, Add, Multiply, Concatenate
from keras.models import Model, Sequential
from keras.utils import to_categorical
from keras.models import model_from_json

from IPython import display
import numpy as np
import pandas as pd
from sklearn import preprocessing

from matplotlib.ticker import FormatStrFormatter
from keras.utils.vis_utils import model_to_dot, plot_model
from IPython.display import SVG
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ## Definition of Constants
# Hyper parameters and constants will all be located here for ease of adjustments

# %%
categorical_dim = 11
categorical_map = {0:0, 0.5:1, 1: 2, 1.5:3, 2:4, 2.5:5, 3:6, 3.5:7, 4:8, 4.5:9, 5:10}
reverse_categorical_map = {0:0, 1:0.5, 2:1, 3:1.5, 4:2, 5:2.5, 6:3, 7:3.5, 8:4, 9:4.5, 10:5}
continuous_dim = 3
binary_dim = 1
original_dim = binary_dim + continuous_dim + categorical_dim
intermediate_dim_1 = 12
intermediate_dim_2 = 8
latent_dim = 4
batch_size = 100
epochs = 50
epsilon_std = 1.0

# %% [markdown]
# ## Building the Model
# We have to write our own custom layer and custom loss function as these are not supported on Keras natively. There are a few things to be done:
#
# 1. Custom KLDivergence Layer
# 2. Custom Loss Functions
# 3. Building the Model

# %% [markdown]
# ### KL Divergence Layer
# To ensure modularity, we decided to create a separate layer for KL Divergence. This layer will account for the loss required.

# %%
class KLDivergenceLayer(Layer):

    """ Identity transform layer that adds KL divergence
    to the final model loss.
    """

    def __init__(self, *args, **kwargs):
        self.is_placeholder = True
        super(KLDivergenceLayer, self).__init__(*args, **kwargs)

    def call(self, inputs):

        mu, log_var = inputs

        kl_batch = - .5 * K.sum(1 + log_var -
                                K.square(mu) -
                                K.exp(log_var), axis=-1)

        self.add_loss(K.mean(kl_batch), inputs=inputs)

        return inputs

# %% [markdown]
# ### Custom Loss Functions
# As the yelp dataset contains binary, categorical as well as continuous data, we will build 3 custom loss functions.
#
# #### Binary Loss Function

# %%
def binary_loss(y_true, y_pred):
	# input dimension is (batchsize, 1)
    return K.binary_crossentropy(y_true, y_pred) # the dimension of return value is (batchsize , 1)

# %% [markdown]
# #### Categorical Loss Function

# %%
def categorical_loss(y_true, y_pred):
	# input dimension is (batchsize, number of categories)
  return K.categorical_crossentropy(y_true, y_pred) # the dimension of return value is (batchsize , 1)

# %% [markdown]
# #### Continuous Loss Function

# %%
def log_normal_pdf(sample, mean, logvar, raxis=1):
  log2pi = tf.math.log(2. * np.pi)
  return tf.reduce_sum(
      -.5 * ((sample - mean) ** 2. * tf.exp(-logvar) + logvar + log2pi),
      axis=raxis) # return a tensor of shape (batch_size, 1)

# Added a postfix because now we also have poisson as a distribution
def continuous_loss_gaussian(y_true, y_pred):
	# need to return log probability for continuous gaussian loss.
	# will get a (batchsize, 6 continuous variable input) where 3 of the 6 represents mu and the others logvar
	# y_true will be (batchsize, 3)
  mu, logvar = tf.split(y_pred, num_or_size_splits = 2, axis = 1)
  return -1 * log_normal_pdf(y_true, mu, logvar) 

def continuous_loss_poisson(y_true, y_pred):
	# need to return log probability for continuous poisson loss.
	# will get a (batchsize, 6 continuous variable input) where 3 of the 6 represents mu and the others logvar
	# y_true will be (batchsize, 3)
  return tf.nn.log_poisson_loss(y_true, y_pred)

# %% [markdown]
# ### Model Architecture
# - tanh/sigmoid is used because Relu resulted in loss going to infinity
# - going to delete review_log_var and review_mu since we are trying out the Poission distribution which only takes 1 parameter.

# %%
x = Input(shape=(original_dim,), name='input_x')
h = Dense(intermediate_dim_1, activation='tanh', name='hidden_enc_1')(x)
h = Dense(intermediate_dim_2, activation='tanh', name='hidden_enc_2')(h)

z_mu = Dense(latent_dim, name='z_mu')(h)
z_log_var = Dense(latent_dim, name='z_log_var')(h)

z_mu, z_log_var = KLDivergenceLayer(name='KL_Divergence')([z_mu, z_log_var])
z_sigma = Lambda(lambda t: K.exp(.5*t))(z_log_var)

eps = Input(name='input_eps',tensor=K.random_normal(stddev=epsilon_std,
                                   shape=(K.shape(x)[0], latent_dim)))
z_eps = Multiply()([z_sigma, eps])
z = Add()([z_mu, z_eps])

decode_1 = Dense(intermediate_dim_2, activation='tanh', name='hidden_dec_2')
h_dec = decode_1(z)

decode_2 = Dense(intermediate_dim_1, activation='tanh', name='hidden_dec_1')
h_dec = decode_2(h_dec)

x_pred_coordinates_mu_layer = Dense(2, activation='sigmoid',name='x_pred_coordinates_mu')
x_pred_coordinates_mu = x_pred_coordinates_mu_layer(h_dec)

x_pred_coordinates_log_var_layer = Dense(2, name='x_pred_coordinates_log_var')
x_pred_coordinates_log_var = x_pred_coordinates_log_var_layer(h_dec)

x_pred_coordinates_layer = Concatenate(axis=-1, name = 'x_pred_coordinates')
x_pred_coordinates = x_pred_coordinates_layer([x_pred_coordinates_mu, x_pred_coordinates_log_var])

## This outputs the lambda require for poisson distribution and thats all that we need
x_pred_review_log_lambda_layer = Dense(1,name = 'x_pred_review_log_lambda_layer')
x_pred_review = x_pred_review_log_lambda_layer(h_dec)


# x_pred_review_mu_layer = Dense(1, activation='relu', name='x_pred_review_mu')
# x_pred_review_mu = x_pred_review_mu_layer(h_dec)

# x_pred_review_log_var_layer = Dense(1, name='x_pred_review_log_var')
# x_pred_review_log_var = x_pred_review_log_var_layer(h_dec)

# x_pred_review_layer = Concatenate(axis=-1, name = 'x_pred_review')
# x_pred_review = x_pred_review_layer([x_pred_review_mu, x_pred_review_log_var])

x_pred_binary_layer = Dense(binary_dim, activation='sigmoid', name='x_pred_binary')
x_pred_binary = x_pred_binary_layer(h_dec) # binary cross entropy

x_pred_categorical_layer = Dense(categorical_dim, activation='softmax', name='x_pred_categorical')
x_pred_categorical = x_pred_categorical_layer(h_dec) # categorical cross entropy

vae = Model(inputs=[x,eps], outputs=[x_pred_binary, x_pred_categorical, x_pred_review, x_pred_coordinates])

# %%
SVG(model_to_dot(vae, show_shapes=True)
    .create(prog='dot', format='svg'))

# %%
plot_model(
    model=vae, show_shapes=True,
    to_file='./description/vae_full_model.png'
)

# %% [markdown]
# ### Compiling Model and Setting Parameters

# %%
optimizer = keras.optimizers.Adam(lr=0.0001,clipvalue=1)
vae.compile(optimizer=optimizer, loss=[binary_loss, categorical_loss, continuous_loss_poisson, continuous_loss_gaussian], loss_weights=[1, 1, 1, 1])

# %%
vae.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_x (InputLayer)            (None, 15)           0
# __________________________________________________________________________________________________
# hidden_enc_1 (Dense)            (None, 12)           192         input_x[0][0]
# __________________________________________________________________________________________________
# hidden_enc_2 (Dense)            (None, 8)            104         hidden_enc_1[0][0]
# __________________________________________________________________________________________________
# z_mu (Dense)                    (None, 4)            36          hidden_enc_2[0][0]
# __________________________________________________________________________________________________
# z_log_var (Dense)               (None, 4)            36          hidden_enc_2[0][0]
# __________________________________________________________________________________________________
# KL_Divergence (KLDivergenceLaye [(None, 4), (None, 4 0           z_mu[0][0]
#                                                                  z_log_var[0][0]
# __________________________________________________________________________________________________
# lambda_1 (Lambda)               (None, 4)            0           KL_Divergence[0][1]
# __________________________________________________________________________________________________
# input_eps (InputLayer)          (None, 4)            0
# __________________________________________________________________________________________________
# multiply_1 (Multiply)           (None, 4)            0           lambda_1[0][0]
#                                                                  input_eps[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 4)            0           KL_Divergence[0][0]
#                                                                  multiply_1[0][0]
# __________________________________________________________________________________________________
# hidden_dec_2 (Dense)            (None, 8)            40          add_1[0][0]
# __________________________________________________________________________________________________
# hidden_dec_1 (Dense)            (None, 12)           108         hidden_dec_2[0][0]
# __________________________________________________________________________________________________
# x_pred_coordinates_mu (Dense)   (None, 2)            26          hidden_dec_1[0][0]
# __________________________________________________________________________________________________
# x_pred_coordinates_log_var (Den (None, 2)            26          hidden_dec_1[0][0]
# __________________________________________________________________________________________________
# x_pred_binary (Dense)           (None, 1)            13          hidden_dec_1[0][0]
# __________________________________________________________________________________________________
# x_pred_categorical (Dense)      (None, 11)           143         hidden_dec_1[0][0]
# __________________________________________________________________________________________________
# x_pred_review_log_lambda_layer  (None, 1)            13          hidden_dec_1[0][0]
# __________________________________________________________________________________________________
# x_pred_coordinates (Concatenate (None, 4)            0           x_pred_coordinates_mu[0][0]
#                                                                  x_pred_coordinates_log_var[0][0]
# ==================================================================================================
# Total params: 737
# Trainable params: 737
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# ## Data Loading and Preprocessing

# %%
dataset = np.genfromtxt('../../datasets/yelp_business.csv',delimiter=',',skip_header=1)
dataset = dataset[~np.isnan(dataset).any(axis=1)]
test_set, train_set = np.split(dataset,[1], axis = 0)

def format_data(dataset):
  # handling the categorical variables
  coordinates, ratings, reviews, is_opens = np.split(dataset, [2, 3, 4], axis = 1)
  one_hot_array = np.zeros((ratings.shape[0], categorical_dim))

  for i, r in enumerate(ratings):
    one_hot_array[i][categorical_map[r[0]]] = 1
  
  for i, c in enumerate(coordinates):
    coordinates[i][0] = (c[0]+180)/360
    coordinates[i][1] = (c[1]+180)/360

  dataset = np.concatenate((coordinates, reviews, is_opens, one_hot_array), axis = 1)

  # creating the labels
  coordinates_labels = coordinates
  review_labels = reviews
  categorical_labels = one_hot_array
  binary_labels = is_opens
  return dataset, coordinates_labels, review_labels, categorical_labels, binary_labels

train_dataset, train_coordinates_labels, train_review_labels, train_categorical_labels, train_binary_labels = format_data(train_set)
test_dataset, test_coordinates_labels, test_review_labels, test_categorical_labels, test_binary_labels = format_data(test_set)

# %% [markdown]
# ### Distribution of Review_Count

# %%
# import matplotlib.pyplot as plt
# plt.hist(train_review_labels, 1000)
# plt.show()

# %% [markdown]
# ## Training the Model

# %%
vae.fit(train_dataset , [train_binary_labels, train_categorical_labels, train_review_labels, train_coordinates_labels], shuffle = True, epochs = epochs, batch_size = batch_size, validation_data=(test_dataset , [test_binary_labels, test_categorical_labels, test_review_labels, test_coordinates_labels]))
# Out:
# Train on 174565 samples, validate on 1 samples
# Epoch 1/50
# 174565/174565 [==============================] - 7s 38us/step - loss: -62.7115 - x_pred_binary_loss: 0.6188 - x_pred_categorical_loss: 2.2905 - x_pred_review_log_lambda_layer_loss: -68.2060 - x_pred_coordinates_loss: 1.0216 - val_loss: -40.1262 - val_x_pred_binary_loss: 0.2826 - val_x_pred_categorical_loss: 2.1060 - val_x_pred_review_log_lambda_layer_loss: -44.9232 - val_x_pred_coordinates_loss: 0.6666
# Epoch 2/50
# 174565/174565 [==============================] - 6s 34us/step - loss: -95.4629 - x_pred_binary_loss: 0.4947 - x_pred_categorical_loss: 2.0920 - x_pred_review_log_lambda_layer_loss: -100.4102 - x_pred_coordinates_loss: 0.1296 - val_loss: -42.1726 - val_x_pred_binary_loss: 0.1677 - val_x_pred_categorical_loss: 1.4731 - val_x_pred_review_log_lambda_layer_loss: -45.1335 - val_x_pred_coordinates_loss: -1.3552
# Epoch 3/50
# 174565/174565 [==============================] - 7s 41us/step - loss: -101.6014 - x_pred_binary_loss: 0.4493 - x_pred_categorical_loss: 2.0216 - x_pred_review_log_lambda_layer_loss: -105.3247 - x_pred_coordinates_loss: -1.1976 - val_loss: -43.1128 - val_x_pred_binary_loss: 0.1197 - val_x_pred_categorical_loss: 1.6275 - val_x_pred_review_log_lambda_layer_loss: -45.0036 - val_x_pred_coordinates_loss: -2.2456_categorical_loss: 2.0288 - x_pred_review_log_lambda_layer_l
# Epoch 4/50
# 174565/174565 [==============================] - 7s 38us/step - loss: -104.0593 - x_pred_binary_loss: 0.4447 - x_pred_categorical_loss: 1.9989 - x_pred_review_log_lambda_layer_loss: -106.4208 - x_pred_coordinates_loss: -2.2758 - val_loss: -45.8751 - val_x_pred_binary_loss: 0.1385 - val_x_pred_categorical_loss: 1.5543 - val_x_pred_review_log_lambda_layer_loss: -46.0005 - val_x_pred_coordinates_loss: -3.7438
# Epoch 5/50
# 174565/174565 [==============================] - 8s 44us/step - loss: -105.7721 - x_pred_binary_loss: 0.4419 - x_pred_categorical_loss: 1.9866 - x_pred_review_log_lambda_layer_loss: -107.0120 - x_pred_coordinates_loss: -3.1995 - val_loss: -45.9295 - val_x_pred_binary_loss: 0.1523 - val_x_pred_categorical_loss: 1.6189 - val_x_pred_review_log_lambda_layer_loss: -45.6178 - val_x_pred_coordinates_loss: -4.0579
# Epoch 6/50
# 174565/174565 [==============================] - 6s 37us/step - loss: -107.0124 - x_pred_binary_loss: 0.4404 - x_pred_categorical_loss: 1.9805 - x_pred_review_log_lambda_layer_loss: -107.4436 - x_pred_coordinates_loss: -3.8125 - val_loss: -43.7557 - val_x_pred_binary_loss: 0.1650 - val_x_pred_categorical_loss: 1.4298 - val_x_pred_review_log_lambda_layer_loss: -42.6354 - val_x_pred_coordinates_loss: -4.5073
# Epoch 7/50
# 174565/174565 [==============================] - 7s 43us/step - loss: -107.6533 - x_pred_binary_loss: 0.4398 - x_pred_categorical_loss: 1.9768 - x_pred_review_log_lambda_layer_loss: -107.8194 - x_pred_coordinates_loss: -3.9579 - val_loss: -45.4770 - val_x_pred_binary_loss: 0.1616 - val_x_pred_categorical_loss: 1.6013 - val_x_pred_review_log_lambda_layer_loss: -44.7835 - val_x_pred_coordinates_loss: -4.2361
# Epoch 8/50
# 174565/174565 [==============================] - 8s 47us/step - loss: -107.9709 - x_pred_binary_loss: 0.4395 - x_pred_categorical_loss: 1.9733 - x_pred_review_log_lambda_layer_loss: -108.0351 - x_pred_coordinates_loss: -3.9935 - val_loss: -46.1412 - val_x_pred_binary_loss: 0.1684 - val_x_pred_categorical_loss: 1.5647 - val_x_pred_review_log_lambda_layer_loss: -45.1065 - val_x_pred_coordinates_loss: -4.4811
# Epoch 9/50
# 174565/174565 [==============================] - 7s 37us/step - loss: -108.2087 - x_pred_binary_loss: 0.4393 - x_pred_categorical_loss: 1.9714 - x_pred_review_log_lambda_layer_loss: -108.2394 - x_pred_coordinates_loss: -4.0110 - val_loss: -47.1031 - val_x_pred_binary_loss: 0.1599 - val_x_pred_categorical_loss: 1.5125 - val_x_pred_review_log_lambda_layer_loss: -45.9910 - val_x_pred_coordinates_loss: -4.5334
# Epoch 10/50
# 174565/174565 [==============================] - 10s 55us/step - loss: -108.3676 - x_pred_binary_loss: 0.4392 - x_pred_categorical_loss: 1.9701 - x_pred_review_log_lambda_layer_loss: -108.3115 - x_pred_coordinates_loss: -4.0215 - val_loss: -46.6485 - val_x_pred_binary_loss: 0.1689 - val_x_pred_categorical_loss: 1.5317 - val_x_pred_review_log_lambda_layer_loss: -45.4440 - val_x_pred_coordinates_loss: -4.6438
# Epoch 11/50
# 174565/174565 [==============================] - 11s 62us/step - loss: -108.4648 - x_pred_binary_loss: 0.4391 - x_pred_categorical_loss: 1.9698 - x_pred_review_log_lambda_layer_loss: -108.3642 - x_pred_coordinates_loss: -4.0297 - val_loss: -47.2526 - val_x_pred_binary_loss: 0.1659 - val_x_pred_categorical_loss: 1.4599 - val_x_pred_review_log_lambda_layer_loss: -45.9090 - val_x_pred_coordinates_loss: -4.6995
# Epoch 12/50
# 174565/174565 [==============================] - 8s 48us/step - loss: -108.5416 - x_pred_binary_loss: 0.4390 - x_pred_categorical_loss: 1.9690 - x_pred_review_log_lambda_layer_loss: -108.4228 - x_pred_coordinates_loss: -4.0323 - val_loss: -47.2646 - val_x_pred_binary_loss: 0.1625 - val_x_pred_categorical_loss: 1.4848 - val_x_pred_review_log_lambda_layer_loss: -46.0018 - val_x_pred_coordinates_loss: -4.6260
# Epoch 13/50
# 174565/174565 [==============================] - 8s 44us/step - loss: -108.6221 - x_pred_binary_loss: 0.4389 - x_pred_categorical_loss: 1.9687 - x_pred_review_log_lambda_layer_loss: -108.4815 - x_pred_coordinates_loss: -4.0358 - val_loss: -44.2359 - val_x_pred_binary_loss: 0.1720 - val_x_pred_categorical_loss: 1.6149 - val_x_pred_review_log_lambda_layer_loss: -43.4993 - val_x_pred_coordinates_loss: -4.2406
# Epoch 14/50
# 174565/174565 [==============================] - 8s 43us/step - loss: -108.7039 - x_pred_binary_loss: 0.4387 - x_pred_categorical_loss: 1.9686 - x_pred_review_log_lambda_layer_loss: -108.5444 - x_pred_coordinates_loss: -4.0408 - val_loss: -45.2224 - val_x_pred_binary_loss: 0.1667 - val_x_pred_categorical_loss: 1.3723 - val_x_pred_review_log_lambda_layer_loss: -43.6256 - val_x_pred_coordinates_loss: -4.8680
# Epoch 15/50
# 174565/174565 [==============================] - 6s 37us/step - loss: -108.7774 - x_pred_binary_loss: 0.4386 - x_pred_categorical_loss: 1.9682 - x_pred_review_log_lambda_layer_loss: -108.6165 - x_pred_coordinates_loss: -4.0449 - val_loss: -46.5004 - val_x_pred_binary_loss: 0.1638 - val_x_pred_categorical_loss: 1.4166 - val_x_pred_review_log_lambda_layer_loss: -45.1941 - val_x_pred_coordinates_loss: -4.6423ed_binary_loss: 0.4412 - x_pred_categorical_loss: 1.9700 - x
# Epoch 16/50
# 174565/174565 [==============================] - 5s 30us/step - loss: -108.7852 - x_pred_binary_loss: 0.4386 - x_pred_categorical_loss: 1.9683 - x_pred_review_log_lambda_layer_loss: -108.6005 - x_pred_coordinates_loss: -4.0479 - val_loss: -47.2491 - val_x_pred_binary_loss: 0.1694 - val_x_pred_categorical_loss: 1.4725 - val_x_pred_review_log_lambda_layer_loss: -45.9084 - val_x_pred_coordinates_loss: -4.6991
# Epoch 17/50
# 174565/174565 [==============================] - 5s 31us/step - loss: -108.8370 - x_pred_binary_loss: 0.4385 - x_pred_categorical_loss: 1.9679 - x_pred_review_log_lambda_layer_loss: -108.6456 - x_pred_coordinates_loss: -4.0539 - val_loss: -45.9663 - val_x_pred_binary_loss: 0.1666 - val_x_pred_categorical_loss: 1.5615 - val_x_pred_review_log_lambda_layer_loss: -44.8788 - val_x_pred_coordinates_loss: -4.5478
# Epoch 18/50
# 174565/174565 [==============================] - 5s 31us/step - loss: -108.8713 - x_pred_binary_loss: 0.4385 - x_pred_categorical_loss: 1.9676 - x_pred_review_log_lambda_layer_loss: -108.6679 - x_pred_coordinates_loss: -4.0561 - val_loss: -46.8834 - val_x_pred_binary_loss: 0.1753 - val_x_pred_categorical_loss: 1.5026 - val_x_pred_review_log_lambda_layer_loss: -45.7910 - val_x_pred_coordinates_loss: -4.4943
# Epoch 19/50
# 174565/174565 [==============================] - 5s 31us/step - loss: -108.8918 - x_pred_binary_loss: 0.4384 - x_pred_categorical_loss: 1.9674 - x_pred_review_log_lambda_layer_loss: -108.6885 - x_pred_coordinates_loss: -4.0610 - val_loss: -46.5569 - val_x_pred_binary_loss: 0.1695 - val_x_pred_categorical_loss: 1.5221 - val_x_pred_review_log_lambda_layer_loss: -45.4823 - val_x_pred_coordinates_loss: -4.5362
# Epoch 20/50
# 174565/174565 [==============================] - 5s 31us/step - loss: -108.9284 - x_pred_binary_loss: 0.4383 - x_pred_categorical_loss: 1.9674 - x_pred_review_log_lambda_layer_loss: -108.7451 - x_pred_coordinates_loss: -4.0619 - val_loss: -46.8686 - val_x_pred_binary_loss: 0.1695 - val_x_pred_categorical_loss: 1.5177 - val_x_pred_review_log_lambda_layer_loss: -45.7836 - val_x_pred_coordinates_loss: -4.5150
# Epoch 21/50
# 174565/174565 [==============================] - 5s 31us/step - loss: -108.9604 - x_pred_binary_loss: 0.4384 - x_pred_categorical_loss: 1.9679 - x_pred_review_log_lambda_layer_loss: -108.7460 - x_pred_coordinates_loss: -4.0665 - val_loss: -46.9945 - val_x_pred_binary_loss: 0.1686 - val_x_pred_categorical_loss: 1.5061 - val_x_pred_review_log_lambda_layer_loss: -45.7802 - val_x_pred_coordinates_loss: -4.6470
# Epoch 22/50
# 174565/174565 [==============================] - 5s 30us/step - loss: -108.9580 - x_pred_binary_loss: 0.4383 - x_pred_categorical_loss: 1.9679 - x_pred_review_log_lambda_layer_loss: -108.7463 - x_pred_coordinates_loss: -4.0691 - val_loss: -46.9170 - val_x_pred_binary_loss: 0.1641 - val_x_pred_categorical_loss: 1.4430 - val_x_pred_review_log_lambda_layer_loss: -45.6343 - val_x_pred_coordinates_loss: -4.6437
# Epoch 23/50
# 174565/174565 [==============================] - 5s 30us/step - loss: -108.9906 - x_pred_binary_loss: 0.4383 - x_pred_categorical_loss: 1.9675 - x_pred_review_log_lambda_layer_loss: -108.7553 - x_pred_coordinates_loss: -4.0725 - val_loss: -46.6564 - val_x_pred_binary_loss: 0.1698 - val_x_pred_categorical_loss: 1.5175 - val_x_pred_review_log_lambda_layer_loss: -45.5629 - val_x_pred_coordinates_loss: -4.5304
# Epoch 24/50
# 174565/174565 [==============================] - 5s 30us/step - loss: -109.0149 - x_pred_binary_loss: 0.4383 - x_pred_categorical_loss: 1.9673 - x_pred_review_log_lambda_layer_loss: -108.8085 - x_pred_coordinates_loss: -4.0758 - val_loss: -47.3321 - val_x_pred_binary_loss: 0.1646 - val_x_pred_categorical_loss: 1.4572 - val_x_pred_review_log_lambda_layer_loss: -45.9581 - val_x_pred_coordinates_loss: -4.7206
# Epoch 25/50
# 174565/174565 [==============================] - 5s 30us/step - loss: -109.0330 - x_pred_binary_loss: 0.4383 - x_pred_categorical_loss: 1.9677 - x_pred_review_log_lambda_layer_loss: -108.7873 - x_pred_coordinates_loss: -4.0810 - val_loss: -46.9689 - val_x_pred_binary_loss: 0.1662 - val_x_pred_categorical_loss: 1.4407 - val_x_pred_review_log_lambda_layer_loss: -45.7310 - val_x_pred_coordinates_loss: -4.5739
# Epoch 26/50
# 174565/174565 [==============================] - 5s 30us/step - loss: -109.0428 - x_pred_binary_loss: 0.4383 - x_pred_categorical_loss: 1.9675 - x_pred_review_log_lambda_layer_loss: -108.8040 - x_pred_coordinates_loss: -4.0819 - val_loss: -47.1425 - val_x_pred_binary_loss: 0.1701 - val_x_pred_categorical_loss: 1.4839 - val_x_pred_review_log_lambda_layer_loss: -46.0011 - val_x_pred_coordinates_loss: -4.5255
# Epoch 27/50
# 174565/174565 [==============================] - 7s 39us/step - loss: -109.0402 - x_pred_binary_loss: 0.4382 - x_pred_categorical_loss: 1.9680 - x_pred_review_log_lambda_layer_loss: -108.8121 - x_pred_coordinates_loss: -4.0891 - val_loss: -47.0559 - val_x_pred_binary_loss: 0.1699 - val_x_pred_categorical_loss: 1.4655 - val_x_pred_review_log_lambda_layer_loss: -45.9681 - val_x_pred_coordinates_loss: -4.5060
# Epoch 28/50
# 174565/174565 [==============================] - 6s 32us/step - loss: -109.0205 - x_pred_binary_loss: 0.4382 - x_pred_categorical_loss: 1.9680 - x_pred_review_log_lambda_layer_loss: -108.7915 - x_pred_coordinates_loss: -4.0913 - val_loss: -47.1070 - val_x_pred_binary_loss: 0.1664 - val_x_pred_categorical_loss: 1.4387 - val_x_pred_review_log_lambda_layer_loss: -45.7209 - val_x_pred_coordinates_loss: -4.7367
# Epoch 29/50
# 174565/174565 [==============================] - 9s 50us/step - loss: -109.0477 - x_pred_binary_loss: 0.4382 - x_pred_categorical_loss: 1.9681 - x_pred_review_log_lambda_layer_loss: -108.8002 - x_pred_coordinates_loss: -4.0941 - val_loss: -47.1188 - val_x_pred_binary_loss: 0.1659 - val_x_pred_categorical_loss: 1.4475 - val_x_pred_review_log_lambda_layer_loss: -45.9340 - val_x_pred_coordinates_loss: -4.5271
# Epoch 30/50
# 174565/174565 [==============================] - 9s 49us/step - loss: -109.0510 - x_pred_binary_loss: 0.4382 - x_pred_categorical_loss: 1.9680 - x_pred_review_log_lambda_layer_loss: -108.7929 - x_pred_coordinates_loss: -4.1014 - val_loss: -46.7427 - val_x_pred_binary_loss: 0.1637 - val_x_pred_categorical_loss: 1.4206 - val_x_pred_review_log_lambda_layer_loss: -45.3802 - val_x_pred_coordinates_loss: -4.6909_binary_loss: 0.4386 - x_pred_categorical_loss: 1.9668
# Epoch 31/50
# 174565/174565 [==============================] - 6s 35us/step - loss: -109.0644 - x_pred_binary_loss: 0.4382 - x_pred_categorical_loss: 1.9684 - x_pred_review_log_lambda_layer_loss: -108.8057 - x_pred_coordinates_loss: -4.1048 - val_loss: -46.9407 - val_x_pred_binary_loss: 0.1634 - val_x_pred_categorical_loss: 1.4376 - val_x_pred_review_log_lambda_layer_loss: -45.7916 - val_x_pred_coordinates_loss: -4.4918
# Epoch 32/50
# 174565/174565 [==============================] - 6s 34us/step - loss: -109.0808 - x_pred_binary_loss: 0.4382 - x_pred_categorical_loss: 1.9683 - x_pred_review_log_lambda_layer_loss: -108.8489 - x_pred_coordinates_loss: -4.1094 - val_loss: -45.2934 - val_x_pred_binary_loss: 0.1692 - val_x_pred_categorical_loss: 1.5693 - val_x_pred_review_log_lambda_layer_loss: -44.0668 - val_x_pred_coordinates_loss: -4.7090
# Epoch 33/50
# 174565/174565 [==============================] - 6s 33us/step - loss: -109.0856 - x_pred_binary_loss: 0.4382 - x_pred_categorical_loss: 1.9688 - x_pred_review_log_lambda_layer_loss: -108.8257 - x_pred_coordinates_loss: -4.1159 - val_loss: -46.9256 - val_x_pred_binary_loss: 0.1730 - val_x_pred_categorical_loss: 1.5178 - val_x_pred_review_log_lambda_layer_loss: -45.8620 - val_x_pred_coordinates_loss: -4.5324
# Epoch 34/50
# 174565/174565 [==============================] - 6s 35us/step - loss: -109.0703 - x_pred_binary_loss: 0.4382 - x_pred_categorical_loss: 1.9687 - x_pred_review_log_lambda_layer_loss: -108.7977 - x_pred_coordinates_loss: -4.1233 - val_loss: -46.3883 - val_x_pred_binary_loss: 0.1603 - val_x_pred_categorical_loss: 1.3831 - val_x_pred_review_log_lambda_layer_loss: -44.7394 - val_x_pred_coordinates_loss: -4.9195
# Epoch 35/50
# 174565/174565 [==============================] - 7s 38us/step - loss: -109.0792 - x_pred_binary_loss: 0.4382 - x_pred_categorical_loss: 1.9691 - x_pred_review_log_lambda_layer_loss: -108.8049 - x_pred_coordinates_loss: -4.1312 - val_loss: -47.0246 - val_x_pred_binary_loss: 0.1725 - val_x_pred_categorical_loss: 1.5077 - val_x_pred_review_log_lambda_layer_loss: -45.9660 - val_x_pred_coordinates_loss: -4.4492
# Epoch 36/50
# 174565/174565 [==============================] - 6s 32us/step - loss: -109.0743 - x_pred_binary_loss: 0.4381 - x_pred_categorical_loss: 1.9687 - x_pred_review_log_lambda_layer_loss: -108.7915 - x_pred_coordinates_loss: -4.1402 - val_loss: -47.2563 - val_x_pred_binary_loss: 0.1680 - val_x_pred_categorical_loss: 1.5037 - val_x_pred_review_log_lambda_layer_loss: -45.7391 - val_x_pred_coordinates_loss: -4.8898
# Epoch 37/50
# 174565/174565 [==============================] - 6s 34us/step - loss: -109.0949 - x_pred_binary_loss: 0.4381 - x_pred_categorical_loss: 1.9690 - x_pred_review_log_lambda_layer_loss: -108.8186 - x_pred_coordinates_loss: -4.1457 - val_loss: -47.3807 - val_x_pred_binary_loss: 0.1676 - val_x_pred_categorical_loss: 1.4764 - val_x_pred_review_log_lambda_layer_loss: -45.9313 - val_x_pred_coordinates_loss: -4.8003
# Epoch 38/50
# 174565/174565 [==============================] - 6s 32us/step - loss: -109.0864 - x_pred_binary_loss: 0.4381 - x_pred_categorical_loss: 1.9692 - x_pred_review_log_lambda_layer_loss: -108.7922 - x_pred_coordinates_loss: -4.1567 - val_loss: -47.1330 - val_x_pred_binary_loss: 0.1713 - val_x_pred_categorical_loss: 1.4670 - val_x_pred_review_log_lambda_layer_loss: -45.8218 - val_x_pred_coordinates_loss: -4.6950
# Epoch 39/50
# 174565/174565 [==============================] - 6s 32us/step - loss: -109.1073 - x_pred_binary_loss: 0.4381 - x_pred_categorical_loss: 1.9696 - x_pred_review_log_lambda_layer_loss: -108.8196 - x_pred_coordinates_loss: -4.1626 - val_loss: -46.3311 - val_x_pred_binary_loss: 0.1710 - val_x_pred_categorical_loss: 1.5396 - val_x_pred_review_log_lambda_layer_loss: -44.7261 - val_x_pred_coordinates_loss: -5.0469
# Epoch 40/50
# 174565/174565 [==============================] - 6s 36us/step - loss: -109.1092 - x_pred_binary_loss: 0.4381 - x_pred_categorical_loss: 1.9695 - x_pred_review_log_lambda_layer_loss: -108.8096 - x_pred_coordinates_loss: -4.1754 - val_loss: -47.2812 - val_x_pred_binary_loss: 0.1730 - val_x_pred_categorical_loss: 1.4407 - val_x_pred_review_log_lambda_layer_loss: -45.9250 - val_x_pred_coordinates_loss: -4.7151
# Epoch 41/50
# 174565/174565 [==============================] - 6s 33us/step - loss: -109.1164 - x_pred_binary_loss: 0.4380 - x_pred_categorical_loss: 1.9694 - x_pred_review_log_lambda_layer_loss: -108.7936 - x_pred_coordinates_loss: -4.1893 - val_loss: -47.0370 - val_x_pred_binary_loss: 0.1724 - val_x_pred_categorical_loss: 1.5280 - val_x_pred_review_log_lambda_layer_loss: -45.4864 - val_x_pred_coordinates_loss: -4.9495
# Epoch 42/50
# 174565/174565 [==============================] - 6s 37us/step - loss: -109.1345 - x_pred_binary_loss: 0.4380 - x_pred_categorical_loss: 1.9696 - x_pred_review_log_lambda_layer_loss: -108.8247 - x_pred_coordinates_loss: -4.2038 - val_loss: -46.6288 - val_x_pred_binary_loss: 0.1715 - val_x_pred_categorical_loss: 1.4928 - val_x_pred_review_log_lambda_layer_loss: -45.5489 - val_x_pred_coordinates_loss: -4.4838
# Epoch 43/50
# 174565/174565 [==============================] - 6s 33us/step - loss: -109.1384 - x_pred_binary_loss: 0.4381 - x_pred_categorical_loss: 1.9695 - x_pred_review_log_lambda_layer_loss: -108.8033 - x_pred_coordinates_loss: -4.2238 - val_loss: -47.0411 - val_x_pred_binary_loss: 0.1748 - val_x_pred_categorical_loss: 1.5165 - val_x_pred_review_log_lambda_layer_loss: -45.9129 - val_x_pred_coordinates_loss: -4.5731
# Epoch 44/50
# 174565/174565 [==============================] - 6s 33us/step - loss: -109.1267 - x_pred_binary_loss: 0.4380 - x_pred_categorical_loss: 1.9692 - x_pred_review_log_lambda_layer_loss: -108.8190 - x_pred_coordinates_loss: -4.2443 - val_loss: -47.4324 - val_x_pred_binary_loss: 0.1716 - val_x_pred_categorical_loss: 1.4943 - val_x_pred_review_log_lambda_layer_loss: -45.9858 - val_x_pred_coordinates_loss: -4.8428
# Epoch 45/50
# 174565/174565 [==============================] - 6s 32us/step - loss: -109.1577 - x_pred_binary_loss: 0.4380 - x_pred_categorical_loss: 1.9693 - x_pred_review_log_lambda_layer_loss: -108.7993 - x_pred_coordinates_loss: -4.2798 - val_loss: -46.6196 - val_x_pred_binary_loss: 0.1795 - val_x_pred_categorical_loss: 1.5896 - val_x_pred_review_log_lambda_layer_loss: -45.8235 - val_x_pred_coordinates_loss: -4.3366
# Epoch 46/50
# 174565/174565 [==============================] - 6s 34us/step - loss: -109.1920 - x_pred_binary_loss: 0.4380 - x_pred_categorical_loss: 1.9686 - x_pred_review_log_lambda_layer_loss: -108.8173 - x_pred_coordinates_loss: -4.3190 - val_loss: -46.8349 - val_x_pred_binary_loss: 0.1734 - val_x_pred_categorical_loss: 1.5136 - val_x_pred_review_log_lambda_layer_loss: -45.3569 - val_x_pred_coordinates_loss: -4.9081
# Epoch 47/50
# 174565/174565 [==============================] - 6s 37us/step - loss: -109.2044 - x_pred_binary_loss: 0.4379 - x_pred_categorical_loss: 1.9674 - x_pred_review_log_lambda_layer_loss: -108.8077 - x_pred_coordinates_loss: -4.3825 - val_loss: -47.2194 - val_x_pred_binary_loss: 0.1682 - val_x_pred_categorical_loss: 1.5070 - val_x_pred_review_log_lambda_layer_loss: -45.1854 - val_x_pred_coordinates_loss: -5.4534
# Epoch 48/50
# 174565/174565 [==============================] - 6s 35us/step - loss: -109.2071 - x_pred_binary_loss: 0.4379 - x_pred_categorical_loss: 1.9658 - x_pred_review_log_lambda_layer_loss: -108.7696 - x_pred_coordinates_loss: -4.4796 - val_loss: -46.5964 - val_x_pred_binary_loss: 0.1635 - val_x_pred_categorical_loss: 1.3781 - val_x_pred_review_log_lambda_layer_loss: -44.5235 - val_x_pred_coordinates_loss: -5.3801
# Epoch 49/50
# 174565/174565 [==============================] - 5s 31us/step - loss: -109.2608 - x_pred_binary_loss: 0.4379 - x_pred_categorical_loss: 1.9628 - x_pred_review_log_lambda_layer_loss: -108.7536 - x_pred_coordinates_loss: -4.6107 - val_loss: -46.9871 - val_x_pred_binary_loss: 0.1757 - val_x_pred_categorical_loss: 1.4493 - val_x_pred_review_log_lambda_layer_loss: -45.7058 - val_x_pred_coordinates_loss: -4.6826
# Epoch 50/50
# 174565/174565 [==============================] - 5s 31us/step - loss: -109.3628 - x_pred_binary_loss: 0.4379 - x_pred_categorical_loss: 1.9589 - x_pred_review_log_lambda_layer_loss: -108.7684 - x_pred_coordinates_loss: -4.7724 - val_loss: -47.1560 - val_x_pred_binary_loss: 0.1711 - val_x_pred_categorical_loss: 1.4223 - val_x_pred_review_log_lambda_layer_loss: -45.6211 - val_x_pred_coordinates_loss: -5.0127

# %% [markdown]
# ## Building the Decoder

# %%
decode_input = Input(shape=(latent_dim, ), name = 'decode_input')
decode_layer_1 = decode_1(decode_input)
decode_layer_2 = decode_2(decode_layer_1)

x_pred_coordinates_mu = x_pred_coordinates_mu_layer(decode_layer_2)
x_pred_coordinates_log_var = x_pred_coordinates_log_var_layer(decode_layer_2)
decode_x_pred_coordinates = x_pred_coordinates_layer([x_pred_coordinates_mu, x_pred_coordinates_log_var])

decode_x_pred_review = x_pred_review_log_lambda_layer(decode_layer_2)

decode_x_pred_binary = x_pred_binary_layer(decode_layer_2) # binary cross entropy
decode_x_pred_categorical = x_pred_categorical_layer(decode_layer_2) # categorical cross entropy


decoder = Model(decode_input, [decode_x_pred_coordinates, decode_x_pred_review, decode_x_pred_categorical, decode_x_pred_binary])

# %%
SVG(model_to_dot(decoder, show_shapes=True)
    .create(prog='dot', format='svg'))

# %% [markdown]
# ### Saving the Models and Metadata
# #### Saving Models (Actually, only the decoder matter)

# %%
model_json = vae.to_json()
with open("./model/vae_full_model.json", "w") as json_file:
    json_file.write(model_json)
vae.save_weights("./model/vae_full_model.h5")
print("Saved model to disk")

encoder = Model(x, [z_mu, z_log_var])
model_json = encoder.to_json()
with open("./model/vae_encoder.json", "w") as json_file:
    json_file.write(model_json)
encoder.save_weights("./model/vae_encoder.h5")
print("Saved model to disk")

model_json = decoder.to_json()
with open("./model/vae_decoder.json", "w") as json_file:
    json_file.write(model_json)
decoder.save_weights("./model/vae_decoder.h5")
print("Saved model to disk")
# Out:
# Saved model to disk
# Saved model to disk
# Saved model to disk

# %% [markdown]
# #### Generating and Saving Metadata

# %%
vae_sample = train_dataset[np.random.choice(len(train_dataset), size=10000, replace=False)]
vae_sample_mu, vae_sample_log_var = encoder.predict(vae_sample, batch_size=batch_size)
np.save('./model/sample_mu.npy', vae_sample_mu)
np.save('./model/sample_log_var.npy', vae_sample_log_var)

# %% [markdown]
# ### Generating some Samples for Testing
# #### Functions for data generation

# %%
reverse_categorical_map = {0:0, 1:0.5, 2:1, 3:1.5, 4:2, 5:2.5, 6:3, 7:3.5, 8:4, 9:4.5, 10:5}
def sample(model, input_mu, input_log_var, samples_per_z=1):
    multiplied_input_mu = np.repeat(input_mu, samples_per_z, axis=0)
    multiplied_input_log_var = np.repeat(input_log_var, samples_per_z, axis=0)
    eps = np.random.normal(size=(multiplied_input_mu.shape[0], latent_dim))
    z = reparameterize(multiplied_input_mu, multiplied_input_log_var, eps)
    predictions = model.predict(z, batch_size = None, steps = 1)
    return reconstruct(predictions)
    
def reconstruct(predictions):
    coordinates, review, categorical, binary = predictions
    mu, log_var = np.split(coordinates, indices_or_sections = 2,axis = 1)
    eps = np.random.normal(size=mu.shape)
    
    ## coordinates handled here
    coordinates_data = reparameterize(mu, log_var, eps)
    print(coordinates_data)
    for i, c in enumerate(coordinates_data):
        if c[0] > 1.0:
            coordinates_data[i][0]=1.0
        if c[0] < 0.0:
            coordinates_data[i][0]=0.0
        if c[1] > 1.0:
            coordinates_data[i][1]=1.0
        if c[1] < 0.0:
            coordinates_data[i][1]=0.0
        coordinates_data[i][0] = (coordinates_data[i][0]*360)-180
        coordinates_data[i][1] = (coordinates_data[i][1]*360)-180
    
    ## review_count handled here
    review_data = np.random.poisson(lam=review, size = review.shape)
    for i, r in enumerate(review_data):
        if r[0] < 0:
            review_data[i][0] = 0
        review_data[i][0] = float(int(review_data[i][0]))
    
    categorical = np.apply_along_axis(lambda t : np.random.multinomial(1,t), -1, categorical)
    categorical = np.apply_along_axis(lambda t : np.argmax(t), -1, categorical)
    categorical = np.expand_dims(categorical, axis = -1)
    categorical_data = np.apply_along_axis(lambda t : float(reverse_categorical_map[t[0]]), -1, categorical)
    categorical_data = np.expand_dims(categorical_data, axis = -1)
    binary_data = np.apply_along_axis(lambda t: np.random.binomial(1, t), -1, binary)
#     coordinates, reviews = np.split(continuous_data, indices_or_sections=[2], axis = 1)
    return np.concatenate([coordinates_data, categorical_data, review_data, binary_data], axis = 1)
    

def reparameterize(input_mu, input_log_var, eps):
    sigma = np.exp(0.5*input_log_var)
    return eps*sigma + input_mu

# %% [markdown]
# ### Generating Samples
# Make use of the funciton sample to generate samples with our model. U need to supply an array of mu and their respective log var in a separate array to do that.

# %%
vae_samples = sample(decoder, vae_sample_mu, vae_sample_log_var)

# Saving the samples in a separate file
file_name = './samples/vae_4_sample_' + str(len(vae_samples)) + '.csv'
np.savetxt(file_name, vae_samples, delimiter = ',', header='latitude,longitude,stars,review_count,is_open')
# Out:
# [[0.59806709 0.21368881]
#  [0.63074334 0.3118804 ]
#  [0.6002255  0.12343806]
#  ...
#  [0.59839346 0.2320461 ]
#  [0.64251922 0.39499036]
#  [0.6017589  0.23453208]]

# %%
vae_samples[1:10]
# Out:
# array([[  47.06760341,  -67.72305614,    1.5       ,    3.        ,
#            1.        ],
#        [  36.08117857, -135.56229991,    3.        ,    0.        ,
#            1.        ],
#        [  43.29169317,  -96.81232227,    4.        ,    0.        ,
#            1.        ],
#        [  46.98011256,  -75.4714896 ,    5.        ,    1.        ,
#            0.        ],
#        [  40.39510699, -107.10779982,    4.        ,    4.        ,
#            1.        ],
#        [  38.61113838, -120.69743336,    4.        ,    4.        ,
#            1.        ],
#        [  30.53145247,  -95.73843796,    2.        ,    1.        ,
#            0.        ],
#        [  38.14695729, -106.58889332,    2.        ,    3.        ,
#            1.        ],
#        [  45.48466586,  -62.7778726 ,    3.5       ,    2.        ,
#            1.        ]])
