# %% [markdown]
# # Model Training
# In this notebook, we will train our VAE model. This involves:
#
# 1. Encoder
# 2. Decoder
# 3. Full Model

# %% [markdown]
# ## Importing Packages
# We will be using Keras to build and train our VAE

# %%
from __future__ import absolute_import, division, print_function, unicode_literals
# %matplotlib notebook
import tensorflow as tf

import os
import time
import numpy as np
import glob
import matplotlib.pyplot as plt
import PIL
import imageio
import h5py

# import keras
from tensorflow.keras import backend as K
from tensorflow.keras.layers import (Input, Dense, Lambda, Flatten, Reshape, BatchNormalization, 
                          Activation, Dropout, Conv2D, Conv2DTranspose,
                          Concatenate, Add, Multiply)
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import model_from_json

from tensorflow.keras.regularizers import l2
from tensorflow.keras.initializers import RandomUniform
from tensorflow.keras.optimizers import RMSprop, Adam, SGD
from tensorflow.keras import metrics


import mdn
from made import MaskingDense

# import tensorflow.compat.v2 as tf
# tf.enable_v2_behavior()

import tensorflow_probability as tfp

from IPython import display
import numpy as np
import pandas as pd
from sklearn import preprocessing
from pickle import dump, load

from matplotlib.ticker import FormatStrFormatter
from IPython.display import SVG

# %% [markdown]
# ## Definition of Constants
# Hyper parameters and constants will all be located here for ease of adjustments

# %%
categorical_dim = 11
categorical_map = {0:0, 0.5:1, 1: 2, 1.5:3, 2:4, 2.5:5, 3:6, 3.5:7, 4:8, 4.5:9, 5:10}
reverse_categorical_map = {0:0, 1:0.5, 2:1, 3:1.5, 4:2, 5:2.5, 6:3, 7:3.5, 8:4, 9:4.5, 10:5}
continuous_dim = 3
binary_dim = 1
original_dim = binary_dim + continuous_dim + categorical_dim
intermediate_dim_1 = 50
intermediate_dim_2 = 50
latent_dim = 4
batch_size = 100
epochs = 50
epsilon_std = 1.0

## Constants for the Mixture layer
N_HIDDEN = 15  # number of hidden units in the Dense layer
N_MIXES = 10  # number of mixture components
OUTPUT_DIMS = 2  # number of real-values predicted by each mixture component

# Model File Paths
full_model_file = "./model/vae_full_model.json"
full_model_weights = "./model/vae_full_model.h5"
encoder_file = "./model/vae_encoder.json"
encoder_weights = "./model/vae_encoder.h5"
decoder_file = './model/vae_decoder.json'
decoder_weights = './model/vae_decoder.h5'
z_meta_file = './model/z_meta.npy'

## Normalizing Flows
num_iaf = 4
# _z_sigmas = []

# %% [markdown]
# ## Building the Model
# We have to write our own custom layer and custom loss function as these are not supported on Keras natively. There are a few things to be done:
#
# 1. Custom KLDivergence Layer
# 2. Custom Loss Functions
# 3. Building the Model

# %% [markdown]
# ### Custom Loss Functions
# As the yelp dataset contains binary, categorical as well as continuous data, we will build 3 custom loss functions.
#
# #### Binary Loss Function

# %%
def binary_loss(y_true, y_pred):
	# input dimension is (batchsize, 1)
    return K.binary_crossentropy(y_true, y_pred) # the dimension of return value is (batchsize , 1)

# %% [markdown]
# #### Categorical Loss Function

# %%
def categorical_loss(y_true, y_pred):
	# input dimension is (batchsize, number of categories)
  return K.categorical_crossentropy(y_true, y_pred) # the dimension of return value is (batchsize , 1)

# %% [markdown]
# #### Continuous Loss Function

# %%
def log_normal_pdf(sample, mean, logvar, raxis=1):
  log2pi = tf.math.log(2. * np.pi)
  return tf.reduce_sum(
      -.5 * ((sample - mean) ** 2. * tf.exp(-logvar) + logvar + log2pi),
      axis=raxis) # return a tensor of shape (batch_size, 1)

# Added a postfix because now we also have poisson as a distribution
def continuous_loss_gaussian(y_true, y_pred):
	# need to return log probability for continuous gaussian loss.
	# will get a (batchsize, 6 continuous variable input) where 3 of the 6 represents mu and the others logvar
	# y_true will be (batchsize, 3)
  mu, logvar = tf.split(y_pred, num_or_size_splits = 2, axis = 1)
  return -1 * log_normal_pdf(y_true, mu, logvar) 

def continuous_loss_poisson(y_true, y_pred):
	# need to return log probability for continuous poisson loss.
	# will get a (batchsize, 6 continuous variable input) where 3 of the 6 represents mu and the others logvar
	# y_true will be (batchsize, 3)
  return tf.nn.log_poisson_loss(y_true, y_pred)

# %% [markdown]
# ### Model Architecture
# - tanh/sigmoid is used because Relu resulted in loss going to infinity
# - going to delete review_log_var and review_mu since we are trying out the Poission distribution which only takes 1 parameter.

# %%
def combine_arnn(args):
    z_t, mean, sigma = args
    return z_t * sigma + mean * (1. - sigma)

def make_iaf_layer(prev_z, enc_h, reverse=False):
    if reverse:
        prev_z = Lambda(lambda x: K.reverse(x, axes=-1))(prev_z)
        
    iaf_in = [prev_z, enc_h] if enc_h is not None else prev_z
    m = MaskingDense(masking_dim, latent_dim, dropout_rate=0., hidden_layers=2,
                     kernel_regularizer=l2(0.001),
                     bias_regularizer=l2(0.001),
                     activation='sigmoid', out_activation=None)(iaf_in)
    s = MaskingDense(masking_dim, latent_dim, dropout_rate=0., hidden_layers=2,
                     kernel_regularizer=l2(0.001),
                     bias_regularizer=l2(0.001),
                     activation='sigmoid', out_activation=None)(iaf_in)
    sigma = Activation('sigmoid')(s)
    
    return Lambda(combine_arnn)([prev_z, m, sigma]), sigma

# %%
tf.compat.v1.disable_eager_execution()
tfk = tf.keras
tfkl = tf.keras.layers
tfpl = tfp.layers
tfd = tfp.distributions

def epsilon(args, batch_size=batch_size, latent_dim=latent_dim, epsilon_std=epsilon_std):
    return K.random_normal(shape=(batch_size, latent_dim), mean=0., stddev=epsilon_std)

def combine_z_0(args, batch_size=batch_size, latent_dim=latent_dim, epsilon_std=epsilon_std):
    eps, z_mean, z_log_sigma = args
    return z_mean + K.exp(z_log_sigma) * eps

input_shape = (original_dim,)
prior = tfd.Independent(tfd.Normal(loc=tf.zeros(latent_dim), scale=1), reinterpreted_batch_ndims=1)

## Encoder

x = Input(shape=(original_dim,), name='input_x')
h = Dense(intermediate_dim_1, activation='tanh', name='hidden_enc_1')(x)
h_enc_2 = Dense(intermediate_dim_2, activation='tanh', name='hidden_enc_2')(h)

z_mu = Dense(latent_dim, name='z_mu')(h_enc_2)
z_log_var = Dense(latent_dim, name='z_log_var')(h_enc_2)

e_0 = Lambda(epsilon)(h_enc_2)
_z_sigmas = []
_z_mean_0 = Dense(latent_dim)(h_enc_2)
_z_log_sigma_0 = Dense(latent_dim)(h_enc_2)
z_0 = Lambda(combine_z_0)([e_0, _z_mean_0, _z_log_sigma_0])

# sampler = tfk.Sequential([
#     tfkl.InputLayer(input_shape=(tfpl.IndependentNormal.params_size(latent_dim), ), name = 'input_z_params'),
#     tfpl.IndependentNormal( latent_dim, name = 'sample_layer'),
# ])


## Normalizing Flows
masking_dim = 10 * latent_dim
h = Dense(latent_dim, activation='sigmoid')(h_enc_2)
z_t = z_0
for i in range(num_iaf):
    reverse = (i > 0)
    z_t, _z_sigma_t = make_iaf_layer(z_t, h, reverse=reverse)
    _z_sigmas.append(_z_sigma_t)
z = z_t


decode_1 = tfkl.Dense(intermediate_dim_2, activation='tanh', name='hidden_dec_2')
h_dec = decode_1(z)

decode_2 = tfkl.Dense(intermediate_dim_1, activation='tanh', name='hidden_dec_1')
h_dec = decode_2(h_dec)

x_pred_coordinates_mdn_layer = mdn.MDN(OUTPUT_DIMS, N_MIXES, name = 'x_pred_coordinates_mdn_layer')
x_pred_coordinates = x_pred_coordinates_mdn_layer(h_dec)


## This outputs the lambda require for poisson distribution and thats all that we need
x_pred_review_log_lambda_layer = tfkl.Dense(1,name = 'x_pred_review_log_lambda_layer')
x_pred_review = x_pred_review_log_lambda_layer(h_dec)

x_pred_binary_layer = tfkl.Dense(binary_dim, activation='sigmoid', name='x_pred_binary')
x_pred_binary = x_pred_binary_layer(h_dec) # binary cross entropy

x_pred_categorical_layer = tfkl.Dense(categorical_dim, name='x_pred_categorical')
x_pred_categorical_layer_activation = tfkl.Activation(tf.nn.softmax)
x_pred_categorical = x_pred_categorical_layer(h_dec) # categorical cross entropy
x_pred_categorical = x_pred_categorical_layer_activation(x_pred_categorical)

vae = tfk.Model(inputs=x, outputs=[x_pred_binary, x_pred_categorical, x_pred_review, x_pred_coordinates])
# encoder = tfk.Model(inputs=x, outputs=z_t)

# %% [markdown]
# ### Visualizing the Model

# %%
tf.keras.utils.plot_model(
    vae, to_file='./description/vae_full_model.png', show_shapes=True, show_layer_names=True,
    rankdir='TB', expand_nested=False, dpi=96
)

# %%
import math
def logpz(x, x_decoded_mean):
    return -K.sum(0.5 * np.log(2*math.pi) + 0.5 * z ** 2, axis=-1)

def logqz_x(x, x_decoded_mean):
    det = _z_log_sigma_0
    for z_sigma in _z_sigmas:
        det += K.log(z_sigma)
    
    return -K.sum(0.5 * np.log(2*math.pi) + 0.5 * e_0 ** 2 + det, axis=-1)

def logpx_z(x, x_decoded_mean):
# #     x = K.flatten(x)
#     x_decoded_mean = K.flatten(x_decoded_mean)
    xent_loss = 1 * metrics.binary_crossentropy(x, x_decoded_mean)
    return -xent_loss

def vae_loss(x, x_decoded_mean):
    # ELBO: - [logp(x|z) + logp(z) - logq(z|x)] = -logp(x|z) - logp(z) + logq(z|x)
    return K.mean(-logpx_z(x, x_decoded_mean) - logpz(x, x_decoded_mean) + logqz_x(x, x_decoded_mean), axis=-1)

# %% [markdown]
# ### Compiling Model and Setting Parameters

# %%
optimizer = tf.keras.optimizers.Adam(lr=0.0001)
vae.compile(optimizer=optimizer, loss=[vae_loss, categorical_loss, continuous_loss_poisson, mdn.get_mixture_loss_func(OUTPUT_DIMS,N_MIXES)], loss_weights=[1, 1, 1, 1])
# Out:
# WARNING:tensorflow:From /Users/tanliangwei/Desktop/fyp_repo/tf_1/lib/python3.6/site-packages/tensorflow_core/python/ops/linalg/linear_operator_diag.py:166: calling LinearOperator.__init__ (from tensorflow.python.ops.linalg.linear_operator) with graph_parents is deprecated and will be removed in a future version.
# Instructions for updating:
# Do not pass `graph_parents`.  They will  no longer be used.

# %% [markdown]
# ### Alternatively, you can upload the weights which was trained during the previous time

# %%
vae.load_weights(full_model_weights)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-103-11b210e9007e> in <module>
# ----> 1 vae.load_weights(full_model_weights)
#
# ~/Desktop/fyp_repo/tf_1/lib/python3.6/site-packages/tensorflow_core/python/keras/engine/training.py in load_weights(self, filepath, by_name, skip_mismatch)
#     232         raise ValueError('Load weights is not yet supported with TPUStrategy '
#     233                          'with steps_per_run greater than 1.')
# --> 234     return super(Model, self).load_weights(filepath, by_name, skip_mismatch)
#     235
#     236   @trackable.no_automatic_dependency_tracking
#
# ~/Desktop/fyp_repo/tf_1/lib/python3.6/site-packages/tensorflow_core/python/keras/engine/network.py in load_weights(self, filepath, by_name, skip_mismatch)
#    1220             f, self.layers, skip_mismatch=skip_mismatch)
#    1221       else:
# -> 1222         hdf5_format.load_weights_from_hdf5_group(f, self.layers)
#    1223
#    1224   def _updated_config(self):
#
# ~/Desktop/fyp_repo/tf_1/lib/python3.6/site-packages/tensorflow_core/python/keras/saving/hdf5_format.py in load_weights_from_hdf5_group(f, layers)
#     697                        str(len(weight_values)) + ' elements.')
#     698     weight_value_tuples += zip(symbolic_weights, weight_values)
# --> 699   K.batch_set_value(weight_value_tuples)
#     700
#     701
#
# ~/Desktop/fyp_repo/tf_1/lib/python3.6/site-packages/tensorflow_core/python/keras/backend.py in batch_set_value(tuples)
#    3321     with ops.init_scope():
#    3322       for x, value in tuples:
# -> 3323         x.assign(np.asarray(value, dtype=dtype(x)))
#    3324   else:
#    3325     with get_graph().as_default():
#
# ~/Desktop/fyp_repo/tf_1/lib/python3.6/site-packages/tensorflow_core/python/ops/resource_variable_ops.py in assign(self, value, use_locking, name, read_value)
#     817     with _handle_graph(self.handle):
#     818       value_tensor = ops.convert_to_tensor(value, dtype=self.dtype)
# --> 819       self._shape.assert_is_compatible_with(value_tensor.shape)
#     820       assign_op = gen_resource_variable_ops.assign_variable_op(
#     821           self.handle, value_tensor, name=name)
#
# ~/Desktop/fyp_repo/tf_1/lib/python3.6/site-packages/tensorflow_core/python/framework/tensor_shape.py in assert_is_compatible_with(self, other)
#    1108     """
#    1109     if not self.is_compatible_with(other):
# -> 1110       raise ValueError("Shapes %s and %s are incompatible" % (self, other))
#    1111
#    1112   def most_specific_compatible_shape(self, other):
#
# ValueError: Shapes (50, 11) and (50, 1) are incompatible

# %%
vae.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_x (InputLayer)            [(None, 15)]         0
# __________________________________________________________________________________________________
# hidden_enc_1 (Dense)            (None, 50)           800         input_x[0][0]
# __________________________________________________________________________________________________
# hidden_enc_2 (Dense)            (None, 50)           2550        hidden_enc_1[0][0]
# __________________________________________________________________________________________________
# z_probability_distribution (Den (None, 8)            408         hidden_enc_2[0][0]
# __________________________________________________________________________________________________
# sequential_1 (Sequential)       (None, 4)            0           z_probability_distribution[0][0]
# __________________________________________________________________________________________________
# hidden_dec_2 (Dense)            (None, 50)           250         sequential_1[1][0]
# __________________________________________________________________________________________________
# hidden_dec_1 (Dense)            (None, 50)           2550        hidden_dec_2[0][0]
# __________________________________________________________________________________________________
# x_pred_categorical (Dense)      (None, 11)           561         hidden_dec_1[0][0]
# __________________________________________________________________________________________________
# x_pred_binary (Dense)           (None, 1)            51          hidden_dec_1[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 11)           0           x_pred_categorical[0][0]
# __________________________________________________________________________________________________
# x_pred_review_log_lambda_layer  (None, 1)            51          hidden_dec_1[0][0]
# __________________________________________________________________________________________________
# x_pred_coordinates_mdn_layer (M (None, 50)           2550        hidden_dec_1[0][0]
# ==================================================================================================
# Total params: 9,771
# Trainable params: 9,771
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# ## Data Loading and Preprocessing

# %% [markdown]
# ### Converting Coordinates to 2D Euclidean space (mercator)

# %%
import math
def lonlat2meters(lon, lat):
    semimajoraxis = 6378137.0
    east = lon * 0.017453292519943295
    north = lat * 0.017453292519943295
    t = math.sin(north)
    return semimajoraxis * east, 3189068.5 * math.log((1 + t) / (1 - t))

def meters2lonlat(x, y):
    semimajoraxis = 6378137.0
    lon = x / semimajoraxis / 0.017453292519943295
    t = math.exp(y / 3189068.5)
    lat = math.asin((t - 1) / (t + 1)) / 0.017453292519943295
    return lon, lat

# %%
dataset = np.genfromtxt('../../datasets/yelp_business.csv',delimiter=',',skip_header=1)
dataset = dataset[~np.isnan(dataset).any(axis=1)]
test_set, train_set = np.split(dataset,[66], axis = 0)

def format_data(dataset, scaler_to_use=None ,save_scaler=True):
    # handling the categorical variables
    coordinates, ratings, reviews, is_opens = np.split(dataset, [2, 3, 4], axis = 1)
    one_hot_array = np.zeros((ratings.shape[0], categorical_dim))

    for i, r in enumerate(ratings):
        one_hot_array[i][categorical_map[r[0]]] = 1
    
    # handling coordinates
    for i, c in enumerate(coordinates):
        lon = coordinates[i][1]
        lat = coordinates[i][0]
        x, y = lonlat2meters(lon, lat)
        coordinates[i][1] = x
        coordinates[i][0] = y
    
    if scaler_to_use is None:
        scaler_to_use = preprocessing.StandardScaler()
        scaler_to_use.fit(coordinates)
    
    coordinates = scaler_to_use.transform(coordinates)
    
    if save_scaler:
        dump(scaler_to_use, open('./model/standard_scaler.pkl', 'wb'))
    
    dataset = np.concatenate((coordinates, reviews, is_opens, one_hot_array), axis = 1)

    # creating the labels
    coordinates_labels = coordinates
    review_labels = reviews
    categorical_labels = one_hot_array
    binary_labels = is_opens
    return dataset, coordinates_labels, review_labels, categorical_labels, binary_labels

train_dataset, train_coordinates_labels, train_review_labels, train_categorical_labels, train_binary_labels = format_data(train_set)

## Open scaler
scaler = load(open('./model/standard_scaler.pkl', 'rb'))
test_dataset, test_coordinates_labels, test_review_labels, test_categorical_labels, test_binary_labels = format_data(test_set, scaler, False)

# %% [markdown]
# ### Distribution of Review_Count

# %%
import matplotlib.pyplot as plt
plt.hist(train_review_labels, 1000)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ## Training the Model

# %%
tf.compat.v1.disable_eager_execution()

# %%
vae.fit(train_dataset , [train_binary_labels, train_categorical_labels, train_review_labels, train_coordinates_labels], shuffle = True, epochs = epochs, batch_size = batch_size )
# Out:
# Train on 174500 samples
# Epoch 1/50
# 174500/174500 [==============================] - 16s 90us/sample - loss: -103.3559 - x_pred_binary_loss: 3.2488 - activation_9_loss: 1.9924 - x_pred_review_log_lambda_layer_loss: -108.6248 - x_pred_coordinates_mdn_layer_loss: 0.0101
# Epoch 2/50
# 174500/174500 [==============================] - 16s 94us/sample - loss: -104.6122 - x_pred_binary_loss: 3.1285 - activation_9_loss: 1.9775 - x_pred_review_log_lambda_layer_loss: -108.6936 - x_pred_coordinates_mdn_layer_loss: -1.0380
# Epoch 3/50
# 174500/174500 [==============================] - 17s 98us/sample - loss: -105.7523 - x_pred_binary_loss: 3.0603 - activation_9_loss: 1.9704 - x_pred_review_log_lambda_layer_loss: -108.7677 - x_pred_coordinates_mdn_layer_loss: -2.0271
# Epoch 4/50
# 174500/174500 [==============================] - 17s 99us/sample - loss: -106.1890 - x_pred_binary_loss: 2.9470 - activation_9_loss: 1.9668 - x_pred_review_log_lambda_layer_loss: -108.7359 - x_pred_coordinates_mdn_layer_loss: -2.3781
# Epoch 5/50
# 174500/174500 [==============================] - 18s 101us/sample - loss: -106.5997 - x_pred_binary_loss: 2.8076 - activation_9_loss: 1.9646 - x_pred_review_log_lambda_layer_loss: -108.7802 - x_pred_coordinates_mdn_layer_loss: -2.6028
# Epoch 6/50
# 174500/174500 [==============================] - 18s 101us/sample - loss: -106.9032 - x_pred_binary_loss: 2.6853 - activation_9_loss: 1.9633 - x_pred_review_log_lambda_layer_loss: -108.8009 - x_pred_coordinates_mdn_layer_loss: -2.7617
# Epoch 7/50
# 174500/174500 [==============================] - 18s 103us/sample - loss: -107.1653 - x_pred_binary_loss: 2.5589 - activation_9_loss: 1.9627 - x_pred_review_log_lambda_layer_loss: -108.8221 - x_pred_coordinates_mdn_layer_loss: -2.8753
# Epoch 8/50
# 174500/174500 [==============================] - 17s 98us/sample - loss: -107.2985 - x_pred_binary_loss: 2.4786 - activation_9_loss: 1.9611 - x_pred_review_log_lambda_layer_loss: -108.7952 - x_pred_coordinates_mdn_layer_loss: -2.9532s - loss: -106.8057 - x_pred_binary_loss: 2.4870 - activation_9_loss: 1.9617 - x_pred_review_log_
# Epoch 9/50
# 174500/174500 [==============================] - 17s 97us/sample - loss: -107.4479 - x_pred_binary_loss: 2.4211 - activation_9_loss: 1.9615 - x_pred_review_log_lambda_layer_loss: -108.8242 - x_pred_coordinates_mdn_layer_loss: -3.0163
# Epoch 10/50
# 174500/174500 [==============================] - 17s 100us/sample - loss: -107.5782 - x_pred_binary_loss: 2.3592 - activation_9_loss: 1.9609 - x_pred_review_log_lambda_layer_loss: -108.8436 - x_pred_coordinates_mdn_layer_loss: -3.0642
# Epoch 11/50
# 174500/174500 [==============================] - 17s 100us/sample - loss: -107.6166 - x_pred_binary_loss: 2.3409 - activation_9_loss: 1.9599 - x_pred_review_log_lambda_layer_loss: -108.8213 - x_pred_coordinates_mdn_layer_loss: -3.1054
# Epoch 12/50
# 174500/174500 [==============================] - 17s 98us/sample - loss: -107.6430 - x_pred_binary_loss: 2.3260 - activation_9_loss: 1.9588 - x_pred_review_log_lambda_layer_loss: -108.8005 - x_pred_coordinates_mdn_layer_loss: -3.1366
# Epoch 13/50
# 174500/174500 [==============================] - 17s 99us/sample - loss: -107.7067 - x_pred_binary_loss: 2.3102 - activation_9_loss: 1.9586 - x_pred_review_log_lambda_layer_loss: -108.8247 - x_pred_coordinates_mdn_layer_loss: -3.1599
# Epoch 14/50
# 174500/174500 [==============================] - 17s 99us/sample - loss: -107.7253 - x_pred_binary_loss: 2.2700 - activation_9_loss: 1.9579 - x_pred_review_log_lambda_layer_loss: -108.7799 - x_pred_coordinates_mdn_layer_loss: -3.1822
# Epoch 15/50
# 174500/174500 [==============================] - 19s 111us/sample - loss: -107.7581 - x_pred_binary_loss: 2.2916 - activation_9_loss: 1.9564 - x_pred_review_log_lambda_layer_loss: -108.8081 - x_pred_coordinates_mdn_layer_loss: -3.2068
# Epoch 16/50
# 174500/174500 [==============================] - 18s 101us/sample - loss: -107.8462 - x_pred_binary_loss: 2.2611 - activation_9_loss: 1.9560 - x_pred_review_log_lambda_layer_loss: -108.8551 - x_pred_coordinates_mdn_layer_loss: -3.2171
# Epoch 17/50
# 174500/174500 [==============================] - 17s 97us/sample - loss: -107.8876 - x_pred_binary_loss: 2.2303 - activation_9_loss: 1.9552 - x_pred_review_log_lambda_layer_loss: -108.8515 - x_pred_coordinates_mdn_layer_loss: -3.2301
# Epoch 18/50
# 174500/174500 [==============================] - 17s 98us/sample - loss: -107.8656 - x_pred_binary_loss: 2.2133 - activation_9_loss: 1.9545 - x_pred_review_log_lambda_layer_loss: -108.8019 - x_pred_coordinates_mdn_layer_loss: -3.2400
# Epoch 19/50
# 174500/174500 [==============================] - 17s 98us/sample - loss: -107.9250 - x_pred_binary_loss: 2.2232 - activation_9_loss: 1.9540 - x_pred_review_log_lambda_layer_loss: -108.8528 - x_pred_coordinates_mdn_layer_loss: -3.2578
# Epoch 20/50
# 174500/174500 [==============================] - 17s 98us/sample - loss: -107.9595 - x_pred_binary_loss: 2.2009 - activation_9_loss: 1.9522 - x_pred_review_log_lambda_layer_loss: -108.8584 - x_pred_coordinates_mdn_layer_loss: -3.2625
# Epoch 21/50
# 174500/174500 [==============================] - 18s 101us/sample - loss: -107.9507 - x_pred_binary_loss: 2.1959 - activation_9_loss: 1.9521 - x_pred_review_log_lambda_layer_loss: -108.8334 - x_pred_coordinates_mdn_layer_loss: -3.2734
# Epoch 22/50
# 174500/174500 [==============================] - 17s 98us/sample - loss: -108.0100 - x_pred_binary_loss: 2.1713 - activation_9_loss: 1.9508 - x_pred_review_log_lambda_layer_loss: -108.8619 - x_pred_coordinates_mdn_layer_loss: -3.2784
# Epoch 23/50
# 174500/174500 [==============================] - 17s 97us/sample - loss: -107.9806 - x_pred_binary_loss: 2.1725 - activation_9_loss: 1.9491 - x_pred_review_log_lambda_layer_loss: -108.8189 - x_pred_coordinates_mdn_layer_loss: -3.2913
# Epoch 24/50
# 174500/174500 [==============================] - 17s 97us/sample - loss: -107.9757 - x_pred_binary_loss: 2.1789 - activation_9_loss: 1.9486 - x_pred_review_log_lambda_layer_loss: -108.8128 - x_pred_coordinates_mdn_layer_loss: -3.2985
# Epoch 25/50
# 174500/174500 [==============================] - 17s 96us/sample - loss: -107.9856 - x_pred_binary_loss: 2.1889 - activation_9_loss: 1.9485 - x_pred_review_log_lambda_layer_loss: -108.8254 - x_pred_coordinates_mdn_layer_loss: -3.3055
# Epoch 26/50
# 174500/174500 [==============================] - 17s 99us/sample - loss: -107.9683 - x_pred_binary_loss: 2.1981 - activation_9_loss: 1.9467 - x_pred_review_log_lambda_layer_loss: -108.8079 - x_pred_coordinates_mdn_layer_loss: -3.3130s - loss: -108.3411 - x_pred_binary_loss: 2.1941 - activatio
# Epoch 27/50
# 174500/174500 [==============================] - 17s 97us/sample - loss: -108.0069 - x_pred_binary_loss: 2.1910 - activation_9_loss: 1.9463 - x_pred_review_log_lambda_layer_loss: -108.8319 - x_pred_coordinates_mdn_layer_loss: -3.3203
# Epoch 28/50
# 174500/174500 [==============================] - 17s 97us/sample - loss: -108.0446 - x_pred_binary_loss: 2.1620 - activation_9_loss: 1.9448 - x_pred_review_log_lambda_layer_loss: -108.8288 - x_pred_coordinates_mdn_layer_loss: -3.3305
# Epoch 29/50
# 174500/174500 [==============================] - 17s 97us/sample - loss: -108.0701 - x_pred_binary_loss: 2.1664 - activation_9_loss: 1.9441 - x_pred_review_log_lambda_layer_loss: -108.8448 - x_pred_coordinates_mdn_layer_loss: -3.3435
# Epoch 30/50
# 174500/174500 [==============================] - 17s 96us/sample - loss: -108.1331 - x_pred_binary_loss: 2.1384 - activation_9_loss: 1.9423 - x_pred_review_log_lambda_layer_loss: -108.8765 - x_pred_coordinates_mdn_layer_loss: -3.3449
# Epoch 31/50
# 174500/174500 [==============================] - 17s 99us/sample - loss: -108.1262 - x_pred_binary_loss: 2.1318 - activation_9_loss: 1.9404 - x_pred_review_log_lambda_layer_loss: -108.8539 - x_pred_coordinates_mdn_layer_loss: -3.3522
# Epoch 32/50
# 174500/174500 [==============================] - 18s 101us/sample - loss: -108.1646 - x_pred_binary_loss: 2.1196 - activation_9_loss: 1.9386 - x_pred_review_log_lambda_layer_loss: -108.8710 - x_pred_coordinates_mdn_layer_loss: -3.3595
# Epoch 33/50
# 174500/174500 [==============================] - 16s 89us/sample - loss: -108.1447 - x_pred_binary_loss: 2.1224 - activation_9_loss: 1.9372 - x_pred_review_log_lambda_layer_loss: -108.8428 - x_pred_coordinates_mdn_layer_loss: -3.3690
# Epoch 34/50
# 174500/174500 [==============================] - 16s 92us/sample - loss: -108.1840 - x_pred_binary_loss: 2.1403 - activation_9_loss: 1.9345 - x_pred_review_log_lambda_layer_loss: -108.8904 - x_pred_coordinates_mdn_layer_loss: -3.3759
# Epoch 35/50
# 174500/174500 [==============================] - 16s 90us/sample - loss: -107.9899 - x_pred_binary_loss: 2.1570 - activation_9_loss: 1.9342 - x_pred_review_log_lambda_layer_loss: -108.7048 - x_pred_coordinates_mdn_layer_loss: -3.3838
# Epoch 36/50
# 174500/174500 [==============================] - 16s 90us/sample - loss: -108.1815 - x_pred_binary_loss: 2.1597 - activation_9_loss: 1.9322 - x_pred_review_log_lambda_layer_loss: -108.8873 - x_pred_coordinates_mdn_layer_loss: -3.3936
# Epoch 37/50
# 174500/174500 [==============================] - 16s 90us/sample - loss: -108.1861 - x_pred_binary_loss: 2.1507 - activation_9_loss: 1.9298 - x_pred_review_log_lambda_layer_loss: -108.8748 - x_pred_coordinates_mdn_layer_loss: -3.3992
# Epoch 38/50
# 174500/174500 [==============================] - 16s 91us/sample - loss: -108.1306 - x_pred_binary_loss: 2.1379 - activation_9_loss: 1.9281 - x_pred_review_log_lambda_layer_loss: -108.8029 - x_pred_coordinates_mdn_layer_loss: -3.4012
# Epoch 39/50
# 174500/174500 [==============================] - 16s 91us/sample - loss: -108.2163 - x_pred_binary_loss: 2.1399 - activation_9_loss: 1.9271 - x_pred_review_log_lambda_layer_loss: -108.8852 - x_pred_coordinates_mdn_layer_loss: -3.4056
# Epoch 40/50
# 174500/174500 [==============================] - 16s 92us/sample - loss: -108.2183 - x_pred_binary_loss: 2.1495 - activation_9_loss: 1.9242 - x_pred_review_log_lambda_layer_loss: -108.8804 - x_pred_coordinates_mdn_layer_loss: -3.4189
# Epoch 41/50
# 174500/174500 [==============================] - 16s 91us/sample - loss: -108.2465 - x_pred_binary_loss: 2.1415 - activation_9_loss: 1.9226 - x_pred_review_log_lambda_layer_loss: -108.8988 - x_pred_coordinates_mdn_layer_loss: -3.4189
# Epoch 42/50
# 174500/174500 [==============================] - 16s 91us/sample - loss: -108.2503 - x_pred_binary_loss: 2.1339 - activation_9_loss: 1.9206 - x_pred_review_log_lambda_layer_loss: -108.8856 - x_pred_coordinates_mdn_layer_loss: -3.4264
# Epoch 43/50
# 174500/174500 [==============================] - 16s 90us/sample - loss: -108.2637 - x_pred_binary_loss: 2.1289 - activation_9_loss: 1.9193 - x_pred_review_log_lambda_layer_loss: -108.8881 - x_pred_coordinates_mdn_layer_loss: -3.4312
# Epoch 44/50
# 174500/174500 [==============================] - 19s 109us/sample - loss: -108.2733 - x_pred_binary_loss: 2.1299 - activation_9_loss: 1.9164 - x_pred_review_log_lambda_layer_loss: -108.8906 - x_pred_coordinates_mdn_layer_loss: -3.4365 - loss: -107.8683 - x_pred_binary_loss: 2.1296 - activation_9_loss: 1.9165 - x_pred_review_log_lambda_layer_loss: -108.4860 - x_pred_coordinates_mdn_layer_loss: -3.43 - ETA: 0s - loss: -107.8293 - x_pred_binary_loss: 2.1295 - activation_9_loss: 1.9165 - x_pred_review_log_lambda_layer_loss: -108.4469 - x_pred_coordinates_mdn_layer_l
# Epoch 45/50
# 174500/174500 [==============================] - 18s 103us/sample - loss: -108.2548 - x_pred_binary_loss: 2.1425 - activation_9_loss: 1.9151 - x_pred_review_log_lambda_layer_loss: -108.8781 - x_pred_coordinates_mdn_layer_loss: -3.4416
# Epoch 46/50
# 174500/174500 [==============================] - 17s 97us/sample - loss: -108.2542 - x_pred_binary_loss: 2.1461 - activation_9_loss: 1.9130 - x_pred_review_log_lambda_layer_loss: -108.8792 - x_pred_coordinates_mdn_layer_loss: -3.4413
# Epoch 47/50
# 174500/174500 [==============================] - 19s 110us/sample - loss: -108.2656 - x_pred_binary_loss: 2.1461 - activation_9_loss: 1.9131 - x_pred_review_log_lambda_layer_loss: -108.8835 - x_pred_coordinates_mdn_layer_loss: -3.4484
# Epoch 48/50
# 174500/174500 [==============================] - 19s 108us/sample - loss: -108.2111 - x_pred_binary_loss: 2.1503 - activation_9_loss: 1.9118 - x_pred_review_log_lambda_layer_loss: -108.8291 - x_pred_coordinates_mdn_layer_loss: -3.4513
# Epoch 49/50
# 174500/174500 [==============================] - 24s 135us/sample - loss: -108.2605 - x_pred_binary_loss: 2.1415 - activation_9_loss: 1.9105 - x_pred_review_log_lambda_layer_loss: -108.8639 - x_pred_coordinates_mdn_layer_loss: -3.4557
# Epoch 50/50
# 174500/174500 [==============================] - 20s 116us/sample - loss: -108.2971 - x_pred_binary_loss: 2.1427 - activation_9_loss: 1.9090 - x_pred_review_log_lambda_layer_loss: -108.9009 - x_pred_coordinates_mdn_layer_loss: -3.4552

# %% [markdown]
# ## Building the Decoder

# %%
decode_input = Input(shape=(latent_dim, ), name = 'decode_input')
decode_layer_1 = decode_1(decode_input)
decode_layer_2 = decode_2(decode_layer_1)

decode_x_pred_coordinates=x_pred_coordinates_mdn_layer(decode_layer_2)

decode_x_pred_review = x_pred_review_log_lambda_layer(decode_layer_2)

decode_x_pred_binary = x_pred_binary_layer(decode_layer_2) # binary cross entropy
decode_x_pred_categorical = x_pred_categorical_layer(decode_layer_2) # categorical cross entropy
decode_x_pred_categorical = x_pred_categorical_layer_activation(decode_x_pred_categorical)


decoder = Model(decode_input, [decode_x_pred_coordinates, decode_x_pred_review, decode_x_pred_categorical, decode_x_pred_binary])

# %%
tf.keras.utils.plot_model(
    decoder, to_file='./description/vae_decoder.png', show_shapes=True, show_layer_names=True,
    rankdir='TB', expand_nested=False, dpi=96
)

# %%
encoder = tfk.Model(inputs=x, outputs=z_t)

# %% [markdown]
# ### Saving the Models and Metadata
# #### Saving Models (Actually, only the decoder matter)

# %%
model_json = vae.to_json()
with open(full_model_file, "w") as json_file:
    json_file.write(model_json)
vae.save_weights(full_model_weights)
print("Saved model to disk")

# encoder = Model(x, [z_mu, z_log_var])
model_json = encoder.to_json()
with open(encoder_file, "w") as json_file:
    json_file.write(model_json)
encoder.save_weights(encoder_weights)
print("Saved model to disk")

model_json = decoder.to_json()
with open(decoder_file, "w") as json_file:
    json_file.write(model_json)
decoder.save_weights(decoder_weights)
print("Saved model to disk")
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# <ipython-input-23-0b50aa3a051a> in <module>
# ----> 1 model_json = vae.to_json()
#       2 with open(full_model_file, "w") as json_file:
#       3     json_file.write(model_json)
#       4 vae.save_weights(full_model_weights)
#       5 print("Saved model to disk")
#
# ~/Desktop/fyp_repo/tf_1/lib/python3.6/site-packages/tensorflow_core/python/keras/engine/network.py in to_json(self, **kwargs)
#    1252         A JSON string.
#    1253     """
# -> 1254     model_config = self._updated_config()
#    1255     return json.dumps(
#    1256         model_config, default=serialization.get_json_type, **kwargs)
#
# ~/Desktop/fyp_repo/tf_1/lib/python3.6/site-packages/tensorflow_core/python/keras/engine/network.py in _updated_config(self)
#    1230     from tensorflow.python.keras import __version__ as keras_version  # pylint: disable=g-import-not-at-top
#    1231
# -> 1232     config = self.get_config()
#    1233     model_config = {
#    1234         'class_name': self.__class__.__name__,
#
# ~/Desktop/fyp_repo/tf_1/lib/python3.6/site-packages/tensorflow_core/python/keras/engine/network.py in get_config(self)
#     916     if not self._is_graph_network:
#     917       raise NotImplementedError
# --> 918     return copy.deepcopy(get_network_config(self))
#     919
#     920   @classmethod
#
# ~/Desktop/fyp_repo/tf_1/lib/python3.6/site-packages/tensorflow_core/python/keras/engine/network.py in get_network_config(network, serialize_layer_fn)
#    1991           filtered_inbound_nodes.append(node_data)
#    1992
# -> 1993     layer_config = serialize_layer_fn(layer)
#    1994     layer_config['name'] = layer.name
#    1995     layer_config['inbound_nodes'] = filtered_inbound_nodes
#
# ~/Desktop/fyp_repo/tf_1/lib/python3.6/site-packages/tensorflow_core/python/keras/utils/generic_utils.py in serialize_keras_object(instance)
#     196
#     197   if hasattr(instance, 'get_config'):
# --> 198     config = instance.get_config()
#     199     serialization_config = {}
#     200     for key, item in config.items():
#
# ~/Desktop/fyp_repo/tf_1/lib/python3.6/site-packages/tensorflow_core/python/keras/engine/base_layer.py in get_config(self)
#     497     # or that `get_config` has been overridden:
#     498     if len(extra_args) > 1 and hasattr(self.get_config, '_is_default'):
# --> 499       raise NotImplementedError('Layers with arguments in `__init__` must '
#     500                                 'override `get_config`.')
#     501     return config
#
# NotImplementedError: Layers with arguments in `__init__` must override `get_config`.

# %% [markdown]
# #### Generating and Saving Metadata

# %%
vae_sample = train_dataset[np.random.choice(len(train_dataset), size=10000, replace=False)]
z_meta = encoder.predict(vae_sample, batch_size=batch_size)

np.save('./model/z_meta.npy', z_meta)

# %% [markdown]
# ### Generating some Samples for Testing
# #### Functions for data generation

# %%
reverse_categorical_map = {0:0, 1:0.5, 2:1, 3:1.5, 4:2, 5:2.5, 6:3, 7:3.5, 8:4, 9:4.5, 10:5}
def sample(decoder,input_z_params,samples_per_z=1):
    multiplied_input_z_params = np.repeat(input_z_params, samples_per_z, axis=0)

    predictions = decoder.predict(multiplied_input_z_params, batch_size = None, steps = 1)
    return reconstruct(predictions)
    
def reconstruct(predictions):
    coordinates, review, categorical, binary = predictions
    print(categorical.dtype)
    # coordinates handled here
    print(coordinates.shape)
    coordinates_data = np.apply_along_axis(mdn.sample_from_output, 1, coordinates, OUTPUT_DIMS, N_MIXES, temp=1.0)
    coordinates_data = np.squeeze(coordinates_data, axis=1)
    scaler = load(open('./model/standard_scaler.pkl', 'rb'))
    coordinates_data = scaler.inverse_transform(coordinates_data)
    print(coordinates_data.shape)
    
    for i, c in enumerate(coordinates_data):
        x = coordinates_data[i][1]
        y = coordinates_data[i][0]
        lon, lat = meters2lonlat(x, y)
        coordinates_data[i][1] = lon
        coordinates_data[i][0] = lat
    
    for i, c in enumerate(coordinates_data):
        if c[0] > 180.0:
            coordinates_data[i][0]= 180.0
        if c[0] < -180.0:
            coordinates_data[i][0]= -180.0
        if c[1] > 180.0:
            coordinates_data[i][1]= 180.0
        if c[1] < -180.0:
            coordinates_data[i][1]= -180.0
    
    ## review_count handled here
    exp_log_review = np.exp(review)
    review_data = np.random.poisson(lam=exp_log_review, size = review.shape)
    for i, r in enumerate(review_data):
        if r[0] < 0:
            review_data[i][0] = 0
        review_data[i][0] = float(int(review_data[i][0]))
#     for c in categorical:
#         if np.sum(c, dtype=np.float16) > 1.0:
#             print(c, np.sum(c, dtype=np.float16))
    
    categorical = np.apply_along_axis(lambda t : np.random.multinomial(1,t), -1, categorical)
    categorical = np.apply_along_axis(lambda t : np.argmax(t), -1, categorical)
    categorical = np.expand_dims(categorical, axis = -1)
    categorical_data = np.apply_along_axis(lambda t : float(reverse_categorical_map[t[0]]), -1, categorical)
    categorical_data = np.expand_dims(categorical_data, axis = -1)
    binary_data = np.apply_along_axis(lambda t: np.random.binomial(1, t), -1, binary)
#     coordinates, reviews = np.split(continuous_data, indices_or_sections=[2], axis = 1)
    return np.concatenate([coordinates_data, categorical_data, review_data, binary_data], axis = 1)
    

def reparameterize(input_mu, input_log_var, eps):
    sigma = np.exp(0.5*input_log_var)
    return eps*sigma + input_mu

# %% [markdown]
# ### Generating Samples
# Make use of the funciton sample to generate samples with our model. U need to supply an array of mu and their respective log var in a separate array to do that.

# %%
vae_samples = sample(decoder, z_meta)

# # Saving the samples in a separate file
file_name = './samples/vae_11_sample_' + str(len(z_meta))+'_times_'+ str(len(vae_samples)//len(z_meta)) + '.csv'
np.savetxt(file_name, vae_samples, delimiter = ',', header='latitude,longitude,stars,review_count,is_open')
# Out:
# WARNING:tensorflow:When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# float32
# (10000, 50)
# (10000, 2)

# %%
vae_samples[1:10]
# Out:
# array([[  33.35861327, -111.90751038,    5.        ,   10.        ,
#            0.        ],
#        [  43.83389651,  -79.19158273,    3.5       ,    6.        ,
#            1.        ],
#        [  35.66103766, -114.99582363,    5.        ,    8.        ,
#            1.        ],
#        [  43.55067007,  -89.01482954,    3.        ,    6.        ,
#            1.        ],
#        [  41.60122171,  -81.01335794,    2.5       ,    9.        ,
#            0.        ],
#        [  43.68811365,  -79.59064075,    3.        ,   33.        ,
#            1.        ],
#        [  36.01870616, -115.05904077,    3.        ,   12.        ,
#            1.        ],
#        [  35.64311011, -114.94561413,    4.5       ,    7.        ,
#            1.        ],
#        [  33.37984217, -112.18428434,    5.        ,    3.        ,
#            1.        ]])
